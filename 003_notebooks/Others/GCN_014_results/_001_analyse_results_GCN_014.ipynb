# %%
#--------------------------------
## IMPORTS
#--------------------------------
import sys
import os

# set the path to find the modules
sys.path.insert(0, '../../005_src/') #use relative path
os.chdir("../../005_src")

from config import *
# Out:
# ----------------------------------------
# Packages import successful
# Variables import successful
# Helper Functions import successful
# Functions import successful
# Functions xml import successful
# Functions graph import successful
# Functions GCN import successful
# Functions Plotting import successful
# Functions Data Adjustments import successful
# ----------------------------------------
# root directory: /storage/remote/atcremers50/ss21_multiagentcontrol/
# input directory: /storage/remote/atcremers50/ss21_multiagentcontrol/004_data/
# output directory: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/
# ----------------------------------------
#
# ----------------------------------------
# root directory: /storage/remote/atcremers50/ss21_multiagentcontrol/
# input directory: /storage/remote/atcremers50/ss21_multiagentcontrol/004_data/
# output directory: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/
# ----------------------------------------

# %%
device = cudaOverview()
# Out:
# CUDA available
# Number of Devices: 1
# ID current Device NVIDIA GeForce GTX 1050 Ti: 0
# 	current GPU memory usage by tensors in bytes:0
# 	current GPU memory managed by caching allocator in bytes:0

# %%
this_date = "20210723"
ts = "22h36m37s"#"22h28m11s"#"21h30m51s"#"18h37m00s"#"20h33m28s"#"19h37m02s" #"13h15m59s"
GCN_num = "014"
this_GCN = f"GCN_{GCN_num}"
print (this_GCN)

from _03_Networks.GCN_014.GCN_model_014 import *
from _03_Networks.GCN_014.GCN_trainer_014 import *
this_GCN, ts_import = check_import()
# Out:
# GCN_014
# at 07h19m06s imported models:
# ['GCN_HL01_bn_relu', 'GCN_HL01_bn_tanh', 'GCN_HL02_bn_relu', 'GCN_HL02_bn_tanh', 'GCN_HL03_bn_relu', 'GCN_HL03_bn_tanh']
# imported trainer: GCN_014 at 07h19m06s

# %% [markdown]
# ## Reload dictionary

# %%
MODEL_OUTPUT_PATH = os.path.join(OUTPUT_DIR,f"{this_GCN}/")
MODEL_OUTPUT_PATH_TODAY = os.path.join(MODEL_OUTPUT_PATH,f"{this_date}-{ts}/")
print (MODEL_OUTPUT_PATH_TODAY)
# Out:
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/

# %%
dict_text_output_path = f"/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/{this_GCN}/{this_date}-{ts}/{this_date}-{ts}_training_parameters"

reloaded_dict = pkl.load(open(f'{dict_text_output_path}.pkl',"rb"))
reloaded_dict
# Out:
# {'input_file_name': '20210710-20h38m27s_timesteps14930_ec3500_em7000',
#  'max_num_veh': 10,
#  'sim_duration_timesteps': '15000',
#  'run_date': '20210723-',
#  'run_time': '22h36m37s',
#  'model': 'GCN_014',
#  'combo': ('mean',
#   128,
#   'Adam',
#   'L1',
#   [64, 128, 256],
#   0.001,
#   0.6,
#   0,
#   'CosineAnnealingWarmRestarts',
#   True,
#   'relu'),
#  'random_seed': 42,
#  'train_size': 0.9,
#  'batch_size': 1024,
#  'Nepochs': 20000,
#  'save_every': 1000,
#  'transformstat': False,
#  'plotstat': True,
#  'printstat': False,
#  'intentionstat': 'obsoleted',
#  'use_edges_attr': True,
#  'activation_function': 'relu',
#  'shuttle_train_frame': None,
#  'shuttle_val_frame': None,
#  'num_rows_training': 10588,
#  'num_rows_validation': 1059,
#  'num_rows_test': 118,
#  'exclude_yaw': 'obsoleted',
#  'concatenatestat': 'obsoleted',
#  'paddingstat': 'obsoleted',
#  'size_input': 6,
#  'size_output': 3,
#  'model_architecture': GCN_HL03_bn_relu(
#    (conv1): GraphConv(6, 64)
#    (conv2): GraphConv(64, 128)
#    (conv3): GraphConv(128, 256)
#    (conv4): GraphConv(256, 3)
#    (bn1): GraphNorm(64)
#    (bn2): GraphNorm(128)
#    (bn3): GraphNorm(256)
#  ),
#  'hidden_layers_sizes': [64, 128, 256],
#  'criterion': L1Loss(),
#  'optimizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      eps: 1e-08
#      initial_lr: 0.001
#      lr: 0.0008274303669726671
#      weight_decay: 0
#  ),
#  'reduction': 'mean',
#  'scheduler': 'CosineAnnealingWarmRestarts',
#  'model_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/20210723-22h36m37sEPOCH_25000of25000_FINAL__GCN_014.pt',
#  'train_losses_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/20210723-22h36m37sEPOCH_25000of25000_FINAL__FINAL__training_loss.pkl',
#  'val_losses_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/20210723-22h36m37sEPOCH_25000of25000_FINAL__FINAL__validation_loss.pkl',
#  'lr_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/20210723-22h36m37sEPOCH_25000of25000_FINAL__FINAL__learning_rate.pkl',
#  'epoch6000_train_loss': 0.567907837304202,
#  'epoch6000_final_val_loss': 1.4698769748210907,
#  'figure_paths': ['/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_006000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_006000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_007000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_007000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_008000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_008000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_009000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_009000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_010000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_010000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_011000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_011000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_012000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_012000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_013000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_013000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_014000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_014000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_015000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_015000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_016000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_016000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_017000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_017000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_018000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_018000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_019000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_019000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_020000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_020000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_021000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_021000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_022000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_022000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_023000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_023000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_024000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_024000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_025000of25000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_025000of25000.png'],
#  'epoch7000_train_loss': 0.4579716297713193,
#  'epoch7000_final_val_loss': 1.3310165405273438,
#  'epoch8000_train_loss': 0.29397220503200183,
#  'epoch8000_final_val_loss': 1.2142624855041504,
#  'epoch9000_train_loss': 0.20678925785151395,
#  'epoch9000_final_val_loss': 1.1448739767074585,
#  'epoch10000_train_loss': 0.17718835852362894,
#  'epoch10000_final_val_loss': 1.1258606910705566,
#  'epoch11000_train_loss': 0.16325577145273035,
#  'epoch11000_final_val_loss': 1.112441599369049,
#  'epoch12000_train_loss': 0.20442439344796268,
#  'epoch12000_final_val_loss': 1.0863840281963348,
#  'epoch13000_train_loss': 0.2025763148611242,
#  'epoch13000_final_val_loss': 1.1006092429161072,
#  'epoch14000_train_loss': 0.18718680197542364,
#  'epoch14000_final_val_loss': 1.0639678835868835,
#  'epoch15000_train_loss': 0.19110978868874637,
#  'epoch15000_final_val_loss': 1.0479232668876648,
#  'epoch16000_train_loss': 0.1562935384837064,
#  'epoch16000_final_val_loss': 1.042581707239151,
#  'epoch17000_train_loss': 0.2067337076772343,
#  'epoch17000_final_val_loss': 1.0758523643016815,
#  'epoch18000_train_loss': 0.18152902072126215,
#  'epoch18000_final_val_loss': 1.0311709493398666,
#  'epoch19000_train_loss': 0.14174108478156003,
#  'epoch19000_final_val_loss': 1.0210851728916168,
#  'epoch20000_train_loss': 0.12016064944592389,
#  'epoch20000_final_val_loss': 1.0135291665792465,
#  'epoch21000_train_loss': 0.11280825463208285,
#  'epoch21000_final_val_loss': 1.0097577720880508,
#  'epoch22000_train_loss': 0.10942752015861598,
#  'epoch22000_final_val_loss': 1.0051006227731705,
#  'epoch23000_train_loss': 0.1601635840806094,
#  'epoch23000_final_val_loss': 0.9888888597488403,
#  'epoch24000_train_loss': 0.15670206126841632,
#  'epoch24000_final_val_loss': 1.0007876753807068,
#  'epoch25000_train_loss': 0.17134819382970984,
#  'epoch25000_final_val_loss': 1.004443496465683,
#  'final_train_loss': 0.17134819382970984,
#  'final_val_loss': 1.004443496465683}

# %%
input_file_name = reloaded_dict["input_file_name"]
reloaded_dict["model_architecture"]
# Out:
# GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): GraphNorm(64)
#   (bn2): GraphNorm(128)
#   (bn3): GraphNorm(256)
# )

# %% [markdown]
# ## Plot losses

# %%
# first lossess paths
t_0_5000_path =  os.path.join(MODEL_OUTPUT_PATH_TODAY,
                              "20210723-22h36m37sEPOCH_5000of5000_FINAL__FINAL__training_loss.pkl")
v_0_5000_path =  os.path.join(MODEL_OUTPUT_PATH_TODAY,
                              "20210723-22h36m37sEPOCH_5000of5000_FINAL__FINAL__validation_loss.pkl")
lr_0_5000_path = os.path.join(MODEL_OUTPUT_PATH_TODAY,
                              "20210723-22h36m37sEPOCH_5000of5000_FINAL__FINAL__learning_rate.pkl")

# %%
# load losses
t_losses_load = pkl.load(open(t_0_5000_path, 'rb'))
v_losses_load = pkl.load(open(v_0_5000_path, 'rb'))
lr_load = pkl.load(open(lr_0_5000_path, 'rb'))

# %%
# load losses
t_losses_load.extend(pkl.load(open( reloaded_dict['train_losses_path'], 'rb')))
v_losses_load.extend(pkl.load(open( reloaded_dict['val_losses_path'], 'rb')))
lr_load.extend(pkl.load(open( reloaded_dict['lr_path'], 'rb')))

# %%
#list(range(0,len(lr_load),1)),
#lr_load

# %%
##================================
# TRAIN AND VAL LOSSES
##================================
fig = plot_training(t_losses_load,
                  v_losses_load,
                  learning_rate = lr_load,
                  gaussian=True,
                  sigma=2,
                  figsize=(20, 6),
                  mytitle = 'Training & validation loss'
                  )

description = f"{this_date}-{ts}"
new_png = f"{description}_train_val_loss_plot.png"
new_png_path = os.path.join(MODEL_OUTPUT_PATH_TODAY,new_png)
plt.savefig(new_png_path)
print (f"Plot saved in {new_png_path}")
# Out:
# Plot saved in /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/20210723-22h36m37s_train_val_loss_plot.png

# %% [markdown]
# ## Verification
# of results

# %%
hidden_layers_sizes = reloaded_dict["hidden_layers_sizes"]
size_input = reloaded_dict['size_input']
size_output = reloaded_dict['size_output']
random_seed = reloaded_dict["random_seed"]
activation_fun = reloaded_dict["activation_function"]

# %%
##================================
## MODEL INIT
##================================
num_hidden_layers = len(hidden_layers_sizes)
    
#print (printstat)
#pdb.set_trace()

## TANH

if activation_fun == "tanh":
    if num_hidden_layers == 1:

        hc_1 = hidden_layers_sizes[0]
        hc_2 = None
        hc_3 = None

        model = GCN_HL01_bn_tanh(
                            num_input_features=size_input,
                            num_output_features =size_output,
                            random_seed = random_seed,
                            hc_1 = hc_1,
                            printstat = printstat, 
                            )
    elif num_hidden_layers == 2:

        hc_1 = hidden_layers_sizes[0]
        hc_2 = hidden_layers_sizes[1]
        hc_3 = None

        model = GCN_HL02_bn_tanh(
                            num_input_features=size_input,
                            num_output_features =size_output,
                            random_seed = random_seed,
                            hc_1 = hc_1,
                            hc_2 = hc_2,
                            printstat = printstat,   
                            )
    elif num_hidden_layers == 3:

        hc_1 = hidden_layers_sizes[0]
        hc_2 = hidden_layers_sizes[1]
        hc_3 = hidden_layers_sizes[2]

        model = GCN_HL03_bn_tanh(
                            num_input_features=size_input,
                            num_output_features =size_output,
                            random_seed = random_seed,
                            hc_1 = hc_1,
                            hc_2 = hc_2,
                            hc_3 = hc_3,
                            printstat = printstat,                
                            )
    else:
        print (f"ERROR: model with {num_hidden_layers=} not implemented")
        print (f"using first three layers")

        hc_1 = hidden_layers_sizes[0]
        hc_2 = hidden_layers_sizes[1]
        hc_3 = hidden_layers_sizes[2]

        model = GCN_HL03_bn_tanh(num_input_features=size_input,
                    num_output_features =size_output,
                    random_seed = random_seed,
                    hc_1 = hc_1,
                    hc_2 = hc_2,
                    hc_3 = hc_3,
                    printstat = printstat, 
                    )
        
#### RELU       
        
elif activation_fun == "relu": 
    if num_hidden_layers == 1:

        hc_1 = hidden_layers_sizes[0]
        hc_2 = None
        hc_3 = None

        model = GCN_HL01_bn_relu(
                            num_input_features=size_input,
                            num_output_features =size_output,
                            random_seed = random_seed,
                            hc_1 = hc_1,
                            printstat = printstat,                 
                            )
    elif num_hidden_layers == 2:

        hc_1 = hidden_layers_sizes[0]
        hc_2 = hidden_layers_sizes[1]
        hc_3 = None

        model = GCN_HL02_bn_relu(
                            num_input_features=size_input,
                            num_output_features =size_output,
                            random_seed = random_seed,
                            hc_1 = hc_1,
                            hc_2 = hc_2,
                            printstat = printstat,                 
                            )
    elif num_hidden_layers == 3:

        hc_1 = hidden_layers_sizes[0]
        hc_2 = hidden_layers_sizes[1]
        hc_3 = hidden_layers_sizes[2]

        model = GCN_HL03_bn_relu(
                            num_input_features=size_input,
                            num_output_features =size_output,
                            random_seed = random_seed,
                            hc_1 = hc_1,
                            hc_2 = hc_2,
                            hc_3 = hc_3,
                            printstat = printstat,               
                            )
    else:
        print (f"ERROR: model with {num_hidden_layers=} not implemented")
        print (f"using first three layers")

        hc_1 = hidden_layers_sizes[0]
        hc_2 = hidden_layers_sizes[1]
        hc_3 = hidden_layers_sizes[2]

        model = GCN_HL03_bn_relu(num_input_features=size_input,
                    num_output_features =size_output,
                    random_seed = random_seed,
                    hc_1 = hc_1,
                    hc_2 = hc_2,
                    hc_3 = hc_3,
                    printstat = printstat,                                      
                    )
else:
    print (f"ERROR: model with {activation_fun=} not implemented")

load_model = model

# %%
load_path = reloaded_dict['model_path']
load_model.load_state_dict(torch.load(load_path))
load_model.eval()
# Out:
# GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): GraphNorm(64)
#   (bn2): GraphNorm(128)
#   (bn3): GraphNorm(256)
# )

# %%
MODEL_OUTPUT_PATH = os.path.join(OUTPUT_DIR,f"{this_GCN}/")
MODEL_OUTPUT_PATH_DATASETS = os.path.join(MODEL_OUTPUT_PATH,f"DATASETS/")
datasets_list = sorted(glob.glob(f"{MODEL_OUTPUT_PATH_DATASETS}"+"/**/*"+f'{input_file_name}_dataset*',
                                     recursive=True))
if len( datasets_list) == 5:                               
        print ("\n> DATASETS FOUND")
        print (*datasets_list, sep = "\n")
        
        dataset_train = torch.load(datasets_list[0], map_location=torch.device('cpu') )
        # map_location=lambda storage, loc: storage.cuda(0))
        dataset_val = torch.load(datasets_list[1], map_location=torch.device('cpu') )
        dataset_test = torch.load(datasets_list[2], map_location=torch.device('cpu') )
        dataset_shuttle_train = torch.load(datasets_list[3], map_location=torch.device('cpu') )
        dataset_shuttle_val = torch.load(datasets_list[4], map_location=torch.device('cpu') )

# %%
path_GIF= build_gif(folder = f'/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_{GCN_num}/{this_date}-{ts}/figures_validation_set/',
              title = "Predictions over epochs",
              search = "", 
              fps=0.5,
              recursive = True,
              delete_tempFiles = False,
              max_n_images = 200
             )
# Out:
# 1it [00:00,  9.34it/s]
# found 30 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/
# the gif will be create using the first 30 images
# 30it [00:02, 11.71it/s]

# %%
Image(open(f'{path_GIF}','rb').read())

# %%
path_GIF= build_gif(folder = f'/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_{GCN_num}/{this_date}-{ts}/figures_training_set/',
              title = "Predictions over epochs",
              search = "", 
              fps=0.5,
              recursive = True,
              delete_tempFiles = False,
              max_n_images = 200
             )
# Out:
# 2it [00:00, 11.64it/s]
# found 30 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/
# the gif will be create using the first 30 images
# 30it [00:02, 11.21it/s]

# %%
Image(open(f'{path_GIF}','rb').read())

# %%
deleted_folders = delete_empty_r(directory= MODEL_OUTPUT_PATH,printstat = True)
# Out:
# deleted path: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/.ipynb_checkpoints
# deleted path: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/.ipynb_checkpoints
