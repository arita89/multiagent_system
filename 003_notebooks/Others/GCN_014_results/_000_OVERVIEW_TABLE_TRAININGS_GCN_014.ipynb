# %%
#--------------------------------
## IMPORTS
#--------------------------------
import sys
import os

# set the path to find the modules
os.chdir("../../005_src")

from config import *
print (os.getenv('CONDA_PREFIX'))
# Out:
# ----------------------------------------
# Packages import successful
# Variables import successful
# Helper Functions import successful
# Functions import successful
# Functions xml import successful
# Functions graph import successful
# Functions GCN import successful
# Functions Plotting import successful
# Functions Data Adjustments import successful
# ----------------------------------------
# root directory: /storage/remote/atcremers50/ss21_multiagentcontrol/
# input directory: /storage/remote/atcremers50/ss21_multiagentcontrol/004_data/
# output directory: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/
# ----------------------------------------
#
# ----------------------------------------
# root directory: /storage/remote/atcremers50/ss21_multiagentcontrol/
# input directory: /storage/remote/atcremers50/ss21_multiagentcontrol/004_data/
# output directory: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/
# ----------------------------------------
#
# /usr/prakt/s0014/anaconda3/envs/p37_GCN_GPU

# %%
device = cudaOverview()
# Out:
# CUDA available
# Number of Devices: 1
# ID current Device NVIDIA GeForce GTX 1050 Ti: 0
# 	current GPU memory usage by tensors in bytes:0
# 	current GPU memory managed by caching allocator in bytes:0

# %%
filenames = sorted(glob.glob(f"{OUTPUT_DIR}"+"/**/*"+f"*training_parameters.pkl", recursive=True))
all_dict = [pkl.load(open(this_file,"rb"))for this_file in filenames]
#all_dict = [pkl.loads(memoryview(open(this_file,"rb"))) for this_file in filenames]

df = pd.DataFrame(all_dict)
# Out:
# at 09h42m57s imported models:
# ['GCN_HL01', 'GCN_HL02', 'GCN_HL03']
# edges_attr=True
# at 09h42m57s imported models:
# ['GCN_HL01_relu', 'GCN_HL01_tanh', 'GCN_HL02_relu', 'GCN_HL02_tanh', 'GCN_HL03_relu', 'GCN_HL03_tanh']
# edges_attr=True
# at 09h42m57s imported models:
# ['GCN_HL01_leaky_relu', 'GCN_HL01_relu', 'GCN_HL01_tanh', 'GCN_HL02_leaky_relu', 'GCN_HL02_relu', 'GCN_HL02_tanh', 'GCN_HL03_leaky_relu', 'GCN_HL03_relu', 'GCN_HL03_tanh']
# at 09h42m57s imported models:
# ['GCN_HL01_bn_relu', 'GCN_HL01_bn_tanh', 'GCN_HL02_bn_relu', 'GCN_HL02_bn_tanh', 'GCN_HL03_bn_relu', 'GCN_HL03_bn_tanh']
# at 09h42m57s imported models:
# ['GCN_HL01_bn_relu', 'GCN_HL01_bn_tanh', 'GCN_HL02_bn_relu', 'GCN_HL02_bn_tanh', 'GCN_HL03_bn_relu', 'GCN_HL03_bn_tanh']

# %%
df.columns
# Out:
# Index(['run_time', 'model', 'random_seed', 'train_size', 'batch_size',
#        'Nepochs', 'save_every', 'transformstat', 'plotstat', 'printstat',
#        ...
#        'batch_size_007', 'Nepochs_007', 'input_file_name_008',
#        'train_size_008', 'batch_size_008', 'Nepochs_008',
#        'epoch9000_train_loss', 'epoch9000_final_val_loss',
#        'epoch10000_train_loss', 'epoch10000_final_val_loss'],
#       dtype='object', length=124)

# %% [markdown]
# # TABLE TRAININGS OVERVIEW
#
# here all the trainings completed succcessfully with a txt file

# %%
df.scheduler.unique()
# Out:
# array([nan,
#        <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7f22c939f2b0>,
#        <torch.optim.lr_scheduler.MultiStepLR object at 0x7f22c939fa00>,
#        <torch.optim.lr_scheduler.CosineAnnealingWarmRestarts object at 0x7f22c939fd90>,
#        None, 'ReduceLROnPlateau', 'MultiStepLR',
#        'CosineAnnealingWarmRestarts', 'NoneType'], dtype=object)

# %% [markdown]
# # Comparative overviews

# %%
GCN_MODEL = "GCN_014"
MODEL_PATH =os.path.join(OUTPUT_DIR,GCN_MODEL)
MODEL_PATH
# Out:
# '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014'

# %%
columns_with_final_val_losses = sorted([col for col in df.columns if "val_loss" in col])
epoch_val_losses = [re.findall(r'\d+', col) for col in columns_with_final_val_losses]
print (list(zip(columns_with_final_val_losses,epoch_val_losses)))
columns_with_final_train_losses = sorted([col for col in df.columns if "train_loss" in col])
columns_with_final_train_losses
# Out:
# [('epoch10000_final_val_loss', ['10000']), ('epoch1000_final_val_loss', ['1000']), ('epoch12000_final_val_loss', ['12000']), ('epoch14000_final_val_loss', ['14000']), ('epoch1500_final_val_loss', ['1500']), ('epoch16000_final_val_loss', ['16000']), ('epoch1_final_val_loss', ['1']), ('epoch20000_final_val_loss', ['20000']), ('epoch2000_final_val_loss', ['2000']), ('epoch2500_final_val_loss', ['2500']), ('epoch28000_final_val_loss', ['28000']), ('epoch2_final_val_loss', ['2']), ('epoch3000_final_val_loss', ['3000']), ('epoch3500_final_val_loss', ['3500']), ('epoch3_final_val_loss', ['3']), ('epoch4000_final_val_loss', ['4000']), ('epoch4500_final_val_loss', ['4500']), ('epoch4_final_val_loss', ['4']), ('epoch5000_final_val_loss', ['5000']), ('epoch500_final_val_loss', ['500']), ('epoch5_final_val_loss', ['5']), ('epoch6000_final_val_loss', ['6000']), ('epoch7000_final_val_loss', ['7000']), ('epoch8000_final_val_loss', ['8000']), ('epoch9000_final_val_loss', ['9000']), ('final_val_loss', []), ('val_losses_path', [])]
# ['epoch10000_train_loss',
#  'epoch1000_train_loss',
#  'epoch12000_train_loss',
#  'epoch14000_train_loss',
#  'epoch1500_train_loss',
#  'epoch16000_train_loss',
#  'epoch1_train_loss',
#  'epoch20000_train_loss',
#  'epoch2000_train_loss',
#  'epoch2500_train_loss',
#  'epoch28000_train_loss',
#  'epoch2_train_loss',
#  'epoch3000_train_loss',
#  'epoch3500_train_loss',
#  'epoch3_train_loss',
#  'epoch4000_train_loss',
#  'epoch4500_train_loss',
#  'epoch4_train_loss',
#  'epoch5000_train_loss',
#  'epoch500_train_loss',
#  'epoch5_train_loss',
#  'epoch6000_train_loss',
#  'epoch7000_train_loss',
#  'epoch8000_train_loss',
#  'epoch9000_train_loss',
#  'final_train_loss',
#  'train_losses_path']

# %% [markdown]
# ## Compare GCN_014

# %%
df.columns
# Out:
# Index(['run_time', 'model', 'random_seed', 'train_size', 'batch_size',
#        'Nepochs', 'save_every', 'transformstat', 'plotstat', 'printstat',
#        ...
#        'batch_size_007', 'Nepochs_007', 'input_file_name_008',
#        'train_size_008', 'batch_size_008', 'Nepochs_008',
#        'epoch9000_train_loss', 'epoch9000_final_val_loss',
#        'epoch10000_train_loss', 'epoch10000_final_val_loss'],
#       dtype='object', length=124)

# %%
mask = (df.model == GCN_MODEL) #and (df.Nepochs == 5000)
df_model = df[mask][[
                'run_date',
                'run_time', 
                'model',
                'Nepochs',
                'batch_size',
                #'input_file_name',
                #'size_input', 
                #'size_output', 
                'model_architecture', 
                'num_rows_training',

                'criterion', 
                'optimizer', 
                #'reduction',
                'scheduler',

                'final_train_loss', 
                'final_val_loss', 
                #'intentionstat', 
                #'model_path',
                'train_losses_path', 
                'val_losses_path',
            
               #'lr',
                'use_edges_attr',
                'activation_function',
                'combo'
                
                   
           ]]
df_model
# Out:
#       run_date   run_time    model  Nepochs  batch_size  \
# 338  20210723-  14h28m01s  GCN_014     5000         128
# 339  20210723-  15h59m43s  GCN_014     5000         128
# 340  20210723-  16h00m45s  GCN_014     5000         128
# 341  20210723-  16h01m42s  GCN_014     5000         128
# 342  20210723-  16h02m40s  GCN_014     5000         128
# 343  20210723-  16h03m37s  GCN_014     5000         128
# 344  20210723-  16h04m35s  GCN_014     5000         128
# 345  20210723-  16h05m32s  GCN_014     5000         128
# 346  20210723-  16h06m30s  GCN_014     5000         128
# 347  20210723-  16h23m09s  GCN_014     5000         128
# 348  20210723-  16h24m33s  GCN_014     5000         128
# 349  20210723-  16h25m52s  GCN_014     5000         128
# 350  20210723-  16h27m17s  GCN_014     5000         128
# 351  20210723-  16h28m37s  GCN_014     5000         128
# 352  20210723-  16h30m06s  GCN_014     5000         128
# 353  20210723-  16h31m25s  GCN_014     5000         128
# 354  20210723-  18h45m06s  GCN_014        5         128
# 355  20210723-  18h45m14s  GCN_014        5         128
# 356  20210723-  18h45m20s  GCN_014        5         128
# 357  20210723-  18h48m11s  GCN_014        5           1
# 358  20210723-  18h48m52s  GCN_014        5           1
# 359  20210723-  18h49m31s  GCN_014        5           1
# 360  20210723-  19h08m21s  GCN_014        5           1
# 361  20210723-  19h09m02s  GCN_014        5           1
# 362  20210723-  19h09m43s  GCN_014        5           1
# 363  20210723-  19h22m42s  GCN_014        5           1
# 364  20210723-  19h23m23s  GCN_014        5           1
# 365  20210723-  19h24m03s  GCN_014        5           1
# 366  20210723-  19h36m28s  GCN_014     5000         128
# 367  20210723-  22h36m37s  GCN_014    20000         512
# 368  20210723-  22h44m02s  GCN_014     5000         128
# 369  20210724-  07h59m18s  GCN_014     5000         128
# 370  20210724-  08h01m46s  GCN_014     5000         128
# 371  20210724-  08h04m02s  GCN_014     5000         128
# 372  20210724-  08h06m15s  GCN_014     5000         128
# 373  20210724-  08h18m52s  GCN_014    20000         512
# 374  20210725-  00h41m56s  GCN_014     5000         512
# 375  20210725-  13h51m08s  GCN_014     5000         512
# 376  20210725-  16h34m34s  GCN_014     5000         512
# 377  20210725-  16h38m02s  GCN_014     5000         512
# 378  20210725-  16h40m10s  GCN_014     5000         512
# 379  20210725-  16h45m59s  GCN_014     5000         512
# 380  20210725-  16h48m09s  GCN_014     5000         512
# 381  20210725-  16h51m01s  GCN_014     5000         512
# 382  20210725-  16h53m11s  GCN_014     5000         512
# 383  20210725-  16h59m01s  GCN_014     5000         512
#
#                                     model_architecture  num_rows_training  \
# 338  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...              10588
# 339  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 340  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 341  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 342  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 343  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 344  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 345  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 346  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 347  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 348  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 349  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 350  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 351  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 352  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 353  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 354  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 355  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 356  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 357  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 358  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 359  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 360  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 361  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 362  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 363  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 364  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 365  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 366  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 367  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...              22478
# 368  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 369  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                127
# 370  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                127
# 371  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                127
# 372  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                127
# 373  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...              22478
# 374  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...              22478
# 375  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...             105883
# 376  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...                146
# 377  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                146
# 378  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...                146
# 379  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                146
# 380  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...                146
# 381  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                146
# 382  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...                146
# 383  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                146
#
#     criterion                                          optimizer  \
# 338  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 339  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 340  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 341  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 342  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 343  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 344  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 345  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 346  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 347  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 348  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 349  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 350  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 351  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 352  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 353  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 354  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 355  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 356  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 357  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 358  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 359  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 360  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 361  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 362  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 363  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 364  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 365  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 366  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 367  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 368  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 369  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 370  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 371  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 372  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 373  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 374  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 375  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 376  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 377  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 378  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 379  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 380  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 381  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 382  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 383  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
#
#                        scheduler  final_train_loss  final_val_loss  \
# 338            ReduceLROnPlateau       2259.217123     2309.631985
# 339            ReduceLROnPlateau       8853.123047     1261.532959
# 340            ReduceLROnPlateau       8661.816406     1124.254639
# 341  CosineAnnealingWarmRestarts       6916.051758     1066.461670
# 342  CosineAnnealingWarmRestarts       4870.933105      754.521484
# 343                     NoneType       4875.875488      993.423767
# 344                     NoneType       3236.903809      594.665405
# 345                  MultiStepLR      11670.248047     1435.495361
# 346                  MultiStepLR      11033.661133     1338.555908
# 347            ReduceLROnPlateau       8838.965820     1112.163696
# 348            ReduceLROnPlateau       8653.780273     1103.817261
# 349  CosineAnnealingWarmRestarts       6855.289062     1057.868530
# 350  CosineAnnealingWarmRestarts       4981.092285      760.006104
# 351                     NoneType       4915.426270      894.899780
# 352                     NoneType       3209.781006      684.326355
# 353                  MultiStepLR               NaN             NaN
# 354  CosineAnnealingWarmRestarts         11.002303       13.771930
# 355                     NoneType         10.946132       13.988120
# 356                     NoneType         10.946132       14.532098
# 357  CosineAnnealingWarmRestarts         10.495321       14.402861
# 358                     NoneType         10.522602       13.409588
# 359                     NoneType         10.472254       14.425552
# 360  CosineAnnealingWarmRestarts         10.405718       14.452155
# 361                     NoneType         10.513580       14.256391
# 362                     NoneType         10.413995       15.083491
# 363  CosineAnnealingWarmRestarts         10.435364       13.148211
# 364                     NoneType         10.404019       13.607946
# 365                     NoneType         10.418518       14.269820
# 366  CosineAnnealingWarmRestarts          1.490443        2.873843
# 367                     NoneType          0.124258        0.280679
# 368                     NoneType          0.923467        4.650014
# 369  CosineAnnealingWarmRestarts          2.719573        4.072335
# 370  CosineAnnealingWarmRestarts          0.816534        2.516336
# 371                     NoneType          1.495942        5.180782
# 372                     NoneType          0.294851        2.726004
# 373  CosineAnnealingWarmRestarts               NaN             NaN
# 374  CosineAnnealingWarmRestarts          0.103252        0.179579
# 375  CosineAnnealingWarmRestarts          0.177611        0.197008
# 376  CosineAnnealingWarmRestarts          0.282124        2.067297
# 377  CosineAnnealingWarmRestarts          0.806616        1.973811
# 378  CosineAnnealingWarmRestarts          0.974617        3.193087
# 379  CosineAnnealingWarmRestarts          2.336663        3.262593
# 380                     NoneType          0.146398        2.045143
# 381                     NoneType          0.242757        2.012705
# 382                     NoneType          0.333207        2.402230
# 383                     NoneType          1.295042        3.211135
#
#                                      train_losses_path  \
# 338  /storage/remote/atcremers50/ss21_multiagentcon...
# 339  /storage/remote/atcremers50/ss21_multiagentcon...
# 340  /storage/remote/atcremers50/ss21_multiagentcon...
# 341  /storage/remote/atcremers50/ss21_multiagentcon...
# 342  /storage/remote/atcremers50/ss21_multiagentcon...
# 343  /storage/remote/atcremers50/ss21_multiagentcon...
# 344  /storage/remote/atcremers50/ss21_multiagentcon...
# 345  /storage/remote/atcremers50/ss21_multiagentcon...
# 346  /storage/remote/atcremers50/ss21_multiagentcon...
# 347  /storage/remote/atcremers50/ss21_multiagentcon...
# 348  /storage/remote/atcremers50/ss21_multiagentcon...
# 349  /storage/remote/atcremers50/ss21_multiagentcon...
# 350  /storage/remote/atcremers50/ss21_multiagentcon...
# 351  /storage/remote/atcremers50/ss21_multiagentcon...
# 352  /storage/remote/atcremers50/ss21_multiagentcon...
# 353  /storage/remote/atcremers50/ss21_multiagentcon...
# 354  /storage/remote/atcremers50/ss21_multiagentcon...
# 355  /storage/remote/atcremers50/ss21_multiagentcon...
# 356  /storage/remote/atcremers50/ss21_multiagentcon...
# 357  /storage/remote/atcremers50/ss21_multiagentcon...
# 358  /storage/remote/atcremers50/ss21_multiagentcon...
# 359  /storage/remote/atcremers50/ss21_multiagentcon...
# 360  /storage/remote/atcremers50/ss21_multiagentcon...
# 361  /storage/remote/atcremers50/ss21_multiagentcon...
# 362  /storage/remote/atcremers50/ss21_multiagentcon...
# 363  /storage/remote/atcremers50/ss21_multiagentcon...
# 364  /storage/remote/atcremers50/ss21_multiagentcon...
# 365  /storage/remote/atcremers50/ss21_multiagentcon...
# 366  /storage/remote/atcremers50/ss21_multiagentcon...
# 367  /storage/remote/atcremers50/ss21_multiagentcon...
# 368  /storage/remote/atcremers50/ss21_multiagentcon...
# 369  /storage/remote/atcremers50/ss21_multiagentcon...
# 370  /storage/remote/atcremers50/ss21_multiagentcon...
# 371  /storage/remote/atcremers50/ss21_multiagentcon...
# 372  /storage/remote/atcremers50/ss21_multiagentcon...
# 373  /storage/remote/atcremers50/ss21_multiagentcon...
# 374  /storage/remote/atcremers50/ss21_multiagentcon...
# 375  /storage/remote/atcremers50/ss21_multiagentcon...
# 376  /storage/remote/atcremers50/ss21_multiagentcon...
# 377  /storage/remote/atcremers50/ss21_multiagentcon...
# 378  /storage/remote/atcremers50/ss21_multiagentcon...
# 379  /storage/remote/atcremers50/ss21_multiagentcon...
# 380  /storage/remote/atcremers50/ss21_multiagentcon...
# 381  /storage/remote/atcremers50/ss21_multiagentcon...
# 382  /storage/remote/atcremers50/ss21_multiagentcon...
# 383  /storage/remote/atcremers50/ss21_multiagentcon...
#
#                                        val_losses_path use_edges_attr  \
# 338  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 339  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 340  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 341  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 342  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 343  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 344  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 345  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 346  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 347  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 348  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 349  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 350  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 351  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 352  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 353  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 354  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 355  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 356  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 357  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 358  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 359  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 360  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 361  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 362  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 363  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 364  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 365  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 366  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 367  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 368  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 369  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 370  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 371  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 372  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 373  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 374  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 375  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 376  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 377  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 378  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 379  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 380  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 381  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 382  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 383  /storage/remote/atcremers50/ss21_multiagentcon...           True
#
#     activation_function                                              combo
# 338                tanh  (sum, 128, Adam, L1, [64], 0.01, 0.6, 0, Reduc...
# 339                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Redu...
# 340                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Redu...
# 341                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Cosi...
# 342                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Cosi...
# 343                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, None...
# 344                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, None...
# 345                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Mult...
# 346                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Mult...
# 347                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Redu...
# 348                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Redu...
# 349                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Cosi...
# 350                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Cosi...
# 351                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, None...
# 352                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, None...
# 353                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Mult...
# 354                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 355                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 356                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 357                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 358                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 359                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 360                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 361                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 362                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 363                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 364                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 365                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 366                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 367                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 368                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 369                tanh  (mean, 128, Adam, L1, [128, 256, 64], 0.001, 0...
# 370                tanh  (mean, 128, Adam, L1, [128, 256, 64], 0.001, 0...
# 371                tanh  (mean, 128, Adam, L1, [128, 256, 64], 0.001, 0...
# 372                tanh  (mean, 128, Adam, L1, [128, 256, 64], 0.001, 0...
# 373                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 374                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 375                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 376                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 377                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 378                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 379                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 380                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 381                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 382                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 383                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...

# %%
df[mask].loc[373].T
# Out:
# run_time                     08h18m52s
# model                          GCN_014
# random_seed                      42314
# train_size                         0.9
# batch_size                         512
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 373, Length: 124, dtype: object

# %%
df_top = df_model.sort_values(by=['final_val_loss'])
df_top#[df_top.batch_size == 1024]
# Out:
#       run_date   run_time    model  Nepochs  batch_size  \
# 374  20210725-  00h41m56s  GCN_014     5000         512
# 375  20210725-  13h51m08s  GCN_014     5000         512
# 367  20210723-  22h36m37s  GCN_014    20000         512
# 377  20210725-  16h38m02s  GCN_014     5000         512
# 381  20210725-  16h51m01s  GCN_014     5000         512
# 380  20210725-  16h48m09s  GCN_014     5000         512
# 376  20210725-  16h34m34s  GCN_014     5000         512
# 382  20210725-  16h53m11s  GCN_014     5000         512
# 370  20210724-  08h01m46s  GCN_014     5000         128
# 372  20210724-  08h06m15s  GCN_014     5000         128
# 366  20210723-  19h36m28s  GCN_014     5000         128
# 378  20210725-  16h40m10s  GCN_014     5000         512
# 383  20210725-  16h59m01s  GCN_014     5000         512
# 379  20210725-  16h45m59s  GCN_014     5000         512
# 369  20210724-  07h59m18s  GCN_014     5000         128
# 368  20210723-  22h44m02s  GCN_014     5000         128
# 371  20210724-  08h04m02s  GCN_014     5000         128
# 363  20210723-  19h22m42s  GCN_014        5           1
# 358  20210723-  18h48m52s  GCN_014        5           1
# 364  20210723-  19h23m23s  GCN_014        5           1
# 354  20210723-  18h45m06s  GCN_014        5         128
# 355  20210723-  18h45m14s  GCN_014        5         128
# 361  20210723-  19h09m02s  GCN_014        5           1
# 365  20210723-  19h24m03s  GCN_014        5           1
# 357  20210723-  18h48m11s  GCN_014        5           1
# 359  20210723-  18h49m31s  GCN_014        5           1
# 360  20210723-  19h08m21s  GCN_014        5           1
# 356  20210723-  18h45m20s  GCN_014        5         128
# 362  20210723-  19h09m43s  GCN_014        5           1
# 344  20210723-  16h04m35s  GCN_014     5000         128
# 352  20210723-  16h30m06s  GCN_014     5000         128
# 342  20210723-  16h02m40s  GCN_014     5000         128
# 350  20210723-  16h27m17s  GCN_014     5000         128
# 351  20210723-  16h28m37s  GCN_014     5000         128
# 343  20210723-  16h03m37s  GCN_014     5000         128
# 349  20210723-  16h25m52s  GCN_014     5000         128
# 341  20210723-  16h01m42s  GCN_014     5000         128
# 348  20210723-  16h24m33s  GCN_014     5000         128
# 347  20210723-  16h23m09s  GCN_014     5000         128
# 340  20210723-  16h00m45s  GCN_014     5000         128
# 339  20210723-  15h59m43s  GCN_014     5000         128
# 346  20210723-  16h06m30s  GCN_014     5000         128
# 345  20210723-  16h05m32s  GCN_014     5000         128
# 338  20210723-  14h28m01s  GCN_014     5000         128
# 353  20210723-  16h31m25s  GCN_014     5000         128
# 373  20210724-  08h18m52s  GCN_014    20000         512
#
#                                     model_architecture  num_rows_training  \
# 374  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...              22478
# 375  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...             105883
# 367  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...              22478
# 377  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                146
# 381  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                146
# 380  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...                146
# 376  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...                146
# 382  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...                146
# 370  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                127
# 372  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                127
# 366  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 378  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...                146
# 383  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                146
# 379  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                146
# 369  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                127
# 368  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 371  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                127
# 363  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 358  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 364  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 354  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 355  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 361  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 365  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 357  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 359  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 360  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 356  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 362  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 344  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 352  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 342  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 350  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 351  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 343  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 349  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 341  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 348  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 347  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 340  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 339  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 346  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 345  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 338  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...              10588
# 353  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 373  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...              22478
#
#     criterion                                          optimizer  \
# 374  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 375  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 367  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 377  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 381  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 380  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 376  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 382  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 370  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 372  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 366  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 378  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 383  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 379  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 369  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 368  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 371  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 363  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 358  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 364  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 354  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 355  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 361  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 365  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 357  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 359  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 360  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 356  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 362  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 344  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 352  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 342  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 350  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 351  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 343  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 349  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 341  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 348  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 347  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 340  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 339  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 346  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 345  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 338  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 353  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 373  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
#
#                        scheduler  final_train_loss  final_val_loss  \
# 374  CosineAnnealingWarmRestarts          0.103252        0.179579
# 375  CosineAnnealingWarmRestarts          0.177611        0.197008
# 367                     NoneType          0.124258        0.280679
# 377  CosineAnnealingWarmRestarts          0.806616        1.973811
# 381                     NoneType          0.242757        2.012705
# 380                     NoneType          0.146398        2.045143
# 376  CosineAnnealingWarmRestarts          0.282124        2.067297
# 382                     NoneType          0.333207        2.402230
# 370  CosineAnnealingWarmRestarts          0.816534        2.516336
# 372                     NoneType          0.294851        2.726004
# 366  CosineAnnealingWarmRestarts          1.490443        2.873843
# 378  CosineAnnealingWarmRestarts          0.974617        3.193087
# 383                     NoneType          1.295042        3.211135
# 379  CosineAnnealingWarmRestarts          2.336663        3.262593
# 369  CosineAnnealingWarmRestarts          2.719573        4.072335
# 368                     NoneType          0.923467        4.650014
# 371                     NoneType          1.495942        5.180782
# 363  CosineAnnealingWarmRestarts         10.435364       13.148211
# 358                     NoneType         10.522602       13.409588
# 364                     NoneType         10.404019       13.607946
# 354  CosineAnnealingWarmRestarts         11.002303       13.771930
# 355                     NoneType         10.946132       13.988120
# 361                     NoneType         10.513580       14.256391
# 365                     NoneType         10.418518       14.269820
# 357  CosineAnnealingWarmRestarts         10.495321       14.402861
# 359                     NoneType         10.472254       14.425552
# 360  CosineAnnealingWarmRestarts         10.405718       14.452155
# 356                     NoneType         10.946132       14.532098
# 362                     NoneType         10.413995       15.083491
# 344                     NoneType       3236.903809      594.665405
# 352                     NoneType       3209.781006      684.326355
# 342  CosineAnnealingWarmRestarts       4870.933105      754.521484
# 350  CosineAnnealingWarmRestarts       4981.092285      760.006104
# 351                     NoneType       4915.426270      894.899780
# 343                     NoneType       4875.875488      993.423767
# 349  CosineAnnealingWarmRestarts       6855.289062     1057.868530
# 341  CosineAnnealingWarmRestarts       6916.051758     1066.461670
# 348            ReduceLROnPlateau       8653.780273     1103.817261
# 347            ReduceLROnPlateau       8838.965820     1112.163696
# 340            ReduceLROnPlateau       8661.816406     1124.254639
# 339            ReduceLROnPlateau       8853.123047     1261.532959
# 346                  MultiStepLR      11033.661133     1338.555908
# 345                  MultiStepLR      11670.248047     1435.495361
# 338            ReduceLROnPlateau       2259.217123     2309.631985
# 353                  MultiStepLR               NaN             NaN
# 373  CosineAnnealingWarmRestarts               NaN             NaN
#
#                                      train_losses_path  \
# 374  /storage/remote/atcremers50/ss21_multiagentcon...
# 375  /storage/remote/atcremers50/ss21_multiagentcon...
# 367  /storage/remote/atcremers50/ss21_multiagentcon...
# 377  /storage/remote/atcremers50/ss21_multiagentcon...
# 381  /storage/remote/atcremers50/ss21_multiagentcon...
# 380  /storage/remote/atcremers50/ss21_multiagentcon...
# 376  /storage/remote/atcremers50/ss21_multiagentcon...
# 382  /storage/remote/atcremers50/ss21_multiagentcon...
# 370  /storage/remote/atcremers50/ss21_multiagentcon...
# 372  /storage/remote/atcremers50/ss21_multiagentcon...
# 366  /storage/remote/atcremers50/ss21_multiagentcon...
# 378  /storage/remote/atcremers50/ss21_multiagentcon...
# 383  /storage/remote/atcremers50/ss21_multiagentcon...
# 379  /storage/remote/atcremers50/ss21_multiagentcon...
# 369  /storage/remote/atcremers50/ss21_multiagentcon...
# 368  /storage/remote/atcremers50/ss21_multiagentcon...
# 371  /storage/remote/atcremers50/ss21_multiagentcon...
# 363  /storage/remote/atcremers50/ss21_multiagentcon...
# 358  /storage/remote/atcremers50/ss21_multiagentcon...
# 364  /storage/remote/atcremers50/ss21_multiagentcon...
# 354  /storage/remote/atcremers50/ss21_multiagentcon...
# 355  /storage/remote/atcremers50/ss21_multiagentcon...
# 361  /storage/remote/atcremers50/ss21_multiagentcon...
# 365  /storage/remote/atcremers50/ss21_multiagentcon...
# 357  /storage/remote/atcremers50/ss21_multiagentcon...
# 359  /storage/remote/atcremers50/ss21_multiagentcon...
# 360  /storage/remote/atcremers50/ss21_multiagentcon...
# 356  /storage/remote/atcremers50/ss21_multiagentcon...
# 362  /storage/remote/atcremers50/ss21_multiagentcon...
# 344  /storage/remote/atcremers50/ss21_multiagentcon...
# 352  /storage/remote/atcremers50/ss21_multiagentcon...
# 342  /storage/remote/atcremers50/ss21_multiagentcon...
# 350  /storage/remote/atcremers50/ss21_multiagentcon...
# 351  /storage/remote/atcremers50/ss21_multiagentcon...
# 343  /storage/remote/atcremers50/ss21_multiagentcon...
# 349  /storage/remote/atcremers50/ss21_multiagentcon...
# 341  /storage/remote/atcremers50/ss21_multiagentcon...
# 348  /storage/remote/atcremers50/ss21_multiagentcon...
# 347  /storage/remote/atcremers50/ss21_multiagentcon...
# 340  /storage/remote/atcremers50/ss21_multiagentcon...
# 339  /storage/remote/atcremers50/ss21_multiagentcon...
# 346  /storage/remote/atcremers50/ss21_multiagentcon...
# 345  /storage/remote/atcremers50/ss21_multiagentcon...
# 338  /storage/remote/atcremers50/ss21_multiagentcon...
# 353  /storage/remote/atcremers50/ss21_multiagentcon...
# 373  /storage/remote/atcremers50/ss21_multiagentcon...
#
#                                        val_losses_path use_edges_attr  \
# 374  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 375  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 367  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 377  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 381  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 380  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 376  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 382  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 370  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 372  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 366  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 378  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 383  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 379  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 369  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 368  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 371  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 363  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 358  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 364  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 354  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 355  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 361  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 365  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 357  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 359  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 360  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 356  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 362  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 344  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 352  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 342  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 350  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 351  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 343  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 349  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 341  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 348  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 347  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 340  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 339  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 346  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 345  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 338  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 353  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 373  /storage/remote/atcremers50/ss21_multiagentcon...          False
#
#     activation_function                                              combo
# 374                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 375                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 367                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 377                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 381                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 380                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 376                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 382                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 370                tanh  (mean, 128, Adam, L1, [128, 256, 64], 0.001, 0...
# 372                tanh  (mean, 128, Adam, L1, [128, 256, 64], 0.001, 0...
# 366                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 378                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 383                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 379                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 369                tanh  (mean, 128, Adam, L1, [128, 256, 64], 0.001, 0...
# 368                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 371                tanh  (mean, 128, Adam, L1, [128, 256, 64], 0.001, 0...
# 363                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 358                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 364                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 354                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 355                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 361                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 365                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 357                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 359                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 360                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 356                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 362                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 344                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, None...
# 352                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, None...
# 342                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Cosi...
# 350                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Cosi...
# 351                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, None...
# 343                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, None...
# 349                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Cosi...
# 341                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Cosi...
# 348                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Redu...
# 347                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Redu...
# 340                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Redu...
# 339                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Redu...
# 346                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Mult...
# 345                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Mult...
# 338                tanh  (sum, 128, Adam, L1, [64], 0.01, 0.6, 0, Reduc...
# 353                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Mult...
# 373                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...

# %%
nan_indexes = df['final_val_loss'].index[df['final_val_loss'].apply(np.isnan)]
for idx in nan_indexes:
    print (df.loc[idx])
# Out:
# run_time                     17h55m10s
# model                          GCN_004
# random_seed                         42
# train_size                         0.9
# batch_size                         100
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 0, Length: 124, dtype: object
# run_time                     18h23m49s
# model                          GCN_004
# random_seed                         42
# train_size                         0.9
# batch_size                         100
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 1, Length: 124, dtype: object
# run_time                     19h08m29s
# model                          GCN_004
# random_seed                         42
# train_size                         0.9
# batch_size                         100
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 2, Length: 124, dtype: object
# run_time                     19h42m38s
# model                          GCN_005
# random_seed                         42
# train_size                         0.9
# batch_size                         100
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 3, Length: 124, dtype: object
# run_time                     20h00m36s
# model                          GCN_005
# random_seed                         42
# train_size                         0.9
# batch_size                          32
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 4, Length: 124, dtype: object
# run_time                     20h14m31s
# model                          GCN_005
# random_seed                         42
# train_size                         0.9
# batch_size                          32
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 5, Length: 124, dtype: object
# run_time                     20h32m49s
# model                          GCN_005
# random_seed                         42
# train_size                         0.9
# batch_size                          64
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 6, Length: 124, dtype: object
# run_time                     17h07m46s
# model                          GCN_011
# random_seed                     457362
# train_size                         0.9
# batch_size                         256
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 149, Length: 124, dtype: object
# run_time                     17h11m49s
# model                          GCN_011
# random_seed                     457362
# train_size                         0.9
# batch_size                         256
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 150, Length: 124, dtype: object
# run_time                     17h26m31s
# model                          GCN_011
# random_seed                     457362
# train_size                         0.9
# batch_size                         512
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 155, Length: 124, dtype: object
# run_time                     17h29m24s
# model                          GCN_011
# random_seed                     457362
# train_size                         0.9
# batch_size                         512
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 156, Length: 124, dtype: object
# run_time                     21h12m45s
# model                          GCN_013
# random_seed                         42
# train_size                         0.9
# batch_size                         512
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 317, Length: 124, dtype: object
# run_time                     10h11m43s
# model                          GCN_013
# random_seed                         42
# train_size                         0.9
# batch_size                         512
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 319, Length: 124, dtype: object
# run_time                     11h04m50s
# model                          GCN_013
# random_seed                         42
# train_size                         0.9
# batch_size                         512
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 337, Length: 124, dtype: object
# run_time                     16h31m25s
# model                          GCN_014
# random_seed                         42
# train_size                         0.9
# batch_size                         128
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 353, Length: 124, dtype: object
# run_time                     08h18m52s
# model                          GCN_014
# random_seed                      42314
# train_size                         0.9
# batch_size                         512
#                                ...
# Nepochs_008                        NaN
# epoch9000_train_loss               NaN
# epoch9000_final_val_loss           NaN
# epoch10000_train_loss              NaN
# epoch10000_final_val_loss          NaN
# Name: 373, Length: 124, dtype: object

# %%
# correct incomplete training n 367 at 22h36m37s, stopped at 6000
epoch = 6000
col_to_correct = "final_val_loss"
right_col = f"epoch{epoch}_final_val_loss"
df_top.loc[367,col_to_correct] = df.loc[367,right_col]

df_top.loc[373,col_to_correct] = df.loc[373,"epoch7000_final_val_loss"]
df_top.loc[373,"final_train_loss"] = df.loc[373,"epoch7000_train_loss"]
df_top.sort_values(by=['final_val_loss'])#.loc[367]
# Out:
#       run_date   run_time    model  Nepochs  batch_size  \
# 373  20210724-  08h18m52s  GCN_014    20000         512
# 374  20210725-  00h41m56s  GCN_014     5000         512
# 375  20210725-  13h51m08s  GCN_014     5000         512
# 367  20210723-  22h36m37s  GCN_014    20000         512
# 377  20210725-  16h38m02s  GCN_014     5000         512
# 381  20210725-  16h51m01s  GCN_014     5000         512
# 380  20210725-  16h48m09s  GCN_014     5000         512
# 376  20210725-  16h34m34s  GCN_014     5000         512
# 382  20210725-  16h53m11s  GCN_014     5000         512
# 370  20210724-  08h01m46s  GCN_014     5000         128
# 372  20210724-  08h06m15s  GCN_014     5000         128
# 366  20210723-  19h36m28s  GCN_014     5000         128
# 378  20210725-  16h40m10s  GCN_014     5000         512
# 383  20210725-  16h59m01s  GCN_014     5000         512
# 379  20210725-  16h45m59s  GCN_014     5000         512
# 369  20210724-  07h59m18s  GCN_014     5000         128
# 368  20210723-  22h44m02s  GCN_014     5000         128
# 371  20210724-  08h04m02s  GCN_014     5000         128
# 363  20210723-  19h22m42s  GCN_014        5           1
# 358  20210723-  18h48m52s  GCN_014        5           1
# 364  20210723-  19h23m23s  GCN_014        5           1
# 354  20210723-  18h45m06s  GCN_014        5         128
# 355  20210723-  18h45m14s  GCN_014        5         128
# 361  20210723-  19h09m02s  GCN_014        5           1
# 365  20210723-  19h24m03s  GCN_014        5           1
# 357  20210723-  18h48m11s  GCN_014        5           1
# 359  20210723-  18h49m31s  GCN_014        5           1
# 360  20210723-  19h08m21s  GCN_014        5           1
# 356  20210723-  18h45m20s  GCN_014        5         128
# 362  20210723-  19h09m43s  GCN_014        5           1
# 344  20210723-  16h04m35s  GCN_014     5000         128
# 352  20210723-  16h30m06s  GCN_014     5000         128
# 342  20210723-  16h02m40s  GCN_014     5000         128
# 350  20210723-  16h27m17s  GCN_014     5000         128
# 351  20210723-  16h28m37s  GCN_014     5000         128
# 343  20210723-  16h03m37s  GCN_014     5000         128
# 349  20210723-  16h25m52s  GCN_014     5000         128
# 341  20210723-  16h01m42s  GCN_014     5000         128
# 348  20210723-  16h24m33s  GCN_014     5000         128
# 347  20210723-  16h23m09s  GCN_014     5000         128
# 340  20210723-  16h00m45s  GCN_014     5000         128
# 339  20210723-  15h59m43s  GCN_014     5000         128
# 346  20210723-  16h06m30s  GCN_014     5000         128
# 345  20210723-  16h05m32s  GCN_014     5000         128
# 338  20210723-  14h28m01s  GCN_014     5000         128
# 353  20210723-  16h31m25s  GCN_014     5000         128
#
#                                     model_architecture  num_rows_training  \
# 373  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...              22478
# 374  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...              22478
# 375  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...             105883
# 367  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...              22478
# 377  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                146
# 381  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                146
# 380  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...                146
# 376  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...                146
# 382  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...                146
# 370  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                127
# 372  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                127
# 366  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 378  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 128...                146
# 383  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                146
# 379  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                146
# 369  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                127
# 368  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 371  GCN_HL03_bn_tanh(\n  (conv1): GraphConv(6, 128...                127
# 363  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 358  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 364  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 354  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 355  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 361  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 365  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 357  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 359  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 360  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 356  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 362  GCN_HL03_bn_relu(\n  (conv1): GraphConv(6, 64)...                127
# 344  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 352  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 342  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 350  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 351  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 343  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 349  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 341  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 348  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 347  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 340  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 339  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 346  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 345  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
# 338  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...              10588
# 353  GCN_HL01_bn_tanh(\n  (conv1): GraphConv(6, 64)...                127
#
#     criterion                                          optimizer  \
# 373  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 374  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 375  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 367  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 377  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 381  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 380  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 376  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 382  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 370  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 372  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 366  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 378  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 383  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 379  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 369  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 368  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 371  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 363  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 358  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 364  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 354  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 355  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 361  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 365  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 357  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 359  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 360  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 356  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 362  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 344  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 352  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 342  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 350  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 351  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 343  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 349  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 341  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 348  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 347  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 340  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 339  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 346  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 345  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 338  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
# 353  L1Loss()  Adam (\nParameter Group 0\n    amsgrad: False\...
#
#                        scheduler  final_train_loss  final_val_loss  \
# 373  CosineAnnealingWarmRestarts          0.089546        0.119161
# 374  CosineAnnealingWarmRestarts          0.103252        0.179579
# 375  CosineAnnealingWarmRestarts          0.177611        0.197008
# 367                     NoneType          0.124258        0.495298
# 377  CosineAnnealingWarmRestarts          0.806616        1.973811
# 381                     NoneType          0.242757        2.012705
# 380                     NoneType          0.146398        2.045143
# 376  CosineAnnealingWarmRestarts          0.282124        2.067297
# 382                     NoneType          0.333207        2.402230
# 370  CosineAnnealingWarmRestarts          0.816534        2.516336
# 372                     NoneType          0.294851        2.726004
# 366  CosineAnnealingWarmRestarts          1.490443        2.873843
# 378  CosineAnnealingWarmRestarts          0.974617        3.193087
# 383                     NoneType          1.295042        3.211135
# 379  CosineAnnealingWarmRestarts          2.336663        3.262593
# 369  CosineAnnealingWarmRestarts          2.719573        4.072335
# 368                     NoneType          0.923467        4.650014
# 371                     NoneType          1.495942        5.180782
# 363  CosineAnnealingWarmRestarts         10.435364       13.148211
# 358                     NoneType         10.522602       13.409588
# 364                     NoneType         10.404019       13.607946
# 354  CosineAnnealingWarmRestarts         11.002303       13.771930
# 355                     NoneType         10.946132       13.988120
# 361                     NoneType         10.513580       14.256391
# 365                     NoneType         10.418518       14.269820
# 357  CosineAnnealingWarmRestarts         10.495321       14.402861
# 359                     NoneType         10.472254       14.425552
# 360  CosineAnnealingWarmRestarts         10.405718       14.452155
# 356                     NoneType         10.946132       14.532098
# 362                     NoneType         10.413995       15.083491
# 344                     NoneType       3236.903809      594.665405
# 352                     NoneType       3209.781006      684.326355
# 342  CosineAnnealingWarmRestarts       4870.933105      754.521484
# 350  CosineAnnealingWarmRestarts       4981.092285      760.006104
# 351                     NoneType       4915.426270      894.899780
# 343                     NoneType       4875.875488      993.423767
# 349  CosineAnnealingWarmRestarts       6855.289062     1057.868530
# 341  CosineAnnealingWarmRestarts       6916.051758     1066.461670
# 348            ReduceLROnPlateau       8653.780273     1103.817261
# 347            ReduceLROnPlateau       8838.965820     1112.163696
# 340            ReduceLROnPlateau       8661.816406     1124.254639
# 339            ReduceLROnPlateau       8853.123047     1261.532959
# 346                  MultiStepLR      11033.661133     1338.555908
# 345                  MultiStepLR      11670.248047     1435.495361
# 338            ReduceLROnPlateau       2259.217123     2309.631985
# 353                  MultiStepLR               NaN             NaN
#
#                                      train_losses_path  \
# 373  /storage/remote/atcremers50/ss21_multiagentcon...
# 374  /storage/remote/atcremers50/ss21_multiagentcon...
# 375  /storage/remote/atcremers50/ss21_multiagentcon...
# 367  /storage/remote/atcremers50/ss21_multiagentcon...
# 377  /storage/remote/atcremers50/ss21_multiagentcon...
# 381  /storage/remote/atcremers50/ss21_multiagentcon...
# 380  /storage/remote/atcremers50/ss21_multiagentcon...
# 376  /storage/remote/atcremers50/ss21_multiagentcon...
# 382  /storage/remote/atcremers50/ss21_multiagentcon...
# 370  /storage/remote/atcremers50/ss21_multiagentcon...
# 372  /storage/remote/atcremers50/ss21_multiagentcon...
# 366  /storage/remote/atcremers50/ss21_multiagentcon...
# 378  /storage/remote/atcremers50/ss21_multiagentcon...
# 383  /storage/remote/atcremers50/ss21_multiagentcon...
# 379  /storage/remote/atcremers50/ss21_multiagentcon...
# 369  /storage/remote/atcremers50/ss21_multiagentcon...
# 368  /storage/remote/atcremers50/ss21_multiagentcon...
# 371  /storage/remote/atcremers50/ss21_multiagentcon...
# 363  /storage/remote/atcremers50/ss21_multiagentcon...
# 358  /storage/remote/atcremers50/ss21_multiagentcon...
# 364  /storage/remote/atcremers50/ss21_multiagentcon...
# 354  /storage/remote/atcremers50/ss21_multiagentcon...
# 355  /storage/remote/atcremers50/ss21_multiagentcon...
# 361  /storage/remote/atcremers50/ss21_multiagentcon...
# 365  /storage/remote/atcremers50/ss21_multiagentcon...
# 357  /storage/remote/atcremers50/ss21_multiagentcon...
# 359  /storage/remote/atcremers50/ss21_multiagentcon...
# 360  /storage/remote/atcremers50/ss21_multiagentcon...
# 356  /storage/remote/atcremers50/ss21_multiagentcon...
# 362  /storage/remote/atcremers50/ss21_multiagentcon...
# 344  /storage/remote/atcremers50/ss21_multiagentcon...
# 352  /storage/remote/atcremers50/ss21_multiagentcon...
# 342  /storage/remote/atcremers50/ss21_multiagentcon...
# 350  /storage/remote/atcremers50/ss21_multiagentcon...
# 351  /storage/remote/atcremers50/ss21_multiagentcon...
# 343  /storage/remote/atcremers50/ss21_multiagentcon...
# 349  /storage/remote/atcremers50/ss21_multiagentcon...
# 341  /storage/remote/atcremers50/ss21_multiagentcon...
# 348  /storage/remote/atcremers50/ss21_multiagentcon...
# 347  /storage/remote/atcremers50/ss21_multiagentcon...
# 340  /storage/remote/atcremers50/ss21_multiagentcon...
# 339  /storage/remote/atcremers50/ss21_multiagentcon...
# 346  /storage/remote/atcremers50/ss21_multiagentcon...
# 345  /storage/remote/atcremers50/ss21_multiagentcon...
# 338  /storage/remote/atcremers50/ss21_multiagentcon...
# 353  /storage/remote/atcremers50/ss21_multiagentcon...
#
#                                        val_losses_path use_edges_attr  \
# 373  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 374  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 375  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 367  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 377  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 381  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 380  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 376  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 382  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 370  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 372  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 366  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 378  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 383  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 379  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 369  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 368  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 371  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 363  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 358  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 364  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 354  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 355  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 361  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 365  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 357  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 359  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 360  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 356  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 362  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 344  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 352  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 342  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 350  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 351  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 343  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 349  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 341  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 348  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 347  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 340  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 339  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 346  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 345  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 338  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 353  /storage/remote/atcremers50/ss21_multiagentcon...           True
#
#     activation_function                                              combo
# 373                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 374                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 375                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 367                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 377                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 381                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 380                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 376                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 382                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 370                tanh  (mean, 128, Adam, L1, [128, 256, 64], 0.001, 0...
# 372                tanh  (mean, 128, Adam, L1, [128, 256, 64], 0.001, 0...
# 366                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 378                relu  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 383                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 379                tanh  (mean, 512, Adam, L1, [128, 256, 64], 0.001, 0...
# 369                tanh  (mean, 128, Adam, L1, [128, 256, 64], 0.001, 0...
# 368                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 371                tanh  (mean, 128, Adam, L1, [128, 256, 64], 0.001, 0...
# 363                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 358                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 364                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 354                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 355                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 361                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 365                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 357                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 359                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 360                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 356                relu  (mean, 128, Adam, L1, [64, 128, 256], 0.001, 0...
# 362                relu  (mean, 1, Adam, L1, [64, 128, 256], 0.001, 0.6...
# 344                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, None...
# 352                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, None...
# 342                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Cosi...
# 350                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Cosi...
# 351                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, None...
# 343                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, None...
# 349                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Cosi...
# 341                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Cosi...
# 348                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Redu...
# 347                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Redu...
# 340                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Redu...
# 339                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Redu...
# 346                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Mult...
# 345                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Mult...
# 338                tanh  (sum, 128, Adam, L1, [64], 0.01, 0.6, 0, Reduc...
# 353                tanh  (sum, 128, Adam, L1, [64], 0.001, 0.6, 0, Mult...

# %%
best_k = df_top.iloc[0].run_time

# %%
t_losses = {}
TOP = 6
for r in df_top.index[:TOP]:
    t_loss_path = df_top.loc[r]['train_losses_path']
    model_details = df_top.loc[r]
    t_loss_load = pkl.load(open(t_loss_path, 'rb'))
    t_losses[r] = (t_loss_load, model_details.to_dict())
v_losses = {}
for r in df_top.index[:TOP]:
    v_loss_path = df_top.loc[r]['val_losses_path']
    model_details = df_top.loc[r]
    v_loss_load = pkl.load(open(v_loss_path, 'rb'))
    v_losses[r] = (v_loss_load, model_details.to_dict())
fig = compare_losses(
                   t_losses,
                   title_1 = "losses_training",
                   columns = ["run_time","batch_size"],
                     
                   #losses_dict_2 = v_losses,
                   #title_2 = "losses_validation",
                   #columns_2 = ["model","scheduler"],
                   gaussian=True,
                   sigma=2,
                   figsize=(20, 8),
                ) 

fig = compare_losses(
                   v_losses,
                   title_1 = "losses_validation",
                   columns = ["scheduler",'use_edges_attr', "activation_function"],
                     
                   #losses_dict_2 = v_losses,
                   #title_2 = "losses_validation",
                   #columns_2 = ["model","scheduler"],
                   gaussian=True,
                   sigma=2,
                   figsize=(20, 8),
                )
# Out:
# Comparing 6 models
# possible keys to choose from:
# : ['run_date', 'run_time', 'model', 'Nepochs', 'batch_size', 'model_architecture', 'num_rows_training', 'criterion', 'optimizer', 'scheduler', 'final_train_loss', 'final_val_loss', 'train_losses_path', 'val_losses_path', 'use_edges_attr', 'activation_function', 'combo']
# min_len=500
# not all lists of losses have same length!
# they will be plotted according to the minimal length 500
# Comparing 6 models
# possible keys to choose from:
# : ['run_date', 'run_time', 'model', 'Nepochs', 'batch_size', 'model_architecture', 'num_rows_training', 'criterion', 'optimizer', 'scheduler', 'final_train_loss', 'final_val_loss', 'train_losses_path', 'val_losses_path', 'use_edges_attr', 'activation_function', 'combo']
# min_len=500
# not all lists of losses have same length!
# they will be plotted according to the minimal length 500

# %%
mask = df.run_time == best_k
print ("-"*80)
print (f"\n {best_k}\n")
print (dict(df[mask]['optimizer']))

architecture = dict(df[mask]['model_architecture'])
print (architecture)
#first_key = list(architecture.keys())[0]
#str(type(architecture[first_key]))[:]
#print (df[mask].T)
# Out:
# --------------------------------------------------------------------------------
#
#  00h41m56s
#
# {374: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.0007077075065009428
#     weight_decay: 0
# )}
# {374: GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )}

# %% [markdown]
# ## details of all models

# %%
all_t_losses = {}
for r in df_top.index[:]:
    t_loss_path = df_top.loc[r]['train_losses_path']
    model_details = df_top.loc[r]
    t_loss_load = pkl.load(open(t_loss_path, 'rb'))
    all_t_losses[r] = (t_loss_load, model_details.to_dict())

for v in all_t_losses.values():
    k = v[1]['run_time']
    mask = df.run_time == k #"16h45m18s"
    print ("-"*80)
    print (f"\n>{k}")
    print (f"final training: {df[mask]['final_train_loss'].values}") 
    print (f"final validation: {df[mask]['final_val_loss'].values}\n ")
    
    print (list(df[mask]['batch_size']))
    print (list(df[mask]['scheduler']))
    print (list(df[mask]['optimizer']))
    print (list(df[mask]['model_architecture']))
# Out:
# --------------------------------------------------------------------------------
#
# >00h41m56s
# final training: [0.10325195]
# final validation: [0.17957926]
#
# [512]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.0007077075065009428
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]
# --------------------------------------------------------------------------------
#
# >13h51m08s
# final training: [0.1776114]
# final validation: [0.19700797]
#
# [512]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.0008628177469378995
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]
# --------------------------------------------------------------------------------
#
# >22h36m37s
# final training: [0.12425794]
# final validation: [0.28067923]
#
# [512]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.0008274303669726671
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): GraphNorm(64)
#   (bn2): GraphNorm(128)
#   (bn3): GraphNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >16h38m02s
# final training: [0.80661601]
# final validation: [1.97381079]
#
# [512]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_tanh(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]
# --------------------------------------------------------------------------------
#
# >16h51m01s
# final training: [0.24275713]
# final validation: [2.01270485]
#
# [512]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_tanh(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]
# --------------------------------------------------------------------------------
#
# >16h48m09s
# final training: [0.14639792]
# final validation: [2.04514337]
#
# [512]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]
# --------------------------------------------------------------------------------
#
# >16h34m34s
# final training: [0.28212357]
# final validation: [2.06729674]
#
# [512]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]
# --------------------------------------------------------------------------------
#
# >16h53m11s
# final training: [0.33320689]
# final validation: [2.40222955]
#
# [512]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]
# --------------------------------------------------------------------------------
#
# >08h01m46s
# final training: [0.81653428]
# final validation: [2.51633573]
#
# [128]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_tanh(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]
# --------------------------------------------------------------------------------
#
# >08h06m15s
# final training: [0.29485065]
# final validation: [2.72600365]
#
# [128]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_tanh(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]
# --------------------------------------------------------------------------------
#
# >19h36m28s
# final training: [1.49044275]
# final validation: [2.87384343]
#
# [128]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): BatchNorm(64)
#   (bn2): BatchNorm(128)
#   (bn3): BatchNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >16h40m10s
# final training: [0.97461748]
# final validation: [3.19308734]
#
# [512]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]
# --------------------------------------------------------------------------------
#
# >16h59m01s
# final training: [1.29504228]
# final validation: [3.21113467]
#
# [512]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_tanh(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]
# --------------------------------------------------------------------------------
#
# >16h45m59s
# final training: [2.33666301]
# final validation: [3.26259255]
#
# [512]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_tanh(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]
# --------------------------------------------------------------------------------
#
# >07h59m18s
# final training: [2.71957254]
# final validation: [4.07233477]
#
# [128]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_tanh(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]
# --------------------------------------------------------------------------------
#
# >22h44m02s
# final training: [0.9234668]
# final validation: [4.65001392]
#
# [128]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): GraphNorm(64)
#   (bn2): GraphNorm(128)
#   (bn3): GraphNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >08h04m02s
# final training: [1.49594164]
# final validation: [5.18078184]
#
# [128]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_tanh(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]
# --------------------------------------------------------------------------------
#
# >19h22m42s
# final training: [10.43536443]
# final validation: [13.14821137]
#
# [1]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.0009999617556940084
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): BatchNorm(64)
#   (bn2): BatchNorm(128)
#   (bn3): BatchNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >18h48m52s
# final training: [10.52260201]
# final validation: [13.40958826]
#
# [1]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): BatchNorm(64)
#   (bn2): BatchNorm(128)
#   (bn3): BatchNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >19h23m23s
# final training: [10.40401883]
# final validation: [13.60794559]
#
# [1]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): BatchNorm(64)
#   (bn2): BatchNorm(128)
#   (bn3): BatchNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >18h45m06s
# final training: [11.00230312]
# final validation: [13.77192974]
#
# [128]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.0005
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): BatchNorm(64)
#   (bn2): BatchNorm(128)
#   (bn3): BatchNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >18h45m14s
# final training: [10.94613171]
# final validation: [13.98812008]
#
# [128]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): BatchNorm(64)
#   (bn2): BatchNorm(128)
#   (bn3): BatchNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >19h09m02s
# final training: [10.51357982]
# final validation: [14.25639138]
#
# [1]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): BatchNorm(64)
#   (bn2): BatchNorm(128)
#   (bn3): BatchNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >19h24m03s
# final training: [10.41851842]
# final validation: [14.26982025]
#
# [1]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): BatchNorm(64)
#   (bn2): BatchNorm(128)
#   (bn3): BatchNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >18h48m11s
# final training: [10.4953207]
# final validation: [14.4028613]
#
# [1]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.0009999617556940084
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): BatchNorm(64)
#   (bn2): BatchNorm(128)
#   (bn3): BatchNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >18h49m31s
# final training: [10.4722537]
# final validation: [14.42555193]
#
# [1]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): BatchNorm(64)
#   (bn2): BatchNorm(128)
#   (bn3): BatchNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >19h08m21s
# final training: [10.40571817]
# final validation: [14.45215486]
#
# [1]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.0009999617556940084
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): BatchNorm(64)
#   (bn2): BatchNorm(128)
#   (bn3): BatchNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >18h45m20s
# final training: [10.94613171]
# final validation: [14.53209782]
#
# [128]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): BatchNorm(64)
#   (bn2): BatchNorm(128)
#   (bn3): BatchNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >19h09m43s
# final training: [10.41399516]
# final validation: [15.08349103]
#
# [1]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): BatchNorm(64)
#   (bn2): BatchNorm(128)
#   (bn3): BatchNorm(256)
# )]
# --------------------------------------------------------------------------------
#
# >16h04m35s
# final training: [3236.90380859]
# final validation: [594.66540527]
#
# [128]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >16h30m06s
# final training: [3209.78100586]
# final validation: [684.32635498]
#
# [128]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >16h02m40s
# final training: [4870.93310547]
# final validation: [754.52148438]
#
# [128]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >16h27m17s
# final training: [4981.09228516]
# final validation: [760.00610352]
#
# [128]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >16h28m37s
# final training: [4915.42626953]
# final validation: [894.89978027]
#
# [128]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >16h03m37s
# final training: [4875.87548828]
# final validation: [993.42376709]
#
# [128]
# ['NoneType']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >16h25m52s
# final training: [6855.2890625]
# final validation: [1057.86853027]
#
# [128]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >16h01m42s
# final training: [6916.05175781]
# final validation: [1066.46166992]
#
# [128]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.001
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >16h24m33s
# final training: [8653.78027344]
# final validation: [1103.81726074]
#
# [128]
# ['ReduceLROnPlateau']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 1.0000000000000001e-11
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >16h23m09s
# final training: [8838.96582031]
# final validation: [1112.16369629]
#
# [128]
# ['ReduceLROnPlateau']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 1.0000000000000001e-11
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >16h00m45s
# final training: [8661.81640625]
# final validation: [1124.25463867]
#
# [128]
# ['ReduceLROnPlateau']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 1.0000000000000001e-11
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >15h59m43s
# final training: [8853.12304688]
# final validation: [1261.53295898]
#
# [128]
# ['ReduceLROnPlateau']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 1.0000000000000001e-11
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >16h06m30s
# final training: [11033.66113281]
# final validation: [1338.5559082]
#
# [128]
# ['MultiStepLR']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 1.0000000000000006e-12
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >16h05m32s
# final training: [11670.24804688]
# final validation: [1435.49536133]
#
# [128]
# ['MultiStepLR']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 1.0000000000000006e-12
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >14h28m01s
# final training: [2259.21712338]
# final validation: [2309.63198513]
#
# [128]
# ['ReduceLROnPlateau']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 1e-08
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >16h31m25s
# final training: [nan]
# final validation: [nan]
#
# [128]
# ['MultiStepLR']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 1.0000000000000004e-08
#     weight_decay: 0
# )]
# [GCN_HL01_bn_tanh(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 2)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )]
# --------------------------------------------------------------------------------
#
# >08h18m52s
# final training: [nan]
# final validation: [nan]
#
# [512]
# ['CosineAnnealingWarmRestarts']
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 2.025351319275115e-05
#     weight_decay: 0
# )]
# [GCN_HL03_bn_tanh(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )]

# %% [markdown]
# ## details of best models

# %%
list(t_losses.keys())
# Out:
# [374, 375, 367, 377, 381, 380]

# %%
best_combos = {}
for v in t_losses.values():
    k = v[1]['run_time']

    mask = df.run_time == k #"16h45m18s"
    print ("-"*80)
    date = df[mask]['run_date'].values[0]
    print (f"\n>{date}{k}")
    print (f"N epochs: {df[mask]['Nepochs'].values[0]}")
    print (f"num_rows_training: {df[mask]['num_rows_training'].values}") 
    print (f"final training: {df[mask]['final_train_loss'].values}") 
    print (f"final validation: {df[mask]['final_val_loss'].values}\n ")
    
    
    additional_info = {column:df[mask][column].values[0] 
                       for column in list(df.columns)} 
    
    combo =  df[mask]['combo'].values[0]
    combo = [e for e in combo]
    print (combo)
    best_combos[f"{date}{k}"] = [combo,additional_info]
# Out:
# --------------------------------------------------------------------------------
#
# >20210725-00h41m56s
# N epochs: 5000
# num_rows_training: [22478]
# final training: [0.10325195]
# final validation: [0.17957926]
#
# ['mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'CosineAnnealingWarmRestarts', False, 'relu']
# --------------------------------------------------------------------------------
#
# >20210725-13h51m08s
# N epochs: 5000
# num_rows_training: [105883]
# final training: [0.1776114]
# final validation: [0.19700797]
#
# ['mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'CosineAnnealingWarmRestarts', False, 'relu']
# --------------------------------------------------------------------------------
#
# >20210723-22h36m37s
# N epochs: 20000
# num_rows_training: [22478]
# final training: [0.12425794]
# final validation: [0.28067923]
#
# ['mean', 128, 'Adam', 'L1', [64, 128, 256], 0.001, 0.6, 0, 'CosineAnnealingWarmRestarts', True, 'relu']
# --------------------------------------------------------------------------------
#
# >20210725-16h38m02s
# N epochs: 5000
# num_rows_training: [146]
# final training: [0.80661601]
# final validation: [1.97381079]
#
# ['mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'CosineAnnealingWarmRestarts', False, 'tanh']
# --------------------------------------------------------------------------------
#
# >20210725-16h51m01s
# N epochs: 5000
# num_rows_training: [146]
# final training: [0.24275713]
# final validation: [2.01270485]
#
# ['mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'None', False, 'tanh']
# --------------------------------------------------------------------------------
#
# >20210725-16h48m09s
# N epochs: 5000
# num_rows_training: [146]
# final training: [0.14639792]
# final validation: [2.04514337]
#
# ['mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'None', False, 'relu']

# %%
#best_combos
#MODEL_PATH

#description = f"{this_date}{ts}"
dict_best_combos_descr = f"{GCN_MODEL}_best_combos"
dict_best_combos_path = os.path.join(MODEL_PATH,dict_best_combos_descr)

# store parameters as a pickle
with open(f'{dict_best_combos_path}.pkl', 'wb') as handle:
    pkl.dump(best_combos, handle, protocol=pkl.HIGHEST_PROTOCOL)

print (dict_best_combos_path)
# Out:
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/GCN_014_best_combos

# %%
# reload combos

reloaded_best_combos = pkl.load(open(f'{dict_best_combos_path}.pkl',"rb"))
for k,v in reloaded_best_combos.items():
    print ()
    print (v[0])
    print ()
    for kk,vv in v[1].items():
        print (f"{kk}:{vv}")
    #print (v[1])
# Out:
# ['mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'CosineAnnealingWarmRestarts', False, 'relu']
#
# run_time:00h41m56s
# model:GCN_014
# random_seed:42
# train_size:0.9
# batch_size:512
# Nepochs:5000
# save_every:250
# transformstat:False
# plotstat:True
# printstat:False
# input_file_name:20210711-17h59m44s_timesteps30000_ec3500_em7000
# num_rows_training:22478
# num_rows_validation:2248
# num_rows_test:250
# exclude_yaw:obsoleted
# concatenatestat:obsoleted
# paddingstat:obsoleted
# size_input:6
# size_output:3
# model_architecture:GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )
# tloss_path:nan
# criterion:L1Loss()
# optimizer:Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.0007077075065009428
#     weight_decay: 0
# )
# final_loss:nan
# train:nan
# val:nan
# lr:nan
# final_train_loss:0.10325195301662791
# final_val_loss:0.17957926094532012
# intentionstat:obsoleted
# model_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/20210725-00h41m56sEPOCH_5000of5000_FINAL__GCN_014.pt
# train_losses_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/20210725-00h41m56sEPOCH_5000of5000_FINAL__FINAL__training_loss.pkl
# val_losses_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/20210725-00h41m56sEPOCH_5000of5000_FINAL__FINAL__validation_loss.pkl
# lr_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/20210725-00h41m56sEPOCH_5000of5000_FINAL__FINAL__learning_rate.pkl
# max_num_veh:10.0
# sim_duration_timesteps:30000
# figure_paths:['/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_training_set/20210725-00h41m56sModel_GCN_014_shuttle_train_epoch_000250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_validation_set/20210725-00h41m56sModel_GCN_014_shuttle_val_epoch_000250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_training_set/20210725-00h41m56sModel_GCN_014_shuttle_train_epoch_000500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_validation_set/20210725-00h41m56sModel_GCN_014_shuttle_val_epoch_000500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_training_set/20210725-00h41m56sModel_GCN_014_shuttle_train_epoch_000750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_validation_set/20210725-00h41m56sModel_GCN_014_shuttle_val_epoch_000750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_training_set/20210725-00h41m56sModel_GCN_014_shuttle_train_epoch_001000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_validation_set/20210725-00h41m56sModel_GCN_014_shuttle_val_epoch_001000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_training_set/20210725-00h41m56sModel_GCN_014_shuttle_train_epoch_001250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_validation_set/20210725-00h41m56sModel_GCN_014_shuttle_val_epoch_001250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_training_set/20210725-00h41m56sModel_GCN_014_shuttle_train_epoch_001500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_validation_set/20210725-00h41m56sModel_GCN_014_shuttle_val_epoch_001500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_training_set/20210725-00h41m56sModel_GCN_014_shuttle_train_epoch_001750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_validation_set/20210725-00h41m56sModel_GCN_014_shuttle_val_epoch_001750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_training_set/20210725-00h41m56sModel_GCN_014_shuttle_train_epoch_002000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_validation_set/20210725-00h41m56sModel_GCN_014_shuttle_val_epoch_002000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_training_set/20210725-00h41m56sModel_GCN_014_shuttle_train_epoch_002250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_validation_set/20210725-00h41m56sModel_GCN_014_shuttle_val_epoch_002250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_training_set/20210725-00h41m56sModel_GCN_014_shuttle_train_epoch_002500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_validation_set/20210725-00h41m56sModel_GCN_014_shuttle_val_epoch_002500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-00h41m56s/figures_training_set/20210725-00h41m56sModel_GCN_014_shuttle_train_epoch_002750of5000.png', '/storage/remote/atcremers50/ss21_mult ...
# shuttle_train_frame:29845.0
# shuttle_val_frame:25744.0
# hidden_layers_sizes:[128, 256, 64]
# reduction:mean
# scheduler:CosineAnnealingWarmRestarts
# run_date:20210725-
# combo:('mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'CosineAnnealingWarmRestarts', False, 'relu')
# use_edges_attr:False
# activation_function:relu
# epoch14000_train_loss:nan
# epoch14000_final_val_loss:nan
# epoch28000_train_loss:nan
# epoch28000_final_val_loss:nan
# epoch2500_train_loss:nan
# epoch2500_final_val_loss:nan
# epoch5000_train_loss:nan
# epoch5000_final_val_loss:nan
# epoch4000_train_loss:nan
# epoch4000_final_val_loss:nan
# epoch8000_train_loss:nan
# epoch8000_final_val_loss:nan
# epoch12000_train_loss:nan
# epoch12000_final_val_loss:nan
# epoch16000_train_loss:nan
# epoch16000_final_val_loss:nan
# epoch20000_train_loss:nan
# epoch20000_final_val_loss:nan
# epoch1_train_loss:nan
# epoch1_final_val_loss:nan
# epoch2_train_loss:nan
# epoch2_final_val_loss:nan
# epoch3_train_loss:nan
# epoch3_final_val_loss:nan
# epoch4_train_loss:nan
# epoch4_final_val_loss:nan
# epoch5_train_loss:nan
# epoch5_final_val_loss:nan
# epoch500_train_loss:nan
# epoch500_final_val_loss:nan
# epoch1000_train_loss:nan
# epoch1000_final_val_loss:nan
# epoch1500_train_loss:nan
# epoch1500_final_val_loss:nan
# epoch2000_train_loss:nan
# epoch2000_final_val_loss:nan
# epoch3000_train_loss:nan
# epoch3000_final_val_loss:nan
# epoch3500_train_loss:nan
# epoch3500_final_val_loss:nan
# epoch4500_train_loss:nan
# epoch4500_final_val_loss:nan
# epoch6000_train_loss:nan
# epoch6000_final_val_loss:nan
# input_file_name_002:nan
# train_size_002:nan
# batch_size_002:nan
# Nepochs_002:nan
# epoch7000_train_loss:nan
# epoch7000_final_val_loss:nan
# input_file_name_003:nan
# train_size_003:nan
# batch_size_003:nan
# Nepochs_003:nan
# input_file_name_004:nan
# train_size_004:nan
# batch_size_004:nan
# Nepochs_004:nan
# input_file_name_005:nan
# train_size_005:nan
# batch_size_005:nan
# Nepochs_005:nan
# input_file_name_006:nan
# train_size_006:nan
# batch_size_006:nan
# Nepochs_006:nan
# input_file_name_007:nan
# train_size_007:nan
# batch_size_007:nan
# Nepochs_007:nan
# input_file_name_008:nan
# train_size_008:nan
# batch_size_008:nan
# Nepochs_008:nan
# epoch9000_train_loss:nan
# epoch9000_final_val_loss:nan
# epoch10000_train_loss:nan
# epoch10000_final_val_loss:nan
#
# ['mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'CosineAnnealingWarmRestarts', False, 'relu']
#
# run_time:13h51m08s
# model:GCN_014
# random_seed:42
# train_size:0.9
# batch_size:512
# Nepochs:5000
# save_every:250
# transformstat:False
# plotstat:True
# printstat:False
# input_file_name:20210724-19h49m31s_timesteps150000_ec3500_em7000
# num_rows_training:105883
# num_rows_validation:10588
# num_rows_test:1177
# exclude_yaw:obsoleted
# concatenatestat:obsoleted
# paddingstat:obsoleted
# size_input:6
# size_output:3
# model_architecture:GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )
# tloss_path:nan
# criterion:L1Loss()
# optimizer:Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.0008628177469378995
#     weight_decay: 0
# )
# final_loss:nan
# train:nan
# val:nan
# lr:nan
# final_train_loss:0.17761140442700776
# final_val_loss:0.19700796760263897
# intentionstat:obsoleted
# model_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-13h51m08s/20210725-13h51m08sEPOCH_500of5000_TEMP__GCN_014.pt
# train_losses_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-13h51m08s/20210725-13h51m08sEPOCH_500of5000_TEMP__TEMP__training_loss.pkl
# val_losses_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-13h51m08s/20210725-13h51m08sEPOCH_500of5000_TEMP__TEMP__validation_loss.pkl
# lr_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-13h51m08s/20210725-13h51m08sEPOCH_500of5000_TEMP__TEMP__learning_rate.pkl
# max_num_veh:10.0
# sim_duration_timesteps:150000
# figure_paths:nan
# shuttle_train_frame:83240.0
# shuttle_val_frame:132605.0
# hidden_layers_sizes:[128, 256, 64]
# reduction:mean
# scheduler:CosineAnnealingWarmRestarts
# run_date:20210725-
# combo:('mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'CosineAnnealingWarmRestarts', False, 'relu')
# use_edges_attr:False
# activation_function:relu
# epoch14000_train_loss:nan
# epoch14000_final_val_loss:nan
# epoch28000_train_loss:nan
# epoch28000_final_val_loss:nan
# epoch2500_train_loss:nan
# epoch2500_final_val_loss:nan
# epoch5000_train_loss:nan
# epoch5000_final_val_loss:nan
# epoch4000_train_loss:nan
# epoch4000_final_val_loss:nan
# epoch8000_train_loss:nan
# epoch8000_final_val_loss:nan
# epoch12000_train_loss:nan
# epoch12000_final_val_loss:nan
# epoch16000_train_loss:nan
# epoch16000_final_val_loss:nan
# epoch20000_train_loss:nan
# epoch20000_final_val_loss:nan
# epoch1_train_loss:nan
# epoch1_final_val_loss:nan
# epoch2_train_loss:nan
# epoch2_final_val_loss:nan
# epoch3_train_loss:nan
# epoch3_final_val_loss:nan
# epoch4_train_loss:nan
# epoch4_final_val_loss:nan
# epoch5_train_loss:nan
# epoch5_final_val_loss:nan
# epoch500_train_loss:nan
# epoch500_final_val_loss:nan
# epoch1000_train_loss:nan
# epoch1000_final_val_loss:nan
# epoch1500_train_loss:nan
# epoch1500_final_val_loss:nan
# epoch2000_train_loss:nan
# epoch2000_final_val_loss:nan
# epoch3000_train_loss:nan
# epoch3000_final_val_loss:nan
# epoch3500_train_loss:nan
# epoch3500_final_val_loss:nan
# epoch4500_train_loss:nan
# epoch4500_final_val_loss:nan
# epoch6000_train_loss:nan
# epoch6000_final_val_loss:nan
# input_file_name_002:nan
# train_size_002:nan
# batch_size_002:nan
# Nepochs_002:nan
# epoch7000_train_loss:nan
# epoch7000_final_val_loss:nan
# input_file_name_003:nan
# train_size_003:nan
# batch_size_003:nan
# Nepochs_003:nan
# input_file_name_004:nan
# train_size_004:nan
# batch_size_004:nan
# Nepochs_004:nan
# input_file_name_005:nan
# train_size_005:nan
# batch_size_005:nan
# Nepochs_005:nan
# input_file_name_006:nan
# train_size_006:nan
# batch_size_006:nan
# Nepochs_006:nan
# input_file_name_007:nan
# train_size_007:nan
# batch_size_007:nan
# Nepochs_007:nan
# input_file_name_008:nan
# train_size_008:nan
# batch_size_008:nan
# Nepochs_008:nan
# epoch9000_train_loss:nan
# epoch9000_final_val_loss:nan
# epoch10000_train_loss:nan
# epoch10000_final_val_loss:nan
#
# ['mean', 128, 'Adam', 'L1', [64, 128, 256], 0.001, 0.6, 0, 'CosineAnnealingWarmRestarts', True, 'relu']
# run_time:22h36m37s
# model:GCN_014
# random_seed:42
# train_size:0.9
# batch_size:512
# Nepochs:20000
# save_every:250
# transformstat:False
# plotstat:True
# printstat:False
# input_file_name:20210721-23h05m03s_timesteps90095_ec3500_em7000
# num_rows_training:22478
# num_rows_validation:2248
# num_rows_test:250
# exclude_yaw:obsoleted
# concatenatestat:obsoleted
# paddingstat:obsoleted
# size_input:6
# size_output:3
# model_architecture:GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 3)
#   (bn1): GraphNorm(64)
#   (bn2): GraphNorm(128)
#   (bn3): GraphNorm(256)
# )
# tloss_path:nan
# criterion:L1Loss()
# optimizer:Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.0008274303669726671
#     weight_decay: 0
# )
# final_loss:nan
# train:nan
# val:nan
# lr:nan
# final_train_loss:0.12425793605771931
# final_val_loss:0.28067922592163086
# intentionstat:obsoleted
# model_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/20210723-22h36m37sEPOCH_28750of30000_TEMP__GCN_014.pt
# train_losses_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/20210723-22h36m37sEPOCH_28750of30000_TEMP__TEMP__training_loss.pkl
# val_losses_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/20210723-22h36m37sEPOCH_28750of30000_TEMP__TEMP__validation_loss.pkl
# lr_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/20210723-22h36m37sEPOCH_28750of30000_TEMP__TEMP__learning_rate.pkl
# max_num_veh:10.0
# sim_duration_timesteps:30000
# figure_paths:['/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_training_set/20210723-22h36m37sModel_GCN_014_shuttle_train_epoch_006000of25000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210723-22h36m37s/figures_validation_set/20210723-22h36m37sModel_GCN_014_shuttle_val_epoch_006000of25000.png']
# shuttle_train_frame:nan
# shuttle_val_frame:nan
# hidden_layers_sizes:[64, 128, 256]
# reduction:mean
# scheduler:NoneType
# run_date:20210723-
# combo:('mean', 128, 'Adam', 'L1', [64, 128, 256], 0.001, 0.6, 0, 'CosineAnnealingWarmRestarts', True, 'relu')
# use_edges_attr:True
# activation_function:relu
# epoch14000_train_loss:nan
# epoch14000_final_val_loss:nan
# epoch28000_train_loss:nan
# epoch28000_final_val_loss:nan
# epoch2500_train_loss:nan
# epoch2500_final_val_loss:nan
# epoch5000_train_loss:nan
# epoch5000_final_val_loss:nan
# epoch4000_train_loss:nan
# epoch4000_final_val_loss:nan
# epoch8000_train_loss:nan
# epoch8000_final_val_loss:nan
# epoch12000_train_loss:nan
# epoch12000_final_val_loss:nan
# epoch16000_train_loss:nan
# epoch16000_final_val_loss:nan
# epoch20000_train_loss:nan
# epoch20000_final_val_loss:nan
# epoch1_train_loss:nan
# epoch1_final_val_loss:nan
# epoch2_train_loss:nan
# epoch2_final_val_loss:nan
# epoch3_train_loss:nan
# epoch3_final_val_loss:nan
# epoch4_train_loss:nan
# epoch4_final_val_loss:nan
# epoch5_train_loss:nan
# epoch5_final_val_loss:nan
# epoch500_train_loss:nan
# epoch500_final_val_loss:nan
# epoch1000_train_loss:nan
# epoch1000_final_val_loss:nan
# epoch1500_train_loss:nan
# epoch1500_final_val_loss:nan
# epoch2000_train_loss:nan
# epoch2000_final_val_loss:nan
# epoch3000_train_loss:nan
# epoch3000_final_val_loss:nan
# epoch3500_train_loss:nan
# epoch3500_final_val_loss:nan
# epoch4500_train_loss:nan
# epoch4500_final_val_loss:nan
# epoch6000_train_loss:0.31600431373940324
# epoch6000_final_val_loss:0.495297526771372
# input_file_name_002:20210711-17h59m44s_timesteps30000_ec3500_em7000
# train_size_002:0.9
# batch_size_002:1024.0
# Nepochs_002:5000.0
# epoch7000_train_loss:nan
# epoch7000_final_val_loss:nan
# input_file_name_003:nan
# train_size_003:nan
# batch_size_003:nan
# Nepochs_003:nan
# input_file_name_004:nan
# train_size_004:nan
# batch_size_004:nan
# Nepochs_004:nan
# input_file_name_005:nan
# train_size_005:nan
# batch_size_005:nan
# Nepochs_005:nan
# input_file_name_006:nan
# train_size_006:nan
# batch_size_006:nan
# Nepochs_006:nan
# input_file_name_007:nan
# train_size_007:nan
# batch_size_007:nan
# Nepochs_007:nan
# input_file_name_008:nan
# train_size_008:nan
# batch_size_008:nan
# Nepochs_008:nan
# epoch9000_train_loss:nan
# epoch9000_final_val_loss:nan
# epoch10000_train_loss:nan
# epoch10000_final_val_loss:nan
#
# ['mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'CosineAnnealingWarmRestarts', False, 'tanh']
#
# run_time:16h38m02s
# model:GCN_014
# random_seed:42
# train_size:0.9
# batch_size:512
# Nepochs:5000
# save_every:250
# transformstat:False
# plotstat:True
# printstat:False
# input_file_name:20210725-16h24m21s_timesteps200_ec3500_em7000
# num_rows_training:146
# num_rows_validation:15
# num_rows_test:2
# exclude_yaw:obsoleted
# concatenatestat:obsoleted
# paddingstat:obsoleted
# size_input:6
# size_output:3
# model_architecture:GCN_HL03_bn_tanh(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )
# tloss_path:nan
# criterion:L1Loss()
# optimizer:Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.001
#     weight_decay: 0
# )
# final_loss:nan
# train:nan
# val:nan
# lr:nan
# final_train_loss:0.8066160082817078
# final_val_loss:1.9738107919692993
# intentionstat:obsoleted
# model_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/20210725-16h38m02sEPOCH_5000of5000_FINAL__GCN_014.pt
# train_losses_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/20210725-16h38m02sEPOCH_5000of5000_FINAL__FINAL__training_loss.pkl
# val_losses_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/20210725-16h38m02sEPOCH_5000of5000_FINAL__FINAL__validation_loss.pkl
# lr_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/20210725-16h38m02sEPOCH_5000of5000_FINAL__FINAL__learning_rate.pkl
# max_num_veh:10.0
# sim_duration_timesteps:200
# figure_paths:['/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_training_set/20210725-16h38m02sModel_GCN_014_shuttle_train_epoch_000250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_validation_set/20210725-16h38m02sModel_GCN_014_shuttle_val_epoch_000250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_training_set/20210725-16h38m02sModel_GCN_014_shuttle_train_epoch_000500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_validation_set/20210725-16h38m02sModel_GCN_014_shuttle_val_epoch_000500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_training_set/20210725-16h38m02sModel_GCN_014_shuttle_train_epoch_000750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_validation_set/20210725-16h38m02sModel_GCN_014_shuttle_val_epoch_000750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_training_set/20210725-16h38m02sModel_GCN_014_shuttle_train_epoch_001000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_validation_set/20210725-16h38m02sModel_GCN_014_shuttle_val_epoch_001000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_training_set/20210725-16h38m02sModel_GCN_014_shuttle_train_epoch_001250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_validation_set/20210725-16h38m02sModel_GCN_014_shuttle_val_epoch_001250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_training_set/20210725-16h38m02sModel_GCN_014_shuttle_train_epoch_001500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_validation_set/20210725-16h38m02sModel_GCN_014_shuttle_val_epoch_001500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_training_set/20210725-16h38m02sModel_GCN_014_shuttle_train_epoch_001750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_validation_set/20210725-16h38m02sModel_GCN_014_shuttle_val_epoch_001750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_training_set/20210725-16h38m02sModel_GCN_014_shuttle_train_epoch_002000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_validation_set/20210725-16h38m02sModel_GCN_014_shuttle_val_epoch_002000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_training_set/20210725-16h38m02sModel_GCN_014_shuttle_train_epoch_002250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_validation_set/20210725-16h38m02sModel_GCN_014_shuttle_val_epoch_002250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_training_set/20210725-16h38m02sModel_GCN_014_shuttle_train_epoch_002500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_validation_set/20210725-16h38m02sModel_GCN_014_shuttle_val_epoch_002500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h38m02s/figures_training_set/20210725-16h38m02sModel_GCN_014_shuttle_train_epoch_002750of5000.png', '/storage/remote/atcremers50/ss21_mult ...
# shuttle_train_frame:21.0
# shuttle_val_frame:161.0
# hidden_layers_sizes:[128, 256, 64]
# reduction:mean
# scheduler:CosineAnnealingWarmRestarts
# run_date:20210725-
# combo:('mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'CosineAnnealingWarmRestarts', False, 'tanh')
# use_edges_attr:False
# activation_function:tanh
# epoch14000_train_loss:nan
# epoch14000_final_val_loss:nan
# epoch28000_train_loss:nan
# epoch28000_final_val_loss:nan
# epoch2500_train_loss:nan
# epoch2500_final_val_loss:nan
# epoch5000_train_loss:nan
# epoch5000_final_val_loss:nan
# epoch4000_train_loss:nan
# epoch4000_final_val_loss:nan
# epoch8000_train_loss:nan
# epoch8000_final_val_loss:nan
# epoch12000_train_loss:nan
# epoch12000_final_val_loss:nan
# epoch16000_train_loss:nan
# epoch16000_final_val_loss:nan
# epoch20000_train_loss:nan
# epoch20000_final_val_loss:nan
# epoch1_train_loss:nan
# epoch1_final_val_loss:nan
# epoch2_train_loss:nan
# epoch2_final_val_loss:nan
# epoch3_train_loss:nan
# epoch3_final_val_loss:nan
# epoch4_train_loss:nan
# epoch4_final_val_loss:nan
# epoch5_train_loss:nan
# epoch5_final_val_loss:nan
# epoch500_train_loss:nan
# epoch500_final_val_loss:nan
# epoch1000_train_loss:nan
# epoch1000_final_val_loss:nan
# epoch1500_train_loss:nan
# epoch1500_final_val_loss:nan
# epoch2000_train_loss:nan
# epoch2000_final_val_loss:nan
# epoch3000_train_loss:nan
# epoch3000_final_val_loss:nan
# epoch3500_train_loss:nan
# epoch3500_final_val_loss:nan
# epoch4500_train_loss:nan
# epoch4500_final_val_loss:nan
# epoch6000_train_loss:nan
# epoch6000_final_val_loss:nan
# input_file_name_002:20210725-16h24m21s_timesteps200_ec3500_em7000
# train_size_002:0.9
# batch_size_002:512.0
# Nepochs_002:5000.0
# epoch7000_train_loss:nan
# epoch7000_final_val_loss:nan
# input_file_name_003:nan
# train_size_003:nan
# batch_size_003:nan
# Nepochs_003:nan
# input_file_name_004:nan
# train_size_004:nan
# batch_size_004:nan
# Nepochs_004:nan
# input_file_name_005:nan
# train_size_005:nan
# batch_size_005:nan
# Nepochs_005:nan
# input_file_name_006:nan
# train_size_006:nan
# batch_size_006:nan
# Nepochs_006:nan
# input_file_name_007:nan
# train_size_007:nan
# batch_size_007:nan
# Nepochs_007:nan
# input_file_name_008:nan
# train_size_008:nan
# batch_size_008:nan
# Nepochs_008:nan
# epoch9000_train_loss:nan
# epoch9000_final_val_loss:nan
# epoch10000_train_loss:nan
# epoch10000_final_val_loss:nan
#
# ['mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'None', False, 'tanh']
#
# run_time:16h51m01s
# model:GCN_014
# random_seed:42
# train_size:0.9
# batch_size:512
# Nepochs:5000
# save_every:250
# transformstat:False
# plotstat:True
# printstat:False
# input_file_name:20210725-16h24m21s_timesteps200_ec3500_em7000
# num_rows_training:146
# num_rows_validation:15
# num_rows_test:2
# exclude_yaw:obsoleted
# concatenatestat:obsoleted
# paddingstat:obsoleted
# size_input:6
# size_output:3
# model_architecture:GCN_HL03_bn_tanh(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )
# tloss_path:nan
# criterion:L1Loss()
# optimizer:Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# final_loss:nan
# train:nan
# val:nan
# lr:nan
# final_train_loss:0.24275712668895721
# final_val_loss:2.012704849243164
# intentionstat:obsoleted
# model_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/20210725-16h51m01sEPOCH_5000of5000_FINAL__GCN_014.pt
# train_losses_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/20210725-16h51m01sEPOCH_5000of5000_FINAL__FINAL__training_loss.pkl
# val_losses_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/20210725-16h51m01sEPOCH_5000of5000_FINAL__FINAL__validation_loss.pkl
# lr_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/20210725-16h51m01sEPOCH_5000of5000_FINAL__FINAL__learning_rate.pkl
# max_num_veh:10.0
# sim_duration_timesteps:200
# figure_paths:['/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_training_set/20210725-16h51m01sModel_GCN_014_shuttle_train_epoch_000250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_validation_set/20210725-16h51m01sModel_GCN_014_shuttle_val_epoch_000250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_training_set/20210725-16h51m01sModel_GCN_014_shuttle_train_epoch_000500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_validation_set/20210725-16h51m01sModel_GCN_014_shuttle_val_epoch_000500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_training_set/20210725-16h51m01sModel_GCN_014_shuttle_train_epoch_000750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_validation_set/20210725-16h51m01sModel_GCN_014_shuttle_val_epoch_000750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_training_set/20210725-16h51m01sModel_GCN_014_shuttle_train_epoch_001000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_validation_set/20210725-16h51m01sModel_GCN_014_shuttle_val_epoch_001000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_training_set/20210725-16h51m01sModel_GCN_014_shuttle_train_epoch_001250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_validation_set/20210725-16h51m01sModel_GCN_014_shuttle_val_epoch_001250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_training_set/20210725-16h51m01sModel_GCN_014_shuttle_train_epoch_001500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_validation_set/20210725-16h51m01sModel_GCN_014_shuttle_val_epoch_001500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_training_set/20210725-16h51m01sModel_GCN_014_shuttle_train_epoch_001750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_validation_set/20210725-16h51m01sModel_GCN_014_shuttle_val_epoch_001750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_training_set/20210725-16h51m01sModel_GCN_014_shuttle_train_epoch_002000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_validation_set/20210725-16h51m01sModel_GCN_014_shuttle_val_epoch_002000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_training_set/20210725-16h51m01sModel_GCN_014_shuttle_train_epoch_002250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_validation_set/20210725-16h51m01sModel_GCN_014_shuttle_val_epoch_002250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_training_set/20210725-16h51m01sModel_GCN_014_shuttle_train_epoch_002500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_validation_set/20210725-16h51m01sModel_GCN_014_shuttle_val_epoch_002500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h51m01s/figures_training_set/20210725-16h51m01sModel_GCN_014_shuttle_train_epoch_002750of5000.png', '/storage/remote/atcremers50/ss21_mult ...
# shuttle_train_frame:158.0
# shuttle_val_frame:160.0
# hidden_layers_sizes:[128, 256, 64]
# reduction:mean
# scheduler:NoneType
# run_date:20210725-
# combo:('mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'None', False, 'tanh')
# use_edges_attr:False
# activation_function:tanh
# epoch14000_train_loss:nan
# epoch14000_final_val_loss:nan
# epoch28000_train_loss:nan
# epoch28000_final_val_loss:nan
# epoch2500_train_loss:nan
# epoch2500_final_val_loss:nan
# epoch5000_train_loss:nan
# epoch5000_final_val_loss:nan
# epoch4000_train_loss:nan
# epoch4000_final_val_loss:nan
# epoch8000_train_loss:nan
# epoch8000_final_val_loss:nan
# epoch12000_train_loss:nan
# epoch12000_final_val_loss:nan
# epoch16000_train_loss:nan
# epoch16000_final_val_loss:nan
# epoch20000_train_loss:nan
# epoch20000_final_val_loss:nan
# epoch1_train_loss:nan
# epoch1_final_val_loss:nan
# epoch2_train_loss:nan
# epoch2_final_val_loss:nan
# epoch3_train_loss:nan
# epoch3_final_val_loss:nan
# epoch4_train_loss:nan
# epoch4_final_val_loss:nan
# epoch5_train_loss:nan
# epoch5_final_val_loss:nan
# epoch500_train_loss:nan
# epoch500_final_val_loss:nan
# epoch1000_train_loss:nan
# epoch1000_final_val_loss:nan
# epoch1500_train_loss:nan
# epoch1500_final_val_loss:nan
# epoch2000_train_loss:nan
# epoch2000_final_val_loss:nan
# epoch3000_train_loss:nan
# epoch3000_final_val_loss:nan
# epoch3500_train_loss:nan
# epoch3500_final_val_loss:nan
# epoch4500_train_loss:nan
# epoch4500_final_val_loss:nan
# epoch6000_train_loss:nan
# epoch6000_final_val_loss:nan
# input_file_name_002:20210725-16h24m21s_timesteps200_ec3500_em7000
# train_size_002:0.9
# batch_size_002:512.0
# Nepochs_002:5000.0
# epoch7000_train_loss:nan
# epoch7000_final_val_loss:nan
# input_file_name_003:20210725-16h24m21s_timesteps200_ec3500_em7000
# train_size_003:0.9
# batch_size_003:512.0
# Nepochs_003:5000.0
# input_file_name_004:20210725-16h24m21s_timesteps200_ec3500_em7000
# train_size_004:0.9
# batch_size_004:512.0
# Nepochs_004:5000.0
# input_file_name_005:20210725-16h24m21s_timesteps200_ec3500_em7000
# train_size_005:0.9
# batch_size_005:512.0
# Nepochs_005:5000.0
# input_file_name_006:20210725-16h24m21s_timesteps200_ec3500_em7000
# train_size_006:0.9
# batch_size_006:512.0
# Nepochs_006:5000.0
# input_file_name_007:nan
# train_size_007:nan
# batch_size_007:nan
# Nepochs_007:nan
# input_file_name_008:nan
# train_size_008:nan
# batch_size_008:nan
# Nepochs_008:nan
# epoch9000_train_loss:nan
# epoch9000_final_val_loss:nan
# epoch10000_train_loss:nan
# epoch10000_final_val_loss:nan
#
# ['mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'None', False, 'relu']
#
# run_time:16h48m09s
# model:GCN_014
# random_seed:42
# train_size:0.9
# batch_size:512
# Nepochs:5000
# save_every:250
# transformstat:False
# plotstat:True
# printstat:False
# input_file_name:20210725-16h24m21s_timesteps200_ec3500_em7000
# num_rows_training:146
# num_rows_validation:15
# num_rows_test:2
# exclude_yaw:obsoleted
# concatenatestat:obsoleted
# paddingstat:obsoleted
# size_input:6
# size_output:3
# model_architecture:GCN_HL03_bn_relu(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )
# tloss_path:nan
# criterion:L1Loss()
# optimizer:Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# final_loss:nan
# train:nan
# val:nan
# lr:nan
# final_train_loss:0.1463979184627533
# final_val_loss:2.0451433658599854
# intentionstat:obsoleted
# model_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/20210725-16h48m09sEPOCH_5000of5000_FINAL__GCN_014.pt
# train_losses_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/20210725-16h48m09sEPOCH_5000of5000_FINAL__FINAL__training_loss.pkl
# val_losses_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/20210725-16h48m09sEPOCH_5000of5000_FINAL__FINAL__validation_loss.pkl
# lr_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/20210725-16h48m09sEPOCH_5000of5000_FINAL__FINAL__learning_rate.pkl
# max_num_veh:10.0
# sim_duration_timesteps:200
# figure_paths:['/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_training_set/20210725-16h48m09sModel_GCN_014_shuttle_train_epoch_000250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_validation_set/20210725-16h48m09sModel_GCN_014_shuttle_val_epoch_000250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_training_set/20210725-16h48m09sModel_GCN_014_shuttle_train_epoch_000500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_validation_set/20210725-16h48m09sModel_GCN_014_shuttle_val_epoch_000500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_training_set/20210725-16h48m09sModel_GCN_014_shuttle_train_epoch_000750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_validation_set/20210725-16h48m09sModel_GCN_014_shuttle_val_epoch_000750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_training_set/20210725-16h48m09sModel_GCN_014_shuttle_train_epoch_001000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_validation_set/20210725-16h48m09sModel_GCN_014_shuttle_val_epoch_001000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_training_set/20210725-16h48m09sModel_GCN_014_shuttle_train_epoch_001250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_validation_set/20210725-16h48m09sModel_GCN_014_shuttle_val_epoch_001250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_training_set/20210725-16h48m09sModel_GCN_014_shuttle_train_epoch_001500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_validation_set/20210725-16h48m09sModel_GCN_014_shuttle_val_epoch_001500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_training_set/20210725-16h48m09sModel_GCN_014_shuttle_train_epoch_001750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_validation_set/20210725-16h48m09sModel_GCN_014_shuttle_val_epoch_001750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_training_set/20210725-16h48m09sModel_GCN_014_shuttle_train_epoch_002000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_validation_set/20210725-16h48m09sModel_GCN_014_shuttle_val_epoch_002000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_training_set/20210725-16h48m09sModel_GCN_014_shuttle_train_epoch_002250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_validation_set/20210725-16h48m09sModel_GCN_014_shuttle_val_epoch_002250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_training_set/20210725-16h48m09sModel_GCN_014_shuttle_train_epoch_002500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_validation_set/20210725-16h48m09sModel_GCN_014_shuttle_val_epoch_002500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210725-16h48m09s/figures_training_set/20210725-16h48m09sModel_GCN_014_shuttle_train_epoch_002750of5000.png', '/storage/remote/atcremers50/ss21_mult ...
# shuttle_train_frame:8.0
# shuttle_val_frame:161.0
# hidden_layers_sizes:[128, 256, 64]
# reduction:mean
# scheduler:NoneType
# run_date:20210725-
# combo:('mean', 512, 'Adam', 'L1', [128, 256, 64], 0.001, 0.6, 0, 'None', False, 'relu')
# use_edges_attr:False
# activation_function:relu
# epoch14000_train_loss:nan
# epoch14000_final_val_loss:nan
# epoch28000_train_loss:nan
# epoch28000_final_val_loss:nan
# epoch2500_train_loss:nan
# epoch2500_final_val_loss:nan
# epoch5000_train_loss:nan
# epoch5000_final_val_loss:nan
# epoch4000_train_loss:nan
# epoch4000_final_val_loss:nan
# epoch8000_train_loss:nan
# epoch8000_final_val_loss:nan
# epoch12000_train_loss:nan
# epoch12000_final_val_loss:nan
# epoch16000_train_loss:nan
# epoch16000_final_val_loss:nan
# epoch20000_train_loss:nan
# epoch20000_final_val_loss:nan
# epoch1_train_loss:nan
# epoch1_final_val_loss:nan
# epoch2_train_loss:nan
# epoch2_final_val_loss:nan
# epoch3_train_loss:nan
# epoch3_final_val_loss:nan
# epoch4_train_loss:nan
# epoch4_final_val_loss:nan
# epoch5_train_loss:nan
# epoch5_final_val_loss:nan
# epoch500_train_loss:nan
# epoch500_final_val_loss:nan
# epoch1000_train_loss:nan
# epoch1000_final_val_loss:nan
# epoch1500_train_loss:nan
# epoch1500_final_val_loss:nan
# epoch2000_train_loss:nan
# epoch2000_final_val_loss:nan
# epoch3000_train_loss:nan
# epoch3000_final_val_loss:nan
# epoch3500_train_loss:nan
# epoch3500_final_val_loss:nan
# epoch4500_train_loss:nan
# epoch4500_final_val_loss:nan
# epoch6000_train_loss:nan
# epoch6000_final_val_loss:nan
# input_file_name_002:20210725-16h24m21s_timesteps200_ec3500_em7000
# train_size_002:0.9
# batch_size_002:512.0
# Nepochs_002:5000.0
# epoch7000_train_loss:nan
# epoch7000_final_val_loss:nan
# input_file_name_003:20210725-16h24m21s_timesteps200_ec3500_em7000
# train_size_003:0.9
# batch_size_003:512.0
# Nepochs_003:5000.0
# input_file_name_004:20210725-16h24m21s_timesteps200_ec3500_em7000
# train_size_004:0.9
# batch_size_004:512.0
# Nepochs_004:5000.0
# input_file_name_005:20210725-16h24m21s_timesteps200_ec3500_em7000
# train_size_005:0.9
# batch_size_005:512.0
# Nepochs_005:5000.0
# input_file_name_006:nan
# train_size_006:nan
# batch_size_006:nan
# Nepochs_006:nan
# input_file_name_007:nan
# train_size_007:nan
# batch_size_007:nan
# Nepochs_007:nan
# input_file_name_008:nan
# train_size_008:nan
# batch_size_008:nan
# Nepochs_008:nan
# epoch9000_train_loss:nan
# epoch9000_final_val_loss:nan
# epoch10000_train_loss:nan
# epoch10000_final_val_loss:nan

# %%
all_combos = [v[0] for k,v in reloaded_best_combos.items()]
all_combos
# Out:
# [['mean',
#   512,
#   'Adam',
#   'L1',
#   [128, 256, 64],
#   0.001,
#   0.6,
#   0,
#   'CosineAnnealingWarmRestarts',
#   False,
#   'relu'],
#  ['mean',
#   512,
#   'Adam',
#   'L1',
#   [128, 256, 64],
#   0.001,
#   0.6,
#   0,
#   'CosineAnnealingWarmRestarts',
#   False,
#   'relu'],
#  ['mean',
#   128,
#   'Adam',
#   'L1',
#   [64, 128, 256],
#   0.001,
#   0.6,
#   0,
#   'CosineAnnealingWarmRestarts',
#   True,
#   'relu'],
#  ['mean',
#   512,
#   'Adam',
#   'L1',
#   [128, 256, 64],
#   0.001,
#   0.6,
#   0,
#   'CosineAnnealingWarmRestarts',
#   False,
#   'tanh'],
#  ['mean',
#   512,
#   'Adam',
#   'L1',
#   [128, 256, 64],
#   0.001,
#   0.6,
#   0,
#   'None',
#   False,
#   'tanh'],
#  ['mean',
#   512,
#   'Adam',
#   'L1',
#   [128, 256, 64],
#   0.001,
#   0.6,
#   0,
#   'None',
#   False,
#   'relu']]

# %%
# check if the value is in the bunch
