# %%
#--------------------------------
## IMPORTS
#--------------------------------
import sys
import os

# set the path to find the modules
sys.path.insert(0, '../../005_src/') #use relative path
os.chdir("../../005_src")

from config import *
# Out:
# ----------------------------------------
# Packages import successful
# Variables import successful
# Helper Functions import successful
# Functions import successful
# Functions xml import successful
# Functions graph import successful
# Functions GCN import successful
# Functions Plotting import successful
# Functions Data Adjustments import successful
# ----------------------------------------
# root directory: /storage/remote/atcremers50/ss21_multiagentcontrol/
# input directory: /storage/remote/atcremers50/ss21_multiagentcontrol/004_data/
# output directory: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/
# ----------------------------------------

# %%
device = cudaOverview()
# Out:
# CUDA available
# Number of Devices: 1
# ID current Device NVIDIA GeForce GTX 1050 Ti: 0
# 	current GPU memory usage by tensors in bytes:0
# 	current GPU memory managed by caching allocator in bytes:0

# %%
this_date = "20210724"
ts = "08h18m52s"
GCN_num = "014"
this_GCN = f"GCN_{GCN_num}"
print (this_GCN)

from _03_Networks.GCN_014.GCN_model_014 import *
from _03_Networks.GCN_014.GCN_trainer_014 import *
from _03_Networks.GCN_014.GCN_parameters_014 import *
this_GCN, ts_import = check_import()
# Out:
# GCN_014
# at 08h38m58s imported models:
# ['GCN_HL01_bn_relu', 'GCN_HL01_bn_tanh', 'GCN_HL02_bn_relu', 'GCN_HL02_bn_tanh', 'GCN_HL03_bn_relu', 'GCN_HL03_bn_tanh']
# imported parameters from: GCN_parameters_014.py at 08h38m58s
# imported trainer: GCN_014 at 08h38m58s

# %% [markdown]
# ## Reload dictionary

# %%
MODEL_OUTPUT_PATH = os.path.join(OUTPUT_DIR,f"{this_GCN}/")
MODEL_OUTPUT_PATH_TODAY = os.path.join(MODEL_OUTPUT_PATH,f"{this_date}-{ts}/")
print (MODEL_OUTPUT_PATH_TODAY)
# Out:
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/

# %%
dict_text_output_path = f"/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/{this_GCN}/{this_date}-{ts}/{this_date}-{ts}_training_parameters"

reloaded_dict = pkl.load(open(f'{dict_text_output_path}.pkl',"rb"))
reloaded_dict
# Out:
# {'input_file_name': '20210711-17h59m44s_timesteps30000_ec3500_em7000',
#  'max_num_veh': 10,
#  'sim_duration_timesteps': '30000',
#  'run_date': '20210724-',
#  'run_time': '08h18m52s',
#  'model': 'GCN_014',
#  'combo': ('mean',
#   512,
#   'Adam',
#   'L1',
#   [128, 256, 64],
#   0.001,
#   0.6,
#   0,
#   'CosineAnnealingWarmRestarts',
#   False,
#   'tanh'),
#  'random_seed': 42314,
#  'train_size': 0.9,
#  'batch_size': 512,
#  'Nepochs': 20000,
#  'save_every': 1000,
#  'transformstat': False,
#  'plotstat': True,
#  'printstat': False,
#  'intentionstat': 'obsoleted',
#  'use_edges_attr': False,
#  'activation_function': 'tanh',
#  'shuttle_train_frame': 6086,
#  'shuttle_val_frame': 4333,
#  'num_rows_training': 22478,
#  'num_rows_validation': 2248,
#  'num_rows_test': 250,
#  'exclude_yaw': 'obsoleted',
#  'concatenatestat': 'obsoleted',
#  'paddingstat': 'obsoleted',
#  'size_input': 6,
#  'size_output': 3,
#  'model_architecture': GCN_HL03_bn_tanh(
#    (conv1): GraphConv(6, 128)
#    (conv2): GraphConv(128, 256)
#    (conv3): GraphConv(256, 64)
#    (conv4): GraphConv(64, 3)
#    (bn1): GraphNorm(128)
#    (bn2): GraphNorm(256)
#    (bn3): GraphNorm(64)
#  ),
#  'hidden_layers_sizes': [128, 256, 64],
#  'criterion': L1Loss(),
#  'optimizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      eps: 1e-08
#      initial_lr: 0.001
#      lr: 2.025351319275115e-05
#      weight_decay: 0
#  ),
#  'reduction': 'mean',
#  'scheduler': 'CosineAnnealingWarmRestarts',
#  'model_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/20210724-08h18m52sEPOCH_7000of20000_TEMP__GCN_014.pt',
#  'train_losses_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/20210724-08h18m52sEPOCH_7000of20000_TEMP__TEMP__training_loss.pkl',
#  'val_losses_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/20210724-08h18m52sEPOCH_7000of20000_TEMP__TEMP__validation_loss.pkl',
#  'lr_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/20210724-08h18m52sEPOCH_7000of20000_TEMP__TEMP__learning_rate.pkl',
#  'epoch1000_train_loss': 0.22501132264733315,
#  'epoch1000_final_val_loss': 0.2616373926401138,
#  'figure_paths': ['/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_training_set/20210724-08h18m52sModel_GCN_014_shuttle_train_epoch_001000of20000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_validation_set/20210724-08h18m52sModel_GCN_014_shuttle_val_epoch_001000of20000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_training_set/20210724-08h18m52sModel_GCN_014_shuttle_train_epoch_002000of20000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_validation_set/20210724-08h18m52sModel_GCN_014_shuttle_val_epoch_002000of20000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_training_set/20210724-08h18m52sModel_GCN_014_shuttle_train_epoch_003000of20000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_validation_set/20210724-08h18m52sModel_GCN_014_shuttle_val_epoch_003000of20000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_training_set/20210724-08h18m52sModel_GCN_014_shuttle_train_epoch_004000of20000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_validation_set/20210724-08h18m52sModel_GCN_014_shuttle_val_epoch_004000of20000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_training_set/20210724-08h18m52sModel_GCN_014_shuttle_train_epoch_005000of20000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_validation_set/20210724-08h18m52sModel_GCN_014_shuttle_val_epoch_005000of20000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_training_set/20210724-08h18m52sModel_GCN_014_shuttle_train_epoch_006000of20000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_validation_set/20210724-08h18m52sModel_GCN_014_shuttle_val_epoch_006000of20000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_training_set/20210724-08h18m52sModel_GCN_014_shuttle_train_epoch_007000of20000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_validation_set/20210724-08h18m52sModel_GCN_014_shuttle_val_epoch_007000of20000.png'],
#  'epoch2000_train_loss': 0.15987756103277206,
#  'epoch2000_final_val_loss': 0.19208191335201263,
#  'epoch3000_train_loss': 0.11965150352228772,
#  'epoch3000_final_val_loss': 0.1502200186252594,
#  'epoch4000_train_loss': 0.1297747768800367,
#  'epoch4000_final_val_loss': 0.1543711543083191,
#  'epoch5000_train_loss': 0.12479988231577656,
#  'epoch5000_final_val_loss': 0.16249616742134093,
#  'epoch6000_train_loss': 0.1157709200951186,
#  'epoch6000_final_val_loss': 0.14566874504089355,
#  'epoch7000_train_loss': 0.08954608084803278,
#  'epoch7000_final_val_loss': 0.11916106045246125}

# %%
input_file_name = reloaded_dict["input_file_name"]
reloaded_dict["model_architecture"]
# Out:
# GCN_HL03_bn_tanh(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )

# %% [markdown]
# ## Plot losses

# %%
# first lossess paths

curr_epoch = 7000
tot_epoch = 20000
type_epoch = "TEMP"

# %%
# load losses

#if type_epoch == "TEMP":
load_path_files = os.path.join(MODEL_OUTPUT_PATH_TODAY,f"{this_date}-{ts}EPOCH_{curr_epoch}of{tot_epoch}_{type_epoch}__{type_epoch}__")
t_path =  f"{load_path_files}training_loss.pkl"
v_path =  f"{load_path_files}validation_loss.pkl"
lr_path = f"{load_path_files}learning_rate.pkl"
t_losses_load = pkl.load(open(t_path, 'rb'))
v_losses_load = pkl.load(open(v_path, 'rb'))
lr_load = pkl.load(open(lr_path, 'rb'))
#else: 
  # load losses
    #t_losses_load.extend(pkl.load(open( reloaded_dict['train_losses_path'], 'rb')))
    #v_losses_load.extend(pkl.load(open( reloaded_dict['val_losses_path'], 'rb')))
    #lr_load.extend(pkl.load(open( reloaded_dict['lr_path'], 'rb')))

# %%
##================================
# TRAIN AND VAL LOSSES
##================================
fig = plot_training(t_losses_load[:curr_epoch],
                  v_losses_load[:curr_epoch],
                  learning_rate = lr_load,
                  gaussian=True,
                  sigma=2,
                  figsize=(20, 6),
                  mytitle = 'Training & validation loss'
                  )

description = f"{this_date}-{ts}"
new_png = f"{description}_train_val_loss_plot.png"
new_png_path = os.path.join(MODEL_OUTPUT_PATH_TODAY,new_png)
plt.savefig(new_png_path)
print (f"Plot saved in {new_png_path}")
# Out:
# Plot saved in /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/20210724-08h18m52s_train_val_loss_plot.png

# %%
min(v_losses_load), v_losses_load.index(min(v_losses_load))
# Out:
# (0.1183728501200676, 6575)

# %%
min(t_losses_load), t_losses_load.index(min(t_losses_load))
# Out:
# (0.08716451071880081, 6987)

# %% [markdown]
# ## Verification
# of results

# %%
hidden_layers_sizes = reloaded_dict["hidden_layers_sizes"]
size_input = reloaded_dict['size_input']
size_output = reloaded_dict['size_output']
random_seed = reloaded_dict["random_seed"]
activation_fun = reloaded_dict["activation_function"]

# %%
size_input,size_output
# Out:
# (6, 3)

# %%
##================================
## MODEL INIT
##================================
num_hidden_layers = len(hidden_layers_sizes)
    
#print (printstat)
#pdb.set_trace()

## TANH

if activation_fun == "tanh":
    if num_hidden_layers == 1:

        hc_1 = hidden_layers_sizes[0]
        hc_2 = None
        hc_3 = None

        model = GCN_HL01_bn_tanh(
                            num_input_features=size_input,
                            num_output_features =size_output,
                            random_seed = random_seed,
                            hc_1 = hc_1,
                            printstat = printstat, 
                            )
    elif num_hidden_layers == 2:

        hc_1 = hidden_layers_sizes[0]
        hc_2 = hidden_layers_sizes[1]
        hc_3 = None

        model = GCN_HL02_bn_tanh(
                            num_input_features=size_input,
                            num_output_features =size_output,
                            random_seed = random_seed,
                            hc_1 = hc_1,
                            hc_2 = hc_2,
                            printstat = printstat,   
                            )
    elif num_hidden_layers == 3:

        hc_1 = hidden_layers_sizes[0]
        hc_2 = hidden_layers_sizes[1]
        hc_3 = hidden_layers_sizes[2]

        model = GCN_HL03_bn_tanh(
                            num_input_features=size_input,
                            num_output_features =size_output,
                            random_seed = random_seed,
                            hc_1 = hc_1,
                            hc_2 = hc_2,
                            hc_3 = hc_3,
                            printstat = printstat,                
                            )
    else:
        print (f"ERROR: model with {num_hidden_layers=} not implemented")
        print (f"using first three layers")

        hc_1 = hidden_layers_sizes[0]
        hc_2 = hidden_layers_sizes[1]
        hc_3 = hidden_layers_sizes[2]

        model = GCN_HL03_bn_tanh(num_input_features=size_input,
                    num_output_features =size_output,
                    random_seed = random_seed,
                    hc_1 = hc_1,
                    hc_2 = hc_2,
                    hc_3 = hc_3,
                    printstat = printstat, 
                    )
        
#### RELU       
        
elif activation_fun == "relu": 
    if num_hidden_layers == 1:

        hc_1 = hidden_layers_sizes[0]
        hc_2 = None
        hc_3 = None

        model = GCN_HL01_bn_relu(
                            num_input_features=size_input,
                            num_output_features =size_output,
                            random_seed = random_seed,
                            hc_1 = hc_1,
                            printstat = printstat,                 
                            )
    elif num_hidden_layers == 2:

        hc_1 = hidden_layers_sizes[0]
        hc_2 = hidden_layers_sizes[1]
        hc_3 = None

        model = GCN_HL02_bn_relu(
                            num_input_features=size_input,
                            num_output_features =size_output,
                            random_seed = random_seed,
                            hc_1 = hc_1,
                            hc_2 = hc_2,
                            printstat = printstat,                 
                            )
    elif num_hidden_layers == 3:

        hc_1 = hidden_layers_sizes[0]
        hc_2 = hidden_layers_sizes[1]
        hc_3 = hidden_layers_sizes[2]

        model = GCN_HL03_bn_relu(
                            num_input_features=size_input,
                            num_output_features =size_output,
                            random_seed = random_seed,
                            hc_1 = hc_1,
                            hc_2 = hc_2,
                            hc_3 = hc_3,
                            printstat = printstat,               
                            )
    else:
        print (f"ERROR: model with {num_hidden_layers=} not implemented")
        print (f"using first three layers")

        hc_1 = hidden_layers_sizes[0]
        hc_2 = hidden_layers_sizes[1]
        hc_3 = hidden_layers_sizes[2]

        model = GCN_HL03_bn_relu(num_input_features=size_input,
                    num_output_features =size_output,
                    random_seed = random_seed,
                    hc_1 = hc_1,
                    hc_2 = hc_2,
                    hc_3 = hc_3,
                    printstat = printstat,                                      
                    )
else:
    print (f"ERROR: model with {activation_fun=} not implemented")

load_model = model

# %%
load_path = reloaded_dict['model_path']
print (load_path)
load_model.load_state_dict(torch.load(load_path))
load_model.eval()
# Out:
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/20210724-08h18m52sEPOCH_7000of20000_TEMP__GCN_014.pt
# GCN_HL03_bn_tanh(
#   (conv1): GraphConv(6, 128)
#   (conv2): GraphConv(128, 256)
#   (conv3): GraphConv(256, 64)
#   (conv4): GraphConv(64, 3)
#   (bn1): GraphNorm(128)
#   (bn2): GraphNorm(256)
#   (bn3): GraphNorm(64)
# )

# %%
MODEL_OUTPUT_PATH = os.path.join(OUTPUT_DIR,f"{this_GCN}/")
MODEL_OUTPUT_PATH_DATASETS = os.path.join(MODEL_OUTPUT_PATH,f"DATASETS/")
datasets_list = sorted(glob.glob(f"{MODEL_OUTPUT_PATH_DATASETS}"+"/**/*"+f'{input_file_name}_dataset*',
                                     recursive=True))

dataset_train = None

print ()
if len( datasets_list) == 5:                               
        print ("\n> DATASETS FOUND")
        print (*datasets_list, sep = "\n")
        
        dataset_train = torch.load(datasets_list[0], map_location=torch.device('cpu') )
        # map_location=lambda storage, loc: storage.cuda(0))
        dataset_val = torch.load(datasets_list[1], map_location=torch.device('cpu') )
        dataset_test = torch.load(datasets_list[2], map_location=torch.device('cpu') )
        dataset_shuttle_train = torch.load(datasets_list[3], map_location=torch.device('cpu') )
        dataset_shuttle_val = torch.load(datasets_list[4], map_location=torch.device('cpu') )
else: 
    datasets_list_train = sorted(glob.glob(f"{MODEL_OUTPUT_PATH_DATASETS}"+"/**/*"+f'_dataset_01*',
                                     recursive=True))
    
    #print (*datasets_list_train, sep ="\n")

# %%
path_GIF= build_gif(folder = f'/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_{GCN_num}/{this_date}-{ts}/figures_validation_set/',
              title = "Predictions over epochs",
              search = "", 
              fps=0.5,
              recursive = True,
              delete_tempFiles = False,
              max_n_images = 200
             )
# Out:
# 2it [00:00, 11.42it/s]
# found 7 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_validation_set/
# the gif will be create using the first 7 images
# 7it [00:00, 11.52it/s]

# %%
Image(open(f'{path_GIF}','rb').read())

# %%
path_GIF= build_gif(folder = f'/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_{GCN_num}/{this_date}-{ts}/figures_training_set/',
              title = "Predictions over epochs",
              search = "", 
              fps=0.5,
              recursive = True,
              delete_tempFiles = False,
              max_n_images = 200
             )
# Out:
# 1it [00:00,  9.29it/s]
# found 7 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/20210724-08h18m52s/figures_training_set/
# the gif will be create using the first 7 images
# 7it [00:00,  9.96it/s]

# %%
Image(open(f'{path_GIF}','rb').read())

# %%
#deleted_folders = delete_empty_r(directory= MODEL_OUTPUT_PATH,printstat = True)

# %% [markdown]
# ## try with many different images... any difference?

# %%
MODEL_OUTPUT_PATH
# Out:
# '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/'

# %%
datasets_list_train = sorted(glob.glob(f"{MODEL_OUTPUT_PATH_DATASETS}"+"/**/*"+f'_dataset_01*',
                                     recursive=True))

print (*datasets_list_train, sep ="\n")
datasets_list_val = sorted(glob.glob(f"{MODEL_OUTPUT_PATH_DATASETS}"+"/**/*"+f'_dataset_02*',
                                     recursive=True))
# Out:
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/DATASETS/20210710-11h46m35s_timesteps200_ec3500_em7000_127_IN_data_pos_zc_data_x_rad_still_vehicle_OUT_data_y_zc__dataset_01_train.pt
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/DATASETS/20210710-11h46m35s_timesteps200_ec3500_em7000_127_IN_data_pos_zc_data_x_rad_still_vehicle_OUT_data_y_zc_data_y_yaw__dataset_01_train.pt
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/DATASETS/20210710-20h38m27s_timesteps14930_ec3500_em7000_10588_IN_data_pos_zc_data_x_rad_still_vehicle_OUT_data_y_zc__dataset_01_train.pt
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/DATASETS/20210710-20h38m27s_timesteps14930_ec3500_em7000_10588_IN_data_pos_zc_data_x_rad_still_vehicle_OUT_data_y_zc_data_y_yaw__dataset_01_train.pt
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/DATASETS/20210711-17h59m44s_timesteps30000_ec3500_em7000_22478_IN_data_pos_zc_data_x_rad_still_vehicle_OUT_data_y_zc_data_y_yaw__dataset_01_train.pt
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/DATASETS/20210721-23h05m03s_timesteps90095_ec3500_em7000_53793_IN_data_pos_zc_data_x_rad_still_vehicle_OUT_data_y_zc_data_y_yaw__dataset_01_train.pt
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/DATASETS/20210724-19h49m31s_timesteps150000_ec3500_em7000_105883_IN_data_pos_zc_data_x_rad_still_vehicle_OUT_data_y_zc_data_y_yaw__dataset_01_train.pt
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_014/DATASETS/20210725-16h24m21s_timesteps200_ec3500_em7000_146_IN_data_pos_zc_data_x_rad_still_vehicle_OUT_data_y_zc_data_y_yaw__dataset_01_train.pt

# %% [markdown]
# ## TODO: UPDATE THE DATASET!
# In the old trainings we werent storing the dataset path in the dictionary... so you need to fish for it. check the input size and that can give a good indication

# %%
dataset_train = None
if dataset_train is None: 
    i = 4
    dateset_train_path = datasets_list_train[i]
    dateset_val_path = datasets_list_val[i]
    #f"{MODEL_OUTPUT_PATH}DATASETS/20210801-08h53m15s_timesteps50000_ec3500_em7000_25664_IN_data_pos_zc_data_x_speed_data_x_yaw_still_vehicle_OUT_data_y_zc_data_y_yaw__dataset_01_train.pt"
    dateset_train = torch.load(f'{dateset_train_path}')
    dateset_val = torch.load(f'{dateset_val_path}')

# %%
dateset_train
# Out:
# [Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[36], edge_index=[2, 36], x=[9, 6], y=[9, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
# ...
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  ...]

# %%
len(dateset_train),len(dateset_val)
# Out:
# (22478, 2248)

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
from config_GCN_017 import *

# %%
losses = losses_results_model(
                               load_model, 
                               dateset_val,
                               device = "cpu",
                               start_from = 0,
                               end_at = len(dateset_train),
                               edges_attr = True,

                               printstat = False,       
                               loss_stat = "L1"
                              )
print (min(losses))
print (max(losses))
print (mean(losses))
# Out:
# 100%|██████████| 2248/2248 [00:09<00:00, 242.34it/s]
# 4.094218730926514
# 16.28883934020996
# 10.40628068748318

# %%
min_ind = losses.index(min(losses))
max_ind = losses.index(max(losses))

# %%
space = 100
loss = plot_results_model(
                       load_model, 
                       dateset_val,
                       start_from = min_ind,
                       end_at = min_ind+1,
                       edges_attr = True,
                       figsize = (15,15),
                       plot_input = True,
                       plot_target = True,
                       plot_prediction = True,
                       plot_intention = False, 
                       title = None,
        
                       printstat = True,       

                       xlim = (-space,space),
                       ylim = (-space,space),
                       loss_stat = "L1"
                      )
# Out:
# 1183
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -14.0800,   0.0000,   9.3800,   3.0000,   0.0000],
#         [  1.6000, -57.0200,   0.0000,  10.7600,   1.0000,   0.0000]]),
# edge_index=tensor([[0, 0, 1],
#         [1, 2, 2]]),
# edge_attr=tensor([10.3000,  2.7000,  3.0000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [  1.6000,  -8.3600,   0.0000],
#         [  1.6000, -31.3600,   0.0000]])
#
#  PREDICTION
# tensor([[-6.2850e+00, -2.0957e+00,  2.0844e+00],
#         [-2.8409e-01,  5.2431e+00,  1.8866e+00],
#         [ 6.9422e-01, -4.6974e+01, -3.0340e-02]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -14.0800,   0.0000,   9.3800,   3.0000,   0.0000],
#         [  1.6000, -57.0200,   0.0000,  10.7600,   1.0000,   0.0000]]),
# edge_index=tensor([[0, 0, 1],
#         [1, 2, 2]]),
# edge_attr=tensor([10.3000,  2.7000,  3.0000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [  1.6000,  -8.3600,   0.0000],
#         [  1.6000, -31.3600,   0.0000]])
#
#  PREDICTION
# tensor([[-6.2850e+00, -2.0957e+00,  2.0844e+00],
#         [-2.8409e-01,  5.2431e+00,  1.8866e+00],
#         [ 6.9422e-01, -4.6974e+01, -3.0340e-02]], grad_fn=<AddBackward0>)
# loss_value=4.094218730926514
# loss_value=4.094218730926514

# %%
space = 100
loss = plot_results_model(
                       load_model, 
                       dateset_val,
                       start_from = max_ind,
                       end_at = max_ind+1,
                       edges_attr = True,
                       figsize = (15,15),
                       plot_input = True,
                       plot_target = True,
                       plot_prediction = True,
                       plot_intention = False, 
                       title = None,
        
                       printstat = True,
                       plotstat = True,

                       xlim = (-space,space),
                       ylim = (-space,space),
                       loss_stat = "L1"
                      )
# Out:
# 888
#
#  INPUT
# x=tensor([[ 1.5000e+00,  7.0500e+00,  1.7752e+00,  2.2600e+00,  0.0000e+00,
#           0.0000e+00],
#         [-1.6000e+00, -5.7770e+01,  3.1416e+00,  1.4010e+01,  3.0000e+00,
#           0.0000e+00],
#         [-1.6000e+00,  1.2460e+01,  3.1416e+00,  0.0000e+00,  1.0000e+00,
#           0.0000e+00],
#         [-1.6000e+00, -2.9670e+01,  3.1416e+00,  1.0440e+01,  3.0000e+00,
#           0.0000e+00],
#         [-1.6000e+00, -7.5500e+00,  2.8239e+00,  5.1600e+00,  3.0000e+00,
#           0.0000e+00],
#         [-1.6000e+00,  1.9980e+01,  3.1416e+00,  2.0000e-02,  1.0000e+00,
#           0.0000e+00],
#         [-1.2770e+01, -1.6000e+00,  1.5708e+00,  6.6000e+00,  0.0000e+00,
#           0.0000e+00],
#         [-1.6000e+00,  2.7520e+01,  3.1416e+00,  2.0000e-02,  1.0000e+00,
#           0.0000e+00],
#         [ 1.6000e+00,  3.3360e+01,  0.0000e+00,  1.1700e+01,  1.0000e+00,
#           0.0000e+00],
#         [ 1.6000e+00,  6.2160e+01,  0.0000e+00,  1.4180e+01,  3.0000e+00,
#           0.0000e+00]]),
# edge_index=tensor([[6, 1, 4, 4, 3, 0, 2, 2, 1, 1, 0, 2, 5, 0, 3, 3, 1, 6, 4, 1, 0, 7, 5, 0,
#          4, 4, 2, 8, 1, 0, 0, 2, 3, 2, 1, 0, 0, 6, 5, 5, 1, 2, 3, 3, 7],
#         [8, 4, 6, 9, 4, 7, 6, 9, 6, 9, 5, 3, 7, 8, 6, 9, 3, 9, 7, 2, 4, 9, 8, 1,
#          5, 8, 7, 9, 7, 6, 9, 5, 7, 8, 8, 2, 3, 7, 6, 9, 5, 4, 5, 8, 8]]),
# edge_attr=tensor([ 4.3000,  2.7000, 11.8000,  2.3000,  5.7000,  6.0000, 10.6000,  2.6000,
#          2.6000,  2.0000,  8.8000,  4.6000, 10.2000,  4.9000,  5.1000,  2.1000,
#          3.5000,  2.4000,  5.0000,  2.4000, 16.3000,  3.0000,  6.6000,  2.5000,
#          6.8000,  4.2000,  6.9000,  3.3000,  2.3000, 10.8000,  2.5000, 11.6000,
#          4.3000,  5.4000,  2.2000, 16.0000,  4.8000,  5.2000,  7.1000,  2.8000,
#          2.3000, 10.5000,  4.4000,  3.8000, 10.5000])
#
#
#  TARGET
# tensor([[  1.6000,  14.3800,   0.0000],
#         [ -1.6000, -91.0600,   3.1416],
#         [ -1.6000,   8.9200,   3.1416],
#         [ -1.6000, -57.3200,   3.1416],
#         [ -1.6000, -23.9600,   3.1416],
#         [ -1.6000,  18.7800,   3.1416],
#         [ -8.5500,  -1.6000,   1.5708],
#         [ -1.6000,  27.4800,   3.1416],
#         [  1.6000,  61.2100,   0.0000],
#         [  1.6000,  96.6900,   0.0000]])
#
#  PREDICTION
# tensor([[ -7.2340,  -0.3395,   1.1036],
#         [ -9.6325, -10.3848,   2.6778],
#         [ -6.9630,  -3.5965,   0.1669],
#         [  4.4170, -20.4186,  -0.7775],
#         [-14.6807, -10.6902,   0.3957],
#         [ -1.8368, -17.3160,   0.6089],
#         [-10.1675, -14.2142,   0.5985],
#         [ -9.1664, -15.5022,   3.0192],
#         [-10.2837,   0.1237,   4.8901],
#         [ -8.3429,  13.1751,   1.9899]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ 1.5000e+00,  7.0500e+00,  1.7752e+00,  2.2600e+00,  0.0000e+00,
#           0.0000e+00],
#         [-1.6000e+00, -5.7770e+01,  3.1416e+00,  1.4010e+01,  3.0000e+00,
#           0.0000e+00],
#         [-1.6000e+00,  1.2460e+01,  3.1416e+00,  0.0000e+00,  1.0000e+00,
#           0.0000e+00],
#         [-1.6000e+00, -2.9670e+01,  3.1416e+00,  1.0440e+01,  3.0000e+00,
#           0.0000e+00],
#         [-1.6000e+00, -7.5500e+00,  2.8239e+00,  5.1600e+00,  3.0000e+00,
#           0.0000e+00],
#         [-1.6000e+00,  1.9980e+01,  3.1416e+00,  2.0000e-02,  1.0000e+00,
#           0.0000e+00],
#         [-1.2770e+01, -1.6000e+00,  1.5708e+00,  6.6000e+00,  0.0000e+00,
#           0.0000e+00],
#         [-1.6000e+00,  2.7520e+01,  3.1416e+00,  2.0000e-02,  1.0000e+00,
#           0.0000e+00],
#         [ 1.6000e+00,  3.3360e+01,  0.0000e+00,  1.1700e+01,  1.0000e+00,
#           0.0000e+00],
#         [ 1.6000e+00,  6.2160e+01,  0.0000e+00,  1.4180e+01,  3.0000e+00,
#           0.0000e+00]]),
# edge_index=tensor([[6, 1, 4, 4, 3, 0, 2, 2, 1, 1, 0, 2, 5, 0, 3, 3, 1, 6, 4, 1, 0, 7, 5, 0,
#          4, 4, 2, 8, 1, 0, 0, 2, 3, 2, 1, 0, 0, 6, 5, 5, 1, 2, 3, 3, 7],
#         [8, 4, 6, 9, 4, 7, 6, 9, 6, 9, 5, 3, 7, 8, 6, 9, 3, 9, 7, 2, 4, 9, 8, 1,
#          5, 8, 7, 9, 7, 6, 9, 5, 7, 8, 8, 2, 3, 7, 6, 9, 5, 4, 5, 8, 8]]),
# edge_attr=tensor([ 4.3000,  2.7000, 11.8000,  2.3000,  5.7000,  6.0000, 10.6000,  2.6000,
#          2.6000,  2.0000,  8.8000,  4.6000, 10.2000,  4.9000,  5.1000,  2.1000,
#          3.5000,  2.4000,  5.0000,  2.4000, 16.3000,  3.0000,  6.6000,  2.5000,
#          6.8000,  4.2000,  6.9000,  3.3000,  2.3000, 10.8000,  2.5000, 11.6000,
#          4.3000,  5.4000,  2.2000, 16.0000,  4.8000,  5.2000,  7.1000,  2.8000,
#          2.3000, 10.5000,  4.4000,  3.8000, 10.5000])
#
#
#  TARGET
# tensor([[  1.6000,  14.3800,   0.0000],
#         [ -1.6000, -91.0600,   3.1416],
#         [ -1.6000,   8.9200,   3.1416],
#         [ -1.6000, -57.3200,   3.1416],
#         [ -1.6000, -23.9600,   3.1416],
#         [ -1.6000,  18.7800,   3.1416],
#         [ -8.5500,  -1.6000,   1.5708],
#         [ -1.6000,  27.4800,   3.1416],
#         [  1.6000,  61.2100,   0.0000],
#         [  1.6000,  96.6900,   0.0000]])
#
#  PREDICTION
# tensor([[ -7.2340,  -0.3395,   1.1036],
#         [ -9.6325, -10.3848,   2.6778],
#         [ -6.9630,  -3.5965,   0.1669],
#         [  4.4170, -20.4186,  -0.7775],
#         [-14.6807, -10.6902,   0.3957],
#         [ -1.8368, -17.3160,   0.6089],
#         [-10.1675, -14.2142,   0.5985],
#         [ -9.1664, -15.5022,   3.0192],
#         [-10.2837,   0.1237,   4.8901],
#         [ -8.3429,  13.1751,   1.9899]], grad_fn=<AddBackward0>)
# loss_value=16.28883934020996
# loss_value=16.28883934020996

# %% [markdown]
# # visualize best and worst results

# %%
sorted_losses = sorted(losses)

# %%
k = 10
TOP_RESULTS =[losses.index(l) for l in sorted_losses[:k]]
LOWEST_RESULTS =[losses.index(l) for l in sorted_losses[-k:]]

# %%
for min_ind in TOP_RESULTS:
    space = 20
    loss = plot_results_model(
                           load_model, 
                           dateset_train,
                           start_from = min_ind,
                           end_at = min_ind+1,
                           edges_attr = True,
                           figsize = (15,15),
                           plot_input = True,
                           plot_target = True,
                           plot_prediction = True,
                           plot_intention = False, 
                           title = None,

                           printstat = True,       
                           plotstat = True,
        
                           xlim = (-space,space),
                           ylim = (-space,space),
                           loss_stat = "L1"
                          )
# Out:
# 6
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -23.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [ 64.5400,   1.6000,   4.7124,  10.6700,   3.0000,   0.0000],
#         [ 87.7400,   1.6000,   4.7124,   4.7700,   3.0000,   0.0000],
#         [-94.9000,  -1.6000,   1.5708,   0.0000,   1.0000,   0.0000]]),
# edge_index=tensor([[8, 6, 6, 7, 2, 5, 5, 6, 5, 7, 9, 5, 1, 8, 9, 7, 0, 2, 8, 9, 0, 7, 0, 6,
#          7, 5, 6, 7, 9, 5, 1, 6, 7, 5, 8, 1, 0, 8, 3, 6, 5, 8, 6, 9, 5],
#         [9, 3, 9, 3, 4, 3, 9, 1, 6, 1, 3, 1, 4, 0, 1, 2, 3, 3, 4, 2, 1, 9, 2, 0,
#          0, 0, 4, 4, 0, 4, 3, 8, 8, 8, 3, 2, 4, 1, 4, 7, 7, 2, 2, 4, 2]]),
# edge_attr=tensor([ 1.4000,  5.8000,  1.6000,  2.1000, 13.0000, 10.0000,  1.9000,  6.1000,
#          4.6000,  2.1000,  1.8000,  6.6000,  8.5000,  1.6000,  1.7000,  2.3000,
#          7.6000,  6.2000,  1.7000,  1.6000, 13.0000,  1.4000, 16.2000,  6.4000,
#          2.2000,  5.5000, 11.0000,  2.3000,  1.7000,  4.7000, 11.0000,  1.7000,
#          3.3000,  1.5000,  1.6000,  9.0000,  9.2000,  1.6000,  6.1000,  2.2000,
#          2.0000,  1.7000,  7.6000,  1.6000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.2000,   0.0000],
#         [ 37.4900,   1.6000,   4.7124],
#         [ 72.5300,   1.6000,   4.7124],
#         [-87.7800,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[ -4.9096,  -2.1197,   3.4636],
#         [ -9.3996,  -3.9610,   6.2133],
#         [ 10.9637, -10.1897,   6.7145],
#         [-22.5203,  -0.0829,   3.0161],
#         [-10.9302, -12.6168,   5.0507],
#         [-36.0247,  -6.4419,   4.2805],
#         [ -8.2417, -21.4394,   0.7892],
#         [ 39.5150,  -2.9725,   4.2446],
#         [ 65.9424,   3.7841,   3.9211],
#         [-66.8526,  -6.8971,   2.3740]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -23.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [ 64.5400,   1.6000,   4.7124,  10.6700,   3.0000,   0.0000],
#         [ 87.7400,   1.6000,   4.7124,   4.7700,   3.0000,   0.0000],
#         [-94.9000,  -1.6000,   1.5708,   0.0000,   1.0000,   0.0000]]),
# edge_index=tensor([[8, 6, 6, 7, 2, 5, 5, 6, 5, 7, 9, 5, 1, 8, 9, 7, 0, 2, 8, 9, 0, 7, 0, 6,
#          7, 5, 6, 7, 9, 5, 1, 6, 7, 5, 8, 1, 0, 8, 3, 6, 5, 8, 6, 9, 5],
#         [9, 3, 9, 3, 4, 3, 9, 1, 6, 1, 3, 1, 4, 0, 1, 2, 3, 3, 4, 2, 1, 9, 2, 0,
#          0, 0, 4, 4, 0, 4, 3, 8, 8, 8, 3, 2, 4, 1, 4, 7, 7, 2, 2, 4, 2]]),
# edge_attr=tensor([ 1.4000,  5.8000,  1.6000,  2.1000, 13.0000, 10.0000,  1.9000,  6.1000,
#          4.6000,  2.1000,  1.8000,  6.6000,  8.5000,  1.6000,  1.7000,  2.3000,
#          7.6000,  6.2000,  1.7000,  1.6000, 13.0000,  1.4000, 16.2000,  6.4000,
#          2.2000,  5.5000, 11.0000,  2.3000,  1.7000,  4.7000, 11.0000,  1.7000,
#          3.3000,  1.5000,  1.6000,  9.0000,  9.2000,  1.6000,  6.1000,  2.2000,
#          2.0000,  1.7000,  7.6000,  1.6000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.2000,   0.0000],
#         [ 37.4900,   1.6000,   4.7124],
#         [ 72.5300,   1.6000,   4.7124],
#         [-87.7800,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[ -4.9096,  -2.1197,   3.4636],
#         [ -9.3996,  -3.9610,   6.2133],
#         [ 10.9637, -10.1897,   6.7145],
#         [-22.5203,  -0.0829,   3.0161],
#         [-10.9302, -12.6168,   5.0507],
#         [-36.0247,  -6.4419,   4.2805],
#         [ -8.2417, -21.4394,   0.7892],
#         [ 39.5150,  -2.9725,   4.2446],
#         [ 65.9424,   3.7841,   3.9211],
#         [-66.8526,  -6.8971,   2.3740]], grad_fn=<AddBackward0>)
# loss_value=4.34348726272583
# loss_value=4.34348726272583
# 7
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -23.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [  3.4100,   2.7500,   4.9506,   4.6900,   3.0000,   0.0000],
#         [ 25.8400,   1.6000,   4.7124,  11.9000,   3.0000,   0.0000],
#         [-49.5100,  -1.6000,   1.5708,  11.7300,   1.0000,   0.0000]]),
# edge_index=tensor([[8, 6, 6, 7, 2, 5, 5, 6, 5, 7, 9, 5, 1, 8, 9, 7, 0, 2, 8, 9, 0, 7, 0, 6,
#          7, 5, 6, 7, 9, 5, 1, 6, 7, 5, 8, 1, 0, 8, 3, 6, 5, 8, 6, 9, 5],
#         [9, 3, 9, 3, 4, 3, 9, 1, 6, 1, 3, 1, 4, 0, 1, 2, 3, 3, 4, 2, 1, 9, 2, 0,
#          0, 0, 4, 4, 0, 4, 3, 8, 8, 8, 3, 2, 4, 1, 4, 7, 7, 2, 2, 4, 2]]),
# edge_attr=tensor([ 2.7000,  5.8000,  2.9000,  6.2000, 13.0000, 10.0000,  4.7000,  6.1000,
#          4.6000,  8.9000,  3.9000,  6.6000,  8.5000,  5.4000,  3.5000, 16.5000,
#          7.6000,  6.2000,  5.6000,  3.0000, 13.0000,  2.9000, 16.2000,  6.4000,
#         16.0000,  5.5000, 11.0000,  9.0000,  3.2000,  4.7000, 11.0000,  5.3000,
#          6.1000,  4.2000,  4.9000,  9.0000,  9.2000,  5.1000,  6.1000,  6.2000,
#          4.8000,  5.8000,  7.6000,  2.9000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.2000,   0.0000],
#         [  1.6000,  12.1600,   6.2820],
#         [  8.8300,   1.6000,   4.7124],
#         [-38.5600,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[ 3.9756e+00,  3.5946e+00,  3.1205e+00],
#         [ 3.3490e+00, -7.1952e+00,  2.9207e+00],
#         [ 1.6726e+01, -1.5712e+01,  1.0965e+00],
#         [-1.8768e+01,  1.6942e+00, -1.3282e-02],
#         [ 3.4511e+00, -7.6451e+00,  1.0517e+00],
#         [-2.7810e+01,  4.0285e+00,  2.0144e+00],
#         [-2.7385e+00, -1.4986e+01,  2.0514e+00],
#         [-1.0485e+01,  1.5761e+01,  4.5622e+00],
#         [ 7.5482e+00,  3.9961e+00,  4.9445e+00],
#         [-5.0507e+01,  8.8790e+00,  2.4696e+00]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -23.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [  3.4100,   2.7500,   4.9506,   4.6900,   3.0000,   0.0000],
#         [ 25.8400,   1.6000,   4.7124,  11.9000,   3.0000,   0.0000],
#         [-49.5100,  -1.6000,   1.5708,  11.7300,   1.0000,   0.0000]]),
# edge_index=tensor([[8, 6, 6, 7, 2, 5, 5, 6, 5, 7, 9, 5, 1, 8, 9, 7, 0, 2, 8, 9, 0, 7, 0, 6,
#          7, 5, 6, 7, 9, 5, 1, 6, 7, 5, 8, 1, 0, 8, 3, 6, 5, 8, 6, 9, 5],
#         [9, 3, 9, 3, 4, 3, 9, 1, 6, 1, 3, 1, 4, 0, 1, 2, 3, 3, 4, 2, 1, 9, 2, 0,
#          0, 0, 4, 4, 0, 4, 3, 8, 8, 8, 3, 2, 4, 1, 4, 7, 7, 2, 2, 4, 2]]),
# edge_attr=tensor([ 2.7000,  5.8000,  2.9000,  6.2000, 13.0000, 10.0000,  4.7000,  6.1000,
#          4.6000,  8.9000,  3.9000,  6.6000,  8.5000,  5.4000,  3.5000, 16.5000,
#          7.6000,  6.2000,  5.6000,  3.0000, 13.0000,  2.9000, 16.2000,  6.4000,
#         16.0000,  5.5000, 11.0000,  9.0000,  3.2000,  4.7000, 11.0000,  5.3000,
#          6.1000,  4.2000,  4.9000,  9.0000,  9.2000,  5.1000,  6.1000,  6.2000,
#          4.8000,  5.8000,  7.6000,  2.9000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.2000,   0.0000],
#         [  1.6000,  12.1600,   6.2820],
#         [  8.8300,   1.6000,   4.7124],
#         [-38.5600,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[ 3.9756e+00,  3.5946e+00,  3.1205e+00],
#         [ 3.3490e+00, -7.1952e+00,  2.9207e+00],
#         [ 1.6726e+01, -1.5712e+01,  1.0965e+00],
#         [-1.8768e+01,  1.6942e+00, -1.3282e-02],
#         [ 3.4511e+00, -7.6451e+00,  1.0517e+00],
#         [-2.7810e+01,  4.0285e+00,  2.0144e+00],
#         [-2.7385e+00, -1.4986e+01,  2.0514e+00],
#         [-1.0485e+01,  1.5761e+01,  4.5622e+00],
#         [ 7.5482e+00,  3.9961e+00,  4.9445e+00],
#         [-5.0507e+01,  8.8790e+00,  2.4696e+00]], grad_fn=<AddBackward0>)
# loss_value=5.237410068511963
# loss_value=5.237410068511963
# 91
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -23.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [  1.6100,   7.1500,   5.8872,   4.9400,   3.0000,   0.0000],
#         [ 16.4300,   1.6000,   4.7124,   9.4000,   3.0000,   0.0000],
#         [-42.0300,  -1.6000,   1.5708,   7.4800,   1.0000,   0.0000]]),
# edge_index=tensor([[8, 6, 6, 7, 2, 5, 5, 6, 5, 7, 9, 5, 1, 8, 9, 7, 0, 2, 8, 9, 0, 7, 0, 6,
#          7, 5, 6, 7, 9, 5, 1, 6, 7, 5, 8, 1, 0, 8, 3, 6, 5, 8, 6, 9, 5],
#         [9, 3, 9, 3, 4, 3, 9, 1, 6, 1, 3, 1, 4, 0, 1, 2, 3, 3, 4, 2, 1, 9, 2, 0,
#          0, 0, 4, 4, 0, 4, 3, 8, 8, 8, 3, 2, 4, 1, 4, 7, 7, 2, 2, 4, 2]]),
# edge_attr=tensor([ 3.3000,  5.8000,  3.4000,  6.2000, 13.0000, 10.0000,  6.8000,  6.1000,
#          4.6000,  8.9000,  5.1000,  6.6000,  8.5000,  8.1000,  4.3000, 15.3000,
#          7.6000,  6.2000,  8.3000,  3.5000, 13.0000,  3.5000, 16.2000,  6.4000,
#         15.8000,  5.5000, 11.0000,  8.5000,  3.9000,  4.7000, 11.0000,  6.0000,
#          9.3000,  4.4000,  5.6000,  9.0000,  9.2000,  7.6000,  6.1000,  5.9000,
#          4.8000,  8.9000,  7.6000,  3.5000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.2000,   0.0000],
#         [  1.6000,  18.6300,   0.0000],
#         [  3.1000,   2.9400,   4.9901],
#         [-38.3400,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[  3.0308,   0.1495,   2.8975],
#         [  1.2551, -10.2419,   1.9325],
#         [  8.7807, -23.5405,  -0.3423],
#         [-30.8383,   7.1492,   0.7058],
#         [ -0.5223,  -1.3498,   2.1966],
#         [-19.5122,  -0.2170,   2.6412],
#         [  1.1649, -12.6013,   1.0715],
#         [-15.6175,  23.7923,   5.0759],
#         [  2.8873,   3.0516,   3.9083],
#         [-35.1112,   9.2587,   2.1027]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -23.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [  1.6100,   7.1500,   5.8872,   4.9400,   3.0000,   0.0000],
#         [ 16.4300,   1.6000,   4.7124,   9.4000,   3.0000,   0.0000],
#         [-42.0300,  -1.6000,   1.5708,   7.4800,   1.0000,   0.0000]]),
# edge_index=tensor([[8, 6, 6, 7, 2, 5, 5, 6, 5, 7, 9, 5, 1, 8, 9, 7, 0, 2, 8, 9, 0, 7, 0, 6,
#          7, 5, 6, 7, 9, 5, 1, 6, 7, 5, 8, 1, 0, 8, 3, 6, 5, 8, 6, 9, 5],
#         [9, 3, 9, 3, 4, 3, 9, 1, 6, 1, 3, 1, 4, 0, 1, 2, 3, 3, 4, 2, 1, 9, 2, 0,
#          0, 0, 4, 4, 0, 4, 3, 8, 8, 8, 3, 2, 4, 1, 4, 7, 7, 2, 2, 4, 2]]),
# edge_attr=tensor([ 3.3000,  5.8000,  3.4000,  6.2000, 13.0000, 10.0000,  6.8000,  6.1000,
#          4.6000,  8.9000,  5.1000,  6.6000,  8.5000,  8.1000,  4.3000, 15.3000,
#          7.6000,  6.2000,  8.3000,  3.5000, 13.0000,  3.5000, 16.2000,  6.4000,
#         15.8000,  5.5000, 11.0000,  8.5000,  3.9000,  4.7000, 11.0000,  6.0000,
#          9.3000,  4.4000,  5.6000,  9.0000,  9.2000,  7.6000,  6.1000,  5.9000,
#          4.8000,  8.9000,  7.6000,  3.5000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.2000,   0.0000],
#         [  1.6000,  18.6300,   0.0000],
#         [  3.1000,   2.9400,   4.9901],
#         [-38.3400,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[  3.0308,   0.1495,   2.8975],
#         [  1.2551, -10.2419,   1.9325],
#         [  8.7807, -23.5405,  -0.3423],
#         [-30.8383,   7.1492,   0.7058],
#         [ -0.5223,  -1.3498,   2.1966],
#         [-19.5122,  -0.2170,   2.6412],
#         [  1.1649, -12.6013,   1.0715],
#         [-15.6175,  23.7923,   5.0759],
#         [  2.8873,   3.0516,   3.9083],
#         [-35.1112,   9.2587,   2.1027]], grad_fn=<AddBackward0>)
# loss_value=5.609288692474365
# loss_value=5.609288692474365
# 121
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,   9.5200,   6.1910,   5.0800,   3.0000,   0.0000],
#         [ 11.3500,   1.6000,   4.7124,   3.0700,   1.0000,   0.0000],
#         [-15.8400,  -1.6000,   1.5708,   1.0300,   0.0000,   0.0000],
#         [  1.6000, -25.3400,   0.0000,  14.1000,   1.0000,   0.0000],
#         [-54.8900,  -1.6000,   1.5708,  11.5000,   1.0000,   0.0000],
#         [ 82.1700,   1.6000,   4.7124,   6.7800,   1.0000,   0.0000],
#         [  1.6000, -88.9800,   0.0000,   4.1300,   1.0000,   0.0000]]),
# edge_index=tensor([[0, 5, 4, 2, 6, 1, 3, 1, 0, 4, 4, 1, 2, 0, 0, 3, 1, 0, 1, 2, 2, 3, 0, 2,
#          3, 0, 5, 1],
#         [6, 6, 7, 7, 7, 6, 7, 3, 5, 5, 6, 4, 6, 3, 2, 6, 5, 4, 2, 5, 3, 5, 1, 4,
#          4, 7, 7, 7]]),
# edge_attr=tensor([ 1.8000,  1.6000,  1.9000,  1.6000,  1.5000,  1.8000,  1.7000,  8.7000,
#          2.9000,  2.6000,  1.8000,  5.3000,  1.9000, 12.8000, 11.2000,  1.7000,
#          2.7000,  5.8000, 12.7000,  2.6000,  8.1000,  3.1000, 13.8000,  5.6000,
#          5.6000,  1.7000,  1.6000,  1.6000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [  1.6000,  25.6900,   0.0000],
#         [ -1.1400,   1.6000,   4.7124],
#         [-15.7200,  -1.6000,   1.5708],
#         [  1.6000,  -9.8300,   0.0000],
#         [-31.7100,  -1.6000,   1.5708],
#         [ 63.4600,   1.6000,   4.7124],
#         [  1.6000, -74.6100,   0.0000]])
#
#  PREDICTION
# tensor([[-13.6448,   9.8413,   1.0154],
#         [ -6.9495,  15.1751,   0.0906],
#         [ -1.0137,   6.1667,  -0.3104],
#         [-24.6843,  10.3020,   0.2249],
#         [  7.7514,   2.3908,  -1.9267],
#         [-41.6507,  17.9880,   1.0892],
#         [ 74.2639,   3.0389,   3.1177],
#         [  1.8779, -68.6745,   1.5025]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,   9.5200,   6.1910,   5.0800,   3.0000,   0.0000],
#         [ 11.3500,   1.6000,   4.7124,   3.0700,   1.0000,   0.0000],
#         [-15.8400,  -1.6000,   1.5708,   1.0300,   0.0000,   0.0000],
#         [  1.6000, -25.3400,   0.0000,  14.1000,   1.0000,   0.0000],
#         [-54.8900,  -1.6000,   1.5708,  11.5000,   1.0000,   0.0000],
#         [ 82.1700,   1.6000,   4.7124,   6.7800,   1.0000,   0.0000],
#         [  1.6000, -88.9800,   0.0000,   4.1300,   1.0000,   0.0000]]),
# edge_index=tensor([[0, 5, 4, 2, 6, 1, 3, 1, 0, 4, 4, 1, 2, 0, 0, 3, 1, 0, 1, 2, 2, 3, 0, 2,
#          3, 0, 5, 1],
#         [6, 6, 7, 7, 7, 6, 7, 3, 5, 5, 6, 4, 6, 3, 2, 6, 5, 4, 2, 5, 3, 5, 1, 4,
#          4, 7, 7, 7]]),
# edge_attr=tensor([ 1.8000,  1.6000,  1.9000,  1.6000,  1.5000,  1.8000,  1.7000,  8.7000,
#          2.9000,  2.6000,  1.8000,  5.3000,  1.9000, 12.8000, 11.2000,  1.7000,
#          2.7000,  5.8000, 12.7000,  2.6000,  8.1000,  3.1000, 13.8000,  5.6000,
#          5.6000,  1.7000,  1.6000,  1.6000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [  1.6000,  25.6900,   0.0000],
#         [ -1.1400,   1.6000,   4.7124],
#         [-15.7200,  -1.6000,   1.5708],
#         [  1.6000,  -9.8300,   0.0000],
#         [-31.7100,  -1.6000,   1.5708],
#         [ 63.4600,   1.6000,   4.7124],
#         [  1.6000, -74.6100,   0.0000]])
#
#  PREDICTION
# tensor([[-13.6448,   9.8413,   1.0154],
#         [ -6.9495,  15.1751,   0.0906],
#         [ -1.0137,   6.1667,  -0.3104],
#         [-24.6843,  10.3020,   0.2249],
#         [  7.7514,   2.3908,  -1.9267],
#         [-41.6507,  17.9880,   1.0892],
#         [ 74.2639,   3.0389,   3.1177],
#         [  1.8779, -68.6745,   1.5025]], grad_fn=<AddBackward0>)
# loss_value=5.849463939666748
# loss_value=5.849463939666748
# 63
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -23.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [  1.6000,  18.6300,   0.0000,   6.4700,   3.0000,   0.0000],
#         [  3.1000,   2.9400,   4.9901,   6.0300,   3.0000,   0.0000],
#         [-38.3400,  -1.6000,   1.5708,   0.2300,   1.0000,   0.0000]]),
# edge_index=tensor([[8, 6, 6, 7, 2, 5, 5, 6, 5, 7, 9, 5, 1, 8, 9, 7, 0, 2, 8, 9, 0, 7, 0, 6,
#          7, 5, 6, 7, 9, 5, 1, 6, 7, 5, 8, 1, 0, 8, 3, 6, 5, 8, 6, 9, 5],
#         [9, 3, 9, 3, 4, 3, 9, 1, 6, 1, 3, 1, 4, 0, 1, 2, 3, 3, 4, 2, 1, 9, 2, 0,
#          0, 0, 4, 4, 0, 4, 3, 8, 8, 8, 3, 2, 4, 1, 4, 7, 7, 2, 2, 4, 2]]),
# edge_attr=tensor([ 3.8000,  5.8000,  3.7000,  5.9000, 13.0000, 10.0000,  9.1000,  6.1000,
#          4.6000,  7.2000,  5.9000,  6.6000,  8.5000, 16.1000,  4.8000,  7.2000,
#          7.6000,  6.2000,  9.0000,  3.8000, 13.0000,  3.7000, 16.2000,  6.4000,
#          7.5000,  5.5000, 11.0000,  6.8000,  4.3000,  4.7000, 11.0000,  6.2000,
#          8.5000,  4.8000,  6.2000,  9.0000,  9.2000,  8.9000,  6.1000,  5.5000,
#          4.6000, 16.4000,  7.6000,  3.8000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.2000,   0.0000],
#         [  1.6000,  38.3300,   0.0000],
#         [  1.6000,  15.7400,   0.0000],
#         [-38.2200,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[-10.5137,   2.7780,   4.1311],
#         [ -2.2434,  -2.6061,   4.1756],
#         [ 10.5528,  -3.9478,   6.6138],
#         [-20.1056,  11.7659,   2.5705],
#         [ 11.5833,   1.1873,   1.2871],
#         [-28.0588,  -4.5021,   3.2603],
#         [-17.7360, -19.1371,   0.9863],
#         [ -9.1508,  32.7030,   3.2193],
#         [ -9.1469,  11.3038,   4.4809],
#         [-33.4645,   6.9863,   2.1711]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -23.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [  1.6000,  18.6300,   0.0000,   6.4700,   3.0000,   0.0000],
#         [  3.1000,   2.9400,   4.9901,   6.0300,   3.0000,   0.0000],
#         [-38.3400,  -1.6000,   1.5708,   0.2300,   1.0000,   0.0000]]),
# edge_index=tensor([[8, 6, 6, 7, 2, 5, 5, 6, 5, 7, 9, 5, 1, 8, 9, 7, 0, 2, 8, 9, 0, 7, 0, 6,
#          7, 5, 6, 7, 9, 5, 1, 6, 7, 5, 8, 1, 0, 8, 3, 6, 5, 8, 6, 9, 5],
#         [9, 3, 9, 3, 4, 3, 9, 1, 6, 1, 3, 1, 4, 0, 1, 2, 3, 3, 4, 2, 1, 9, 2, 0,
#          0, 0, 4, 4, 0, 4, 3, 8, 8, 8, 3, 2, 4, 1, 4, 7, 7, 2, 2, 4, 2]]),
# edge_attr=tensor([ 3.8000,  5.8000,  3.7000,  5.9000, 13.0000, 10.0000,  9.1000,  6.1000,
#          4.6000,  7.2000,  5.9000,  6.6000,  8.5000, 16.1000,  4.8000,  7.2000,
#          7.6000,  6.2000,  9.0000,  3.8000, 13.0000,  3.7000, 16.2000,  6.4000,
#          7.5000,  5.5000, 11.0000,  6.8000,  4.3000,  4.7000, 11.0000,  6.2000,
#          8.5000,  4.8000,  6.2000,  9.0000,  9.2000,  8.9000,  6.1000,  5.5000,
#          4.6000, 16.4000,  7.6000,  3.8000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.2000,   0.0000],
#         [  1.6000,  38.3300,   0.0000],
#         [  1.6000,  15.7400,   0.0000],
#         [-38.2200,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[-10.5137,   2.7780,   4.1311],
#         [ -2.2434,  -2.6061,   4.1756],
#         [ 10.5528,  -3.9478,   6.6138],
#         [-20.1056,  11.7659,   2.5705],
#         [ 11.5833,   1.1873,   1.2871],
#         [-28.0588,  -4.5021,   3.2603],
#         [-17.7360, -19.1371,   0.9863],
#         [ -9.1508,  32.7030,   3.2193],
#         [ -9.1469,  11.3038,   4.4809],
#         [-33.4645,   6.9863,   2.1711]], grad_fn=<AddBackward0>)
# loss_value=5.8859100341796875
# loss_value=5.8859100341796875
# 32
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -23.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [  7.8500,   1.6000,   4.7124,   5.3800,   3.0000,   0.0000],
#         [ 37.7400,   1.6000,   4.7124,  13.3100,   3.0000,   0.0000],
#         [-61.2400,  -1.6000,   1.5708,  10.8600,   1.0000,   0.0000]]),
# edge_index=tensor([[8, 6, 6, 7, 2, 5, 5, 6, 5, 7, 9, 5, 1, 8, 9, 7, 0, 2, 8, 9, 0, 7, 0, 6,
#          7, 5, 6, 7, 9, 5, 1, 6, 7, 5, 8, 1, 0, 8, 3, 6, 5, 8, 6, 9, 5],
#         [9, 3, 9, 3, 4, 3, 9, 1, 6, 1, 3, 1, 4, 0, 1, 2, 3, 3, 4, 2, 1, 9, 2, 0,
#          0, 0, 4, 4, 0, 4, 3, 8, 8, 8, 3, 2, 4, 1, 4, 7, 7, 2, 2, 4, 2]]),
# edge_attr=tensor([ 2.1000,  5.8000,  2.4000,  5.9000, 13.0000, 10.0000,  3.2000,  6.1000,
#          4.6000,  8.4000,  2.9000,  6.6000,  8.5000,  3.7000,  2.7000, 16.3000,
#          7.6000,  6.2000,  3.8000,  2.4000, 13.0000,  2.3000, 16.2000,  6.4000,
#         15.1000,  5.5000, 11.0000,  9.0000,  2.5000,  4.7000, 11.0000,  3.7000,
#          4.3000,  3.3000,  3.4000,  9.0000,  9.2000,  3.5000,  6.1000,  6.3000,
#          4.6000,  3.9000,  7.6000,  2.4000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.2000,   0.0000],
#         [  1.6100,   7.1500,   5.8872],
#         [ 16.4300,   1.6000,   4.7124],
#         [-42.0300,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[ 6.1572e+00,  7.7511e+00,  2.4111e+00],
#         [ 8.6881e+00, -5.1154e+00,  2.3687e+00],
#         [ 2.0313e+01, -5.7955e+00,  5.6592e-01],
#         [-1.2968e+01,  2.2177e+00, -1.4700e-02],
#         [ 1.4362e+00, -6.5315e+00,  5.2423e-01],
#         [-3.1055e+01,  3.7216e+00,  2.2395e+00],
#         [-3.2436e+00, -1.7410e+01,  2.0336e+00],
#         [-7.9648e+00,  1.1454e+01,  3.1825e+00],
#         [ 5.7619e+00,  8.2870e+00,  4.5757e+00],
#         [-5.9470e+01,  4.2235e+00,  1.3419e+00]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -23.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [  7.8500,   1.6000,   4.7124,   5.3800,   3.0000,   0.0000],
#         [ 37.7400,   1.6000,   4.7124,  13.3100,   3.0000,   0.0000],
#         [-61.2400,  -1.6000,   1.5708,  10.8600,   1.0000,   0.0000]]),
# edge_index=tensor([[8, 6, 6, 7, 2, 5, 5, 6, 5, 7, 9, 5, 1, 8, 9, 7, 0, 2, 8, 9, 0, 7, 0, 6,
#          7, 5, 6, 7, 9, 5, 1, 6, 7, 5, 8, 1, 0, 8, 3, 6, 5, 8, 6, 9, 5],
#         [9, 3, 9, 3, 4, 3, 9, 1, 6, 1, 3, 1, 4, 0, 1, 2, 3, 3, 4, 2, 1, 9, 2, 0,
#          0, 0, 4, 4, 0, 4, 3, 8, 8, 8, 3, 2, 4, 1, 4, 7, 7, 2, 2, 4, 2]]),
# edge_attr=tensor([ 2.1000,  5.8000,  2.4000,  5.9000, 13.0000, 10.0000,  3.2000,  6.1000,
#          4.6000,  8.4000,  2.9000,  6.6000,  8.5000,  3.7000,  2.7000, 16.3000,
#          7.6000,  6.2000,  3.8000,  2.4000, 13.0000,  2.3000, 16.2000,  6.4000,
#         15.1000,  5.5000, 11.0000,  9.0000,  2.5000,  4.7000, 11.0000,  3.7000,
#          4.3000,  3.3000,  3.4000,  9.0000,  9.2000,  3.5000,  6.1000,  6.3000,
#          4.6000,  3.9000,  7.6000,  2.4000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.2000,   0.0000],
#         [  1.6100,   7.1500,   5.8872],
#         [ 16.4300,   1.6000,   4.7124],
#         [-42.0300,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[ 6.1572e+00,  7.7511e+00,  2.4111e+00],
#         [ 8.6881e+00, -5.1154e+00,  2.3687e+00],
#         [ 2.0313e+01, -5.7955e+00,  5.6592e-01],
#         [-1.2968e+01,  2.2177e+00, -1.4700e-02],
#         [ 1.4362e+00, -6.5315e+00,  5.2423e-01],
#         [-3.1055e+01,  3.7216e+00,  2.2395e+00],
#         [-3.2436e+00, -1.7410e+01,  2.0336e+00],
#         [-7.9648e+00,  1.1454e+01,  3.1825e+00],
#         [ 5.7619e+00,  8.2870e+00,  4.5757e+00],
#         [-5.9470e+01,  4.2235e+00,  1.3419e+00]], grad_fn=<AddBackward0>)
# loss_value=5.900178909301758
# loss_value=5.900178909301758
# 92
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -23.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [  1.6000,  12.1600,   6.2820,   5.0100,   3.0000,   0.0000],
#         [  8.8300,   1.6000,   4.7124,   7.6000,   3.0000,   0.0000],
#         [-38.5600,  -1.6000,   1.5708,   3.4700,   1.0000,   0.0000]]),
# edge_index=tensor([[8, 6, 6, 7, 2, 5, 5, 6, 5, 7, 9, 5, 1, 8, 9, 7, 0, 2, 8, 9, 0, 7, 0, 6,
#          7, 5, 6, 7, 9, 5, 1, 6, 7, 5, 8, 1, 0, 8, 3, 6, 5, 8, 6, 9, 5],
#         [9, 3, 9, 3, 4, 3, 9, 1, 6, 1, 3, 1, 4, 0, 1, 2, 3, 3, 4, 2, 1, 9, 2, 0,
#          0, 0, 4, 4, 0, 4, 3, 8, 8, 8, 3, 2, 4, 1, 4, 7, 7, 2, 2, 4, 2]]),
# edge_attr=tensor([ 3.7000,  5.8000,  3.7000,  6.1000, 13.0000, 10.0000,  9.0000,  6.1000,
#          4.6000,  8.6000,  5.9000,  6.6000,  8.5000, 14.0000,  4.8000, 10.7000,
#          7.6000,  6.2000,  9.0000,  3.8000, 13.0000,  3.8000, 16.2000,  6.4000,
#         11.2000,  5.5000, 11.0000,  8.1000,  4.2000,  4.7000, 11.0000,  6.2000,
#         12.1000,  4.6000,  5.9000,  9.0000,  9.2000,  8.3000,  6.1000,  5.7000,
#          4.7000, 15.2000,  7.6000,  3.8000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.2000,   0.0000],
#         [  1.6000,  27.6100,   0.0000],
#         [  1.6000,   7.8700,   6.0134],
#         [-38.2400,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[ -2.0141,  -7.2829,   2.5693],
#         [ -0.6773, -13.3252,   4.1361],
#         [ -0.5388, -18.2879,   5.0166],
#         [-30.9695,   9.0613,   1.3537],
#         [ -3.4297,  -1.9399,   2.1440],
#         [-15.9625,  -1.1084,   3.5508],
#         [ -0.7622,  -7.1589,  -0.4414],
#         [-15.4474,  28.5239,   3.4324],
#         [  8.0529,   3.3801,   2.8037],
#         [-24.9129,   2.7813,   1.9266]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -23.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [  1.6000,  12.1600,   6.2820,   5.0100,   3.0000,   0.0000],
#         [  8.8300,   1.6000,   4.7124,   7.6000,   3.0000,   0.0000],
#         [-38.5600,  -1.6000,   1.5708,   3.4700,   1.0000,   0.0000]]),
# edge_index=tensor([[8, 6, 6, 7, 2, 5, 5, 6, 5, 7, 9, 5, 1, 8, 9, 7, 0, 2, 8, 9, 0, 7, 0, 6,
#          7, 5, 6, 7, 9, 5, 1, 6, 7, 5, 8, 1, 0, 8, 3, 6, 5, 8, 6, 9, 5],
#         [9, 3, 9, 3, 4, 3, 9, 1, 6, 1, 3, 1, 4, 0, 1, 2, 3, 3, 4, 2, 1, 9, 2, 0,
#          0, 0, 4, 4, 0, 4, 3, 8, 8, 8, 3, 2, 4, 1, 4, 7, 7, 2, 2, 4, 2]]),
# edge_attr=tensor([ 3.7000,  5.8000,  3.7000,  6.1000, 13.0000, 10.0000,  9.0000,  6.1000,
#          4.6000,  8.6000,  5.9000,  6.6000,  8.5000, 14.0000,  4.8000, 10.7000,
#          7.6000,  6.2000,  9.0000,  3.8000, 13.0000,  3.8000, 16.2000,  6.4000,
#         11.2000,  5.5000, 11.0000,  8.1000,  4.2000,  4.7000, 11.0000,  6.2000,
#         12.1000,  4.6000,  5.9000,  9.0000,  9.2000,  8.3000,  6.1000,  5.7000,
#          4.7000, 15.2000,  7.6000,  3.8000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.2000,   0.0000],
#         [  1.6000,  27.6100,   0.0000],
#         [  1.6000,   7.8700,   6.0134],
#         [-38.2400,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[ -2.0141,  -7.2829,   2.5693],
#         [ -0.6773, -13.3252,   4.1361],
#         [ -0.5388, -18.2879,   5.0166],
#         [-30.9695,   9.0613,   1.3537],
#         [ -3.4297,  -1.9399,   2.1440],
#         [-15.9625,  -1.1084,   3.5508],
#         [ -0.7622,  -7.1589,  -0.4414],
#         [-15.4474,  28.5239,   3.4324],
#         [  8.0529,   3.3801,   2.8037],
#         [-24.9129,   2.7813,   1.9266]], grad_fn=<AddBackward0>)
# loss_value=6.2889862060546875
# loss_value=6.2889862060546875
# 10
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -23.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [ 37.4900,   1.6000,   4.7124,  14.6800,   3.0000,   0.0000],
#         [ 72.5300,   1.6000,   4.7124,   8.4900,   3.0000,   0.0000],
#         [-87.7800,  -1.6000,   1.5708,   4.5600,   1.0000,   0.0000]]),
# edge_index=tensor([[8, 6, 6, 7, 2, 5, 5, 6, 5, 7, 9, 5, 1, 8, 9, 7, 0, 2, 8, 9, 0, 7, 0, 6,
#          7, 5, 6, 7, 9, 5, 1, 6, 7, 5, 8, 1, 0, 8, 3, 6, 5, 8, 6, 9, 5],
#         [9, 3, 9, 3, 4, 3, 9, 1, 6, 1, 3, 1, 4, 0, 1, 2, 3, 3, 4, 2, 1, 9, 2, 0,
#          0, 0, 4, 4, 0, 4, 3, 8, 8, 8, 3, 2, 4, 1, 4, 7, 7, 2, 2, 4, 2]]),
# edge_attr=tensor([ 1.4000,  5.8000,  1.6000,  3.5000, 13.0000, 10.0000,  2.0000,  6.1000,
#          4.6000,  3.6000,  1.9000,  6.6000,  8.5000,  2.0000,  1.8000,  4.0000,
#          7.6000,  6.2000,  2.1000,  1.7000, 13.0000,  1.5000, 16.2000,  6.4000,
#          3.8000,  5.5000, 11.0000,  4.0000,  1.7000,  4.7000, 11.0000,  2.1000,
#          2.8000,  1.9000,  1.9000,  9.0000,  9.2000,  2.0000,  6.1000,  3.8000,
#          3.4000,  2.1000,  7.6000,  1.7000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.2000,   0.0000],
#         [ 13.2300,   1.6000,   4.7124],
#         [ 51.0500,   1.6000,   4.7124],
#         [-72.1000,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[  3.5162,  12.9102,   3.1388],
#         [ 12.5931,  -4.0615,   2.5192],
#         [ 20.9681, -17.5648,   4.5505],
#         [ -6.0821,   3.9942,   1.8246],
#         [ -3.6901,  -6.6307,   4.2968],
#         [-41.9724,  -7.7070,   3.1315],
#         [ -7.5821, -20.8819,   1.0359],
#         [  4.0788,  -0.2541,   3.4741],
#         [ 48.5742,   6.3606,   3.9851],
#         [-70.8959,   0.3012,   1.2121]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -23.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [ 37.4900,   1.6000,   4.7124,  14.6800,   3.0000,   0.0000],
#         [ 72.5300,   1.6000,   4.7124,   8.4900,   3.0000,   0.0000],
#         [-87.7800,  -1.6000,   1.5708,   4.5600,   1.0000,   0.0000]]),
# edge_index=tensor([[8, 6, 6, 7, 2, 5, 5, 6, 5, 7, 9, 5, 1, 8, 9, 7, 0, 2, 8, 9, 0, 7, 0, 6,
#          7, 5, 6, 7, 9, 5, 1, 6, 7, 5, 8, 1, 0, 8, 3, 6, 5, 8, 6, 9, 5],
#         [9, 3, 9, 3, 4, 3, 9, 1, 6, 1, 3, 1, 4, 0, 1, 2, 3, 3, 4, 2, 1, 9, 2, 0,
#          0, 0, 4, 4, 0, 4, 3, 8, 8, 8, 3, 2, 4, 1, 4, 7, 7, 2, 2, 4, 2]]),
# edge_attr=tensor([ 1.4000,  5.8000,  1.6000,  3.5000, 13.0000, 10.0000,  2.0000,  6.1000,
#          4.6000,  3.6000,  1.9000,  6.6000,  8.5000,  2.0000,  1.8000,  4.0000,
#          7.6000,  6.2000,  2.1000,  1.7000, 13.0000,  1.5000, 16.2000,  6.4000,
#          3.8000,  5.5000, 11.0000,  4.0000,  1.7000,  4.7000, 11.0000,  2.1000,
#          2.8000,  1.9000,  1.9000,  9.0000,  9.2000,  2.0000,  6.1000,  3.8000,
#          3.4000,  2.1000,  7.6000,  1.7000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.2000,   0.0000],
#         [ 13.2300,   1.6000,   4.7124],
#         [ 51.0500,   1.6000,   4.7124],
#         [-72.1000,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[  3.5162,  12.9102,   3.1388],
#         [ 12.5931,  -4.0615,   2.5192],
#         [ 20.9681, -17.5648,   4.5505],
#         [ -6.0821,   3.9942,   1.8246],
#         [ -3.6901,  -6.6307,   4.2968],
#         [-41.9724,  -7.7070,   3.1315],
#         [ -7.5821, -20.8819,   1.0359],
#         [  4.0788,  -0.2541,   3.4741],
#         [ 48.5742,   6.3606,   3.9851],
#         [-70.8959,   0.3012,   1.2121]], grad_fn=<AddBackward0>)
# loss_value=6.318343162536621
# loss_value=6.318343162536621
# 86
#
#  INPUT
# x=tensor([[ -2.2300,   1.6000,   4.7124,   5.0700,   1.0000,   0.0000],
#         [ 11.1200,   1.6000,   4.7124,   2.8900,   3.0000,   0.0000],
#         [ 21.6900,   1.6000,   4.7124,   1.5100,   1.0000,   0.0000],
#         [ 30.7000,   1.6000,   4.7124,   0.0000,   3.0000,   0.0000],
#         [ 38.2100,   1.6000,   4.7124,   0.0000,   3.0000,   0.0000],
#         [ 45.7100,   1.6000,   4.7124,   0.0000,   1.0000,   1.0000],
#         [ -8.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [ 53.5800,   1.6000,   4.7124,   0.3700,   3.0000,   0.0000],
#         [  1.6000, -70.2100,   0.0000,   8.2300,   1.0000,   0.0000]]),
# edge_index=tensor([[6, 8, 1, 1, 7, 1, 0, 3, 4, 3, 3, 2, 2, 1, 0, 0, 4, 2, 1, 5, 2, 6, 0, 1,
#          4, 7, 0, 0, 0, 5, 3, 4, 3, 2, 2, 1, 1, 0, 5, 3, 5, 4, 0, 2, 6],
#         [7, 9, 3, 2, 9, 4, 6, 5, 8, 9, 7, 3, 8, 8, 9, 7, 6, 5, 5, 8, 6, 8, 4, 6,
#          5, 8, 3, 2, 1, 6, 4, 7, 8, 9, 7, 9, 7, 8, 9, 6, 7, 9, 5, 4, 9]]),
# edge_attr=tensor([13.0000,  2.0000,  5.9000,  9.3000,  2.1000,  4.4000, 19.4000,  5.5000,
#          5.2000,  2.0000,  4.4000,  8.8000,  3.5000,  3.1000,  2.1000,  9.9000,
#          3.7000,  4.3000,  3.6000,  8.3000,  6.3000,  2.7000,  3.8000, 11.5000,
#          8.9000,  2.6000,  4.8000,  6.7000, 12.6000,  3.1000,  9.3000,  3.5000,
#          4.1000,  2.1000,  5.9000,  2.1000,  8.2000,  2.8000,  2.0000,  4.6000,
#          3.0000,  2.0000,  3.2000,  5.6000,  2.1000])
#
#
#  TARGET
# tensor([[-18.2100,   1.6000,   4.7124],
#         [  1.9300,   4.8700,   5.4116],
#         [ 15.5500,   1.6000,   4.7124],
#         [ 27.3900,   1.6000,   4.7124],
#         [ 37.5100,   1.6000,   4.7124],
#         [ 45.7100,   1.6000,   4.7124],
#         [ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [ 53.2600,   1.6000,   4.7124],
#         [  1.6000, -47.8400,   0.0000]])
#
#  PREDICTION
# tensor([[  4.7528,   7.0347,   1.5069],
#         [ -6.2275,  20.6594,   2.3164],
#         [ -1.1121,   5.3283,   2.2130],
#         [ 21.4010,  10.6571,   1.7223],
#         [ 39.7130,  -3.2335,   3.8572],
#         [ 45.8953,  -1.9233,   3.4868],
#         [-16.1763,  -8.2035,   4.6870],
#         [-24.3652, -17.6358,  -1.0126],
#         [ 35.4433,  -3.5546,   0.8144],
#         [ -2.9771, -43.3476,  -0.2797]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -2.2300,   1.6000,   4.7124,   5.0700,   1.0000,   0.0000],
#         [ 11.1200,   1.6000,   4.7124,   2.8900,   3.0000,   0.0000],
#         [ 21.6900,   1.6000,   4.7124,   1.5100,   1.0000,   0.0000],
#         [ 30.7000,   1.6000,   4.7124,   0.0000,   3.0000,   0.0000],
#         [ 38.2100,   1.6000,   4.7124,   0.0000,   3.0000,   0.0000],
#         [ 45.7100,   1.6000,   4.7124,   0.0000,   1.0000,   1.0000],
#         [ -8.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [ 53.5800,   1.6000,   4.7124,   0.3700,   3.0000,   0.0000],
#         [  1.6000, -70.2100,   0.0000,   8.2300,   1.0000,   0.0000]]),
# edge_index=tensor([[6, 8, 1, 1, 7, 1, 0, 3, 4, 3, 3, 2, 2, 1, 0, 0, 4, 2, 1, 5, 2, 6, 0, 1,
#          4, 7, 0, 0, 0, 5, 3, 4, 3, 2, 2, 1, 1, 0, 5, 3, 5, 4, 0, 2, 6],
#         [7, 9, 3, 2, 9, 4, 6, 5, 8, 9, 7, 3, 8, 8, 9, 7, 6, 5, 5, 8, 6, 8, 4, 6,
#          5, 8, 3, 2, 1, 6, 4, 7, 8, 9, 7, 9, 7, 8, 9, 6, 7, 9, 5, 4, 9]]),
# edge_attr=tensor([13.0000,  2.0000,  5.9000,  9.3000,  2.1000,  4.4000, 19.4000,  5.5000,
#          5.2000,  2.0000,  4.4000,  8.8000,  3.5000,  3.1000,  2.1000,  9.9000,
#          3.7000,  4.3000,  3.6000,  8.3000,  6.3000,  2.7000,  3.8000, 11.5000,
#          8.9000,  2.6000,  4.8000,  6.7000, 12.6000,  3.1000,  9.3000,  3.5000,
#          4.1000,  2.1000,  5.9000,  2.1000,  8.2000,  2.8000,  2.0000,  4.6000,
#          3.0000,  2.0000,  3.2000,  5.6000,  2.1000])
#
#
#  TARGET
# tensor([[-18.2100,   1.6000,   4.7124],
#         [  1.9300,   4.8700,   5.4116],
#         [ 15.5500,   1.6000,   4.7124],
#         [ 27.3900,   1.6000,   4.7124],
#         [ 37.5100,   1.6000,   4.7124],
#         [ 45.7100,   1.6000,   4.7124],
#         [ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [ 53.2600,   1.6000,   4.7124],
#         [  1.6000, -47.8400,   0.0000]])
#
#  PREDICTION
# tensor([[  4.7528,   7.0347,   1.5069],
#         [ -6.2275,  20.6594,   2.3164],
#         [ -1.1121,   5.3283,   2.2130],
#         [ 21.4010,  10.6571,   1.7223],
#         [ 39.7130,  -3.2335,   3.8572],
#         [ 45.8953,  -1.9233,   3.4868],
#         [-16.1763,  -8.2035,   4.6870],
#         [-24.3652, -17.6358,  -1.0126],
#         [ 35.4433,  -3.5546,   0.8144],
#         [ -2.9771, -43.3476,  -0.2797]], grad_fn=<AddBackward0>)
# loss_value=6.453192710876465
# loss_value=6.453192710876465
# 59
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -34.1300,   0.0000,  11.0700,   1.0000,   0.0000]]),
# edge_index=tensor([[6, 2, 5, 6, 5, 5, 1, 0, 2, 0, 0, 6, 5, 6, 5, 1, 1, 0, 3, 6, 5],
#         [3, 4, 3, 1, 6, 1, 4, 3, 3, 1, 2, 0, 0, 4, 4, 3, 2, 4, 4, 2, 2]]),
# edge_attr=tensor([ 4.1000, 13.0000, 10.0000,  4.3000,  4.0000,  6.6000,  8.5000,  7.6000,
#          6.2000, 13.0000, 16.2000,  4.4000,  5.5000,  5.6000,  4.7000, 11.0000,
#          9.0000,  9.2000,  6.1000,  4.8000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.9900,   0.0000]])
#
#  PREDICTION
# tensor([[ -9.1720,  -3.0556,   4.4184],
#         [-10.2650,   2.3525,   2.3047],
#         [ 16.4664,   6.0770,   2.2834],
#         [-38.3309,  16.0141,   4.2741],
#         [ -8.6856,  -2.2378,   2.4777],
#         [-37.9621,  -0.7980,   2.5233],
#         [-13.5702, -22.0107,   1.7198]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -8.2000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-23.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [  1.6000, -15.7000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-30.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000, -34.1300,   0.0000,  11.0700,   1.0000,   0.0000]]),
# edge_index=tensor([[6, 2, 5, 6, 5, 5, 1, 0, 2, 0, 0, 6, 5, 6, 5, 1, 1, 0, 3, 6, 5],
#         [3, 4, 3, 1, 6, 1, 4, 3, 3, 1, 2, 0, 0, 4, 4, 3, 2, 4, 4, 2, 2]]),
# edge_attr=tensor([ 4.1000, 13.0000, 10.0000,  4.3000,  4.0000,  6.6000,  8.5000,  7.6000,
#          6.2000, 13.0000, 16.2000,  4.4000,  5.5000,  5.6000,  4.7000, 11.0000,
#          9.0000,  9.2000,  6.1000,  4.8000,  4.8000])
#
#
#  TARGET
# tensor([[ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.2000,  -1.6000,   1.5708],
#         [  1.6000, -15.7000,   0.0000],
#         [-30.7000,  -1.6000,   1.5708],
#         [  1.6000, -23.9900,   0.0000]])
#
#  PREDICTION
# tensor([[ -9.1720,  -3.0556,   4.4184],
#         [-10.2650,   2.3525,   2.3047],
#         [ 16.4664,   6.0770,   2.2834],
#         [-38.3309,  16.0141,   4.2741],
#         [ -8.6856,  -2.2378,   2.4777],
#         [-37.9621,  -0.7980,   2.5233],
#         [-13.5702, -22.0107,   1.7198]], grad_fn=<AddBackward0>)
# loss_value=6.494434833526611
# loss_value=6.494434833526611

# %%
for max_ind in LOWEST_RESULTS:
    space = 100
    loss = plot_results_model(
                           load_model, 
                           dateset_train,
                           start_from = max_ind,
                           end_at = max_ind+1,
                           edges_attr = True,
                           figsize = (15,15),
                           plot_input = True,
                           plot_target = True,
                           plot_prediction = True,
                           plot_intention = False, 
                           title = None,

                           printstat = True,
                           plotstat = True,

                           xlim = (-space,space),
                           ylim = (-space,space),
                           loss_stat = "L1"
                          )
# Out:
# 124
#
#  INPUT
# x=tensor([[  1.6000,  62.4500,   0.0000,  14.3000,   3.0000,   0.0000],
#         [-50.7400,   1.6000,   4.7124,  15.4700,   1.0000,   0.0000],
#         [ -8.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  17.3400,   0.0000,   8.1000,   3.0000,   0.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-33.1700,  -1.6000,   1.5708,  10.5400,   0.0000,   0.0000],
#         [ -1.6000,  55.8400,   3.1416,  11.5500,   1.0000,   0.0000],
#         [-89.8700,  -1.6000,   1.5708,   3.4800,   0.0000,   0.0000]]),
# edge_index=tensor([[3, 2, 4, 3, 1, 2, 6, 3, 0, 0, 4, 5, 0, 1, 1, 2, 5, 2, 3, 0, 3, 1, 0, 6,
#          0, 4, 0, 7, 4, 5, 1, 1, 1, 0, 2, 2],
#         [7, 3, 5, 5, 6, 6, 7, 6, 8, 4, 8, 7, 2, 8, 4, 8, 6, 4, 8, 1, 4, 2, 7, 8,
#          3, 7, 6, 8, 6, 8, 7, 5, 3, 5, 7, 5]]),
# edge_attr=tensor([ 2.6000, 13.0000,  7.7000,  9.0000,  4.8000,  5.0000,  2.6000,  5.9000,
#          1.5000,  2.7000,  1.6000,  2.6000,  2.4000,  2.4000,  2.9000,  1.7000,
#          4.4000,  8.0000,  1.8000,  2.2000,  7.6000,  3.2000,  8.4000,  2.0000,
#          2.4000,  3.1000,  2.3000,  1.6000,  4.3000,  1.6000,  2.5000,  2.9000,
#          3.4000,  2.3000,  2.7000, 16.2000])
#
#
#  TARGET
# tensor([[  1.6000,  90.9700,   0.0000],
#         [-87.4800,   1.6000,   4.7124],
#         [ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  37.5500,   0.0000],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.7900,  -1.6000,   1.5708],
#         [ -1.6000,  27.6800,   3.1416],
#         [-76.8300,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[-1.4745e+01,  4.6325e+01,  3.8309e+00],
#         [-6.8037e+01,  9.2258e-01, -2.3945e-02],
#         [-2.4158e+01, -1.0155e+01,  1.4779e+00],
#         [ 1.4068e+01, -1.8416e+01,  1.8272e+00],
#         [ 5.8103e+01, -2.8110e+00,  4.7407e+00],
#         [ 5.2582e+01, -1.6914e+01,  8.0237e-02],
#         [ 2.1110e+01, -3.1477e+01,  1.6688e-01],
#         [ 1.0279e+00,  2.5471e+01,  4.6251e+00],
#         [-6.5480e+01,  3.9520e+00, -1.1045e+00]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[  1.6000,  62.4500,   0.0000,  14.3000,   3.0000,   0.0000],
#         [-50.7400,   1.6000,   4.7124,  15.4700,   1.0000,   0.0000],
#         [ -8.2000,  -1.6000,   1.5708,   0.0000,   1.0000,   1.0000],
#         [-15.7000,  -1.6000,   1.5708,   0.0000,   0.0000,   1.0000],
#         [  1.6000,  17.3400,   0.0000,   8.1000,   3.0000,   0.0000],
#         [  1.6000,  -8.2000,   0.0000,   0.0000,   1.0000,   1.0000],
#         [-33.1700,  -1.6000,   1.5708,  10.5400,   0.0000,   0.0000],
#         [ -1.6000,  55.8400,   3.1416,  11.5500,   1.0000,   0.0000],
#         [-89.8700,  -1.6000,   1.5708,   3.4800,   0.0000,   0.0000]]),
# edge_index=tensor([[3, 2, 4, 3, 1, 2, 6, 3, 0, 0, 4, 5, 0, 1, 1, 2, 5, 2, 3, 0, 3, 1, 0, 6,
#          0, 4, 0, 7, 4, 5, 1, 1, 1, 0, 2, 2],
#         [7, 3, 5, 5, 6, 6, 7, 6, 8, 4, 8, 7, 2, 8, 4, 8, 6, 4, 8, 1, 4, 2, 7, 8,
#          3, 7, 6, 8, 6, 8, 7, 5, 3, 5, 7, 5]]),
# edge_attr=tensor([ 2.6000, 13.0000,  7.7000,  9.0000,  4.8000,  5.0000,  2.6000,  5.9000,
#          1.5000,  2.7000,  1.6000,  2.6000,  2.4000,  2.4000,  2.9000,  1.7000,
#          4.4000,  8.0000,  1.8000,  2.2000,  7.6000,  3.2000,  8.4000,  2.0000,
#          2.4000,  3.1000,  2.3000,  1.6000,  4.3000,  1.6000,  2.5000,  2.9000,
#          3.4000,  2.3000,  2.7000, 16.2000])
#
#
#  TARGET
# tensor([[  1.6000,  90.9700,   0.0000],
#         [-87.4800,   1.6000,   4.7124],
#         [ -8.2000,  -1.6000,   1.5708],
#         [-15.7000,  -1.6000,   1.5708],
#         [  1.6000,  37.5500,   0.0000],
#         [  1.6000,  -8.2000,   0.0000],
#         [-23.7900,  -1.6000,   1.5708],
#         [ -1.6000,  27.6800,   3.1416],
#         [-76.8300,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[-1.4745e+01,  4.6325e+01,  3.8309e+00],
#         [-6.8037e+01,  9.2258e-01, -2.3945e-02],
#         [-2.4158e+01, -1.0155e+01,  1.4779e+00],
#         [ 1.4068e+01, -1.8416e+01,  1.8272e+00],
#         [ 5.8103e+01, -2.8110e+00,  4.7407e+00],
#         [ 5.2582e+01, -1.6914e+01,  8.0237e-02],
#         [ 2.1110e+01, -3.1477e+01,  1.6688e-01],
#         [ 1.0279e+00,  2.5471e+01,  4.6251e+00],
#         [-6.5480e+01,  3.9520e+00, -1.1045e+00]], grad_fn=<AddBackward0>)
# loss_value=15.72529125213623
# loss_value=15.72529125213623
# 68
#
#  INPUT
# x=tensor([[  8.2000,   1.6000,   4.7124,   0.0000,   1.0000,   1.0000],
#         [ 15.7000,   1.6000,   4.7124,   0.0000,   3.0000,   1.0000],
#         [ 23.2000,   1.6000,   4.7124,   0.0000,   1.0000,   1.0000],
#         [ 30.7000,   1.6000,   4.7124,   0.0000,   3.0000,   1.0000],
#         [ -1.6000,  93.0500,   3.1416,   1.8500,   1.0000,   0.0000],
#         [  1.6000, -29.3300,   0.0000,  14.1700,   1.0000,   0.0000],
#         [ 38.8600,   1.6000,   4.7124,   4.3300,   3.0000,   0.0000],
#         [ 66.8100,   1.6000,   4.7124,   9.3300,   1.0000,   0.0000]]),
# edge_index=tensor([[1, 1, 0, 1, 3, 4, 3, 2, 5, 4, 3, 2, 1, 0, 2, 1, 0, 6, 0, 0, 0, 3, 4, 5,
#          2, 1, 0, 2],
#         [3, 2, 5, 6, 7, 7, 5, 3, 7, 5, 4, 7, 7, 4, 5, 5, 6, 7, 3, 2, 1, 6, 6, 6,
#          4, 4, 7, 6]]),
# edge_attr=tensor([ 6.6000, 11.0000,  5.0000,  4.8000,  2.9000,  1.5000,  4.5000, 10.0000,
#          2.2000,  1.5000,  1.6000,  2.6000,  2.5000,  1.6000,  4.7000,  4.9000,
#          4.2000,  3.3000,  5.5000,  7.6000, 13.0000,  8.7000,  1.6000,  3.6000,
#          1.6000,  1.6000,  2.4000,  5.8000])
#
#
#  TARGET
# tensor([[ 8.2000,  1.6000,  4.7124],
#         [15.7000,  1.6000,  4.7124],
#         [23.2000,  1.6000,  4.7124],
#         [30.7000,  1.6000,  4.7124],
#         [-1.6000, 84.9100,  3.1416],
#         [ 1.6000,  4.2700,  0.0000],
#         [38.2200,  1.6000,  4.7124],
#         [48.8800,  1.6000,  4.7124]])
#
#  PREDICTION
# tensor([[ 25.6431,  -4.2257,   1.6029],
#         [ -4.5456,  -1.5109,  -0.4968],
#         [-23.3305, -22.9596,   1.1193],
#         [-13.0492, -19.9070,   2.3759],
#         [  8.8573,  72.7000,   0.5838],
#         [-59.7231, -21.1870,   0.0950],
#         [ -6.9786,  -6.3186,   4.9896],
#         [ 67.8772,   4.3225,   1.9355]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[  8.2000,   1.6000,   4.7124,   0.0000,   1.0000,   1.0000],
#         [ 15.7000,   1.6000,   4.7124,   0.0000,   3.0000,   1.0000],
#         [ 23.2000,   1.6000,   4.7124,   0.0000,   1.0000,   1.0000],
#         [ 30.7000,   1.6000,   4.7124,   0.0000,   3.0000,   1.0000],
#         [ -1.6000,  93.0500,   3.1416,   1.8500,   1.0000,   0.0000],
#         [  1.6000, -29.3300,   0.0000,  14.1700,   1.0000,   0.0000],
#         [ 38.8600,   1.6000,   4.7124,   4.3300,   3.0000,   0.0000],
#         [ 66.8100,   1.6000,   4.7124,   9.3300,   1.0000,   0.0000]]),
# edge_index=tensor([[1, 1, 0, 1, 3, 4, 3, 2, 5, 4, 3, 2, 1, 0, 2, 1, 0, 6, 0, 0, 0, 3, 4, 5,
#          2, 1, 0, 2],
#         [3, 2, 5, 6, 7, 7, 5, 3, 7, 5, 4, 7, 7, 4, 5, 5, 6, 7, 3, 2, 1, 6, 6, 6,
#          4, 4, 7, 6]]),
# edge_attr=tensor([ 6.6000, 11.0000,  5.0000,  4.8000,  2.9000,  1.5000,  4.5000, 10.0000,
#          2.2000,  1.5000,  1.6000,  2.6000,  2.5000,  1.6000,  4.7000,  4.9000,
#          4.2000,  3.3000,  5.5000,  7.6000, 13.0000,  8.7000,  1.6000,  3.6000,
#          1.6000,  1.6000,  2.4000,  5.8000])
#
#
#  TARGET
# tensor([[ 8.2000,  1.6000,  4.7124],
#         [15.7000,  1.6000,  4.7124],
#         [23.2000,  1.6000,  4.7124],
#         [30.7000,  1.6000,  4.7124],
#         [-1.6000, 84.9100,  3.1416],
#         [ 1.6000,  4.2700,  0.0000],
#         [38.2200,  1.6000,  4.7124],
#         [48.8800,  1.6000,  4.7124]])
#
#  PREDICTION
# tensor([[ 25.6431,  -4.2257,   1.6029],
#         [ -4.5456,  -1.5109,  -0.4968],
#         [-23.3305, -22.9596,   1.1193],
#         [-13.0492, -19.9070,   2.3759],
#         [  8.8573,  72.7000,   0.5838],
#         [-59.7231, -21.1870,   0.0950],
#         [ -6.9786,  -6.3186,   4.9896],
#         [ 67.8772,   4.3225,   1.9355]], grad_fn=<AddBackward0>)
# loss_value=16.133787155151367
# loss_value=16.133787155151367
# 9
#
#  INPUT
# x=tensor([[ -1.6000, -50.7600,   3.1416,  18.9200,   1.0000,   0.0000],
#         [  1.6000,  -9.1800,   0.0000,  16.7800,   1.0000,   0.0000],
#         [-77.7400,  -1.6000,   1.5708,   7.2300,   0.0000,   0.0000]]),
# edge_index=tensor([[1, 0, 0],
#         [2, 2, 1]]),
# edge_attr=tensor([1.9000, 1.9000, 3.2000])
#
#
#  TARGET
# tensor([[ -1.6000, -89.3300,   3.1416],
#         [  1.6000,  23.5700,   0.0000],
#         [-56.8000,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[  2.4430, -59.2483,   0.1380],
#         [ 73.7192,  18.6092,   3.1953],
#         [-77.2219,   5.2985,   0.1826]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -1.6000, -50.7600,   3.1416,  18.9200,   1.0000,   0.0000],
#         [  1.6000,  -9.1800,   0.0000,  16.7800,   1.0000,   0.0000],
#         [-77.7400,  -1.6000,   1.5708,   7.2300,   0.0000,   0.0000]]),
# edge_index=tensor([[1, 0, 0],
#         [2, 2, 1]]),
# edge_attr=tensor([1.9000, 1.9000, 3.2000])
#
#
#  TARGET
# tensor([[ -1.6000, -89.3300,   3.1416],
#         [  1.6000,  23.5700,   0.0000],
#         [-56.8000,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[  2.4430, -59.2483,   0.1380],
#         [ 73.7192,  18.6092,   3.1953],
#         [-77.2219,   5.2985,   0.1826]], grad_fn=<AddBackward0>)
# loss_value=16.23468780517578
# loss_value=16.23468780517578
# 69
#
#  INPUT
# x=tensor([[  8.2000,   1.6000,   4.7124,   0.0000,   1.0000,   1.0000],
#         [ 15.7000,   1.6000,   4.7124,   0.0000,   3.0000,   1.0000],
#         [ 23.2000,   1.6000,   4.7124,   0.0000,   1.0000,   1.0000],
#         [ 30.7000,   1.6000,   4.7124,   0.0000,   3.0000,   1.0000],
#         [ -1.6000,  94.9000,   3.1416,   0.0000,   1.0000,   0.0000],
#         [  1.6000, -43.5000,   0.0000,  12.4100,   1.0000,   0.0000],
#         [ 43.1800,   1.6000,   4.7124,   7.2400,   3.0000,   0.0000],
#         [ 76.1400,   1.6000,   4.7124,   7.3100,   1.0000,   0.0000]]),
# edge_index=tensor([[1, 1, 0, 1, 3, 4, 3, 2, 5, 4, 3, 2, 1, 0, 2, 1, 0, 6, 0, 0, 0, 3, 4, 5,
#          2, 1, 0, 2],
#         [3, 2, 5, 6, 7, 7, 5, 3, 7, 5, 4, 7, 7, 4, 5, 5, 6, 7, 3, 2, 1, 6, 6, 6,
#          4, 4, 7, 6]]),
# edge_attr=tensor([ 6.6000, 11.0000,  3.4000,  4.1000,  2.4000,  1.5000,  3.2000, 10.0000,
#          1.9000,  1.5000,  1.6000,  2.2000,  2.1000,  1.6000,  3.3000,  3.4000,
#          3.7000,  2.8000,  5.5000,  7.6000, 13.0000,  6.3000,  1.6000,  3.1000,
#          1.6000,  1.6000,  2.0000,  4.8000])
#
#
#  TARGET
# tensor([[  8.2000,   1.6000,   4.7124],
#         [ 15.7000,   1.6000,   4.7124],
#         [ 23.2000,   1.6000,   4.7124],
#         [ 30.7000,   1.6000,   4.7124],
#         [ -1.6000,  89.7200,   3.1416],
#         [  1.6000, -13.0100,   0.0000],
#         [ 38.3900,   1.6000,   4.7124],
#         [ 56.1300,   1.6000,   4.7124]])
#
#  PREDICTION
# tensor([[ 27.9618,   0.8970,   1.1042],
#         [ -6.9925,  -3.3667,  -0.4029],
#         [-35.1077, -23.5447,   1.0492],
#         [-25.3707, -19.8603,   3.8275],
#         [  6.8714,  73.4536,   0.7340],
#         [-41.0719, -41.5616,   1.2027],
#         [-12.5809,  -3.4641,   3.6800],
#         [ 77.2771,   2.7915,   2.4483]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[  8.2000,   1.6000,   4.7124,   0.0000,   1.0000,   1.0000],
#         [ 15.7000,   1.6000,   4.7124,   0.0000,   3.0000,   1.0000],
#         [ 23.2000,   1.6000,   4.7124,   0.0000,   1.0000,   1.0000],
#         [ 30.7000,   1.6000,   4.7124,   0.0000,   3.0000,   1.0000],
#         [ -1.6000,  94.9000,   3.1416,   0.0000,   1.0000,   0.0000],
#         [  1.6000, -43.5000,   0.0000,  12.4100,   1.0000,   0.0000],
#         [ 43.1800,   1.6000,   4.7124,   7.2400,   3.0000,   0.0000],
#         [ 76.1400,   1.6000,   4.7124,   7.3100,   1.0000,   0.0000]]),
# edge_index=tensor([[1, 1, 0, 1, 3, 4, 3, 2, 5, 4, 3, 2, 1, 0, 2, 1, 0, 6, 0, 0, 0, 3, 4, 5,
#          2, 1, 0, 2],
#         [3, 2, 5, 6, 7, 7, 5, 3, 7, 5, 4, 7, 7, 4, 5, 5, 6, 7, 3, 2, 1, 6, 6, 6,
#          4, 4, 7, 6]]),
# edge_attr=tensor([ 6.6000, 11.0000,  3.4000,  4.1000,  2.4000,  1.5000,  3.2000, 10.0000,
#          1.9000,  1.5000,  1.6000,  2.2000,  2.1000,  1.6000,  3.3000,  3.4000,
#          3.7000,  2.8000,  5.5000,  7.6000, 13.0000,  6.3000,  1.6000,  3.1000,
#          1.6000,  1.6000,  2.0000,  4.8000])
#
#
#  TARGET
# tensor([[  8.2000,   1.6000,   4.7124],
#         [ 15.7000,   1.6000,   4.7124],
#         [ 23.2000,   1.6000,   4.7124],
#         [ 30.7000,   1.6000,   4.7124],
#         [ -1.6000,  89.7200,   3.1416],
#         [  1.6000, -13.0100,   0.0000],
#         [ 38.3900,   1.6000,   4.7124],
#         [ 56.1300,   1.6000,   4.7124]])
#
#  PREDICTION
# tensor([[ 27.9618,   0.8970,   1.1042],
#         [ -6.9925,  -3.3667,  -0.4029],
#         [-35.1077, -23.5447,   1.0492],
#         [-25.3707, -19.8603,   3.8275],
#         [  6.8714,  73.4536,   0.7340],
#         [-41.0719, -41.5616,   1.2027],
#         [-12.5809,  -3.4641,   3.6800],
#         [ 77.2771,   2.7915,   2.4483]], grad_fn=<AddBackward0>)
# loss_value=16.81752586364746
# loss_value=16.81752586364746
# 74
#
#  INPUT
# x=tensor([[ -1.6000,  39.0800,   3.1416,  13.8600,   1.0000,   0.0000],
#         [  1.6000, -74.4600,   0.0000,   8.2100,   1.0000,   0.0000]]),
# edge_index=tensor([[0],
#         [1]]),
# edge_attr=tensor([1.7000])
#
#
#  TARGET
# tensor([[ -1.6000,   5.6100,   3.1416],
#         [  1.6000, -53.7600,   0.0000]])
#
#  PREDICTION
# tensor([[  5.0358,  71.6588,   0.4070],
#         [ -4.2151, -72.6433,   0.8530]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -1.6000,  39.0800,   3.1416,  13.8600,   1.0000,   0.0000],
#         [  1.6000, -74.4600,   0.0000,   8.2100,   1.0000,   0.0000]]),
# edge_index=tensor([[0],
#         [1]]),
# edge_attr=tensor([1.7000])
#
#
#  TARGET
# tensor([[ -1.6000,   5.6100,   3.1416],
#         [  1.6000, -53.7600,   0.0000]])
#
#  PREDICTION
# tensor([[  5.0358,  71.6588,   0.4070],
#         [ -4.2151, -72.6433,   0.8530]], grad_fn=<AddBackward0>)
# loss_value=16.828433990478516
# loss_value=16.828433990478516
# 118
#
#  INPUT
# x=tensor([[ -1.6000, -12.7300,   3.1416,  18.3500,   1.0000,   0.0000],
#         [  1.6000, -40.6300,   0.0000,  13.1200,   1.0000,   0.0000],
#         [-90.0600,  -1.6000,   1.5708,   3.4400,   0.0000,   0.0000]]),
# edge_index=tensor([[1, 0, 0],
#         [2, 2, 1]]),
# edge_attr=tensor([1.6000, 1.7000, 4.3000])
#
#
#  TARGET
# tensor([[ -1.6000, -50.7600,   3.1416],
#         [  1.6000,  -9.1800,   0.0000],
#         [-77.7400,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[ 23.3304,   3.2474,   5.6288],
#         [ 73.5062,  -6.3374,  -0.5548],
#         [-76.7481,   5.6434,   0.2221]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -1.6000, -12.7300,   3.1416,  18.3500,   1.0000,   0.0000],
#         [  1.6000, -40.6300,   0.0000,  13.1200,   1.0000,   0.0000],
#         [-90.0600,  -1.6000,   1.5708,   3.4400,   0.0000,   0.0000]]),
# edge_index=tensor([[1, 0, 0],
#         [2, 2, 1]]),
# edge_attr=tensor([1.6000, 1.7000, 4.3000])
#
#
#  TARGET
# tensor([[ -1.6000, -50.7600,   3.1416],
#         [  1.6000,  -9.1800,   0.0000],
#         [-77.7400,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[ 23.3304,   3.2474,   5.6288],
#         [ 73.5062,  -6.3374,  -0.5548],
#         [-76.7481,   5.6434,   0.2221]], grad_fn=<AddBackward0>)
# loss_value=18.479196548461914
# loss_value=18.479196548461914
# 98
#
#  INPUT
# x=tensor([[-8.2000e+00, -1.6000e+00,  1.5708e+00,  1.0000e-02,  0.0000e+00,
#           1.0000e+00],
#         [ 2.9580e+01,  1.6000e+00,  4.7124e+00,  1.4450e+01,  3.0000e+00,
#           0.0000e+00],
#         [ 7.4060e+01,  1.6000e+00,  4.7124e+00,  8.2200e+00,  1.0000e+00,
#           0.0000e+00]]),
# edge_index=tensor([[0, 1, 0],
#         [2, 2, 1]]),
# edge_attr=tensor([1.9000, 2.4000, 4.7000])
#
#
#  TARGET
# tensor([[-8.2000, -1.6000,  1.5708],
#         [11.0800,  1.6000,  4.7124],
#         [50.3400,  1.6000,  4.7124]])
#
#  PREDICTION
# tensor([[-72.2667,   0.4321,  -1.0209],
#         [-47.1125,  -7.8821,   3.0292],
#         [ 83.1885,   2.9919,   2.3420]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[-8.2000e+00, -1.6000e+00,  1.5708e+00,  1.0000e-02,  0.0000e+00,
#           1.0000e+00],
#         [ 2.9580e+01,  1.6000e+00,  4.7124e+00,  1.4450e+01,  3.0000e+00,
#           0.0000e+00],
#         [ 7.4060e+01,  1.6000e+00,  4.7124e+00,  8.2200e+00,  1.0000e+00,
#           0.0000e+00]]),
# edge_index=tensor([[0, 1, 0],
#         [2, 2, 1]]),
# edge_attr=tensor([1.9000, 2.4000, 4.7000])
#
#
#  TARGET
# tensor([[-8.2000, -1.6000,  1.5708],
#         [11.0800,  1.6000,  4.7124],
#         [50.3400,  1.6000,  4.7124]])
#
#  PREDICTION
# tensor([[-72.2667,   0.4321,  -1.0209],
#         [-47.1125,  -7.8821,   3.0292],
#         [ 83.1885,   2.9919,   2.3420]], grad_fn=<AddBackward0>)
# loss_value=19.40656852722168
# loss_value=19.40656852722168
# 53
#
#  INPUT
# x=tensor([[ -1.6000,  23.2200,   3.1416,  15.8600,   1.0000,   0.0000],
#         [  1.6000, -64.8100,   0.0000,   9.6500,   1.0000,   0.0000],
#         [-94.9000,  -1.6000,   1.5708,   0.0000,   0.0000,   0.0000]]),
# edge_index=tensor([[1, 0, 0],
#         [2, 2, 1]]),
# edge_attr=tensor([1.5000, 1.6000, 2.1000])
#
#
#  TARGET
# tensor([[ -1.6000, -12.7300,   3.1416],
#         [  1.6000, -40.6300,   0.0000],
#         [-90.0600,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[ 23.9992,  61.0867,  -0.6468],
#         [ 19.4557, -63.4129,  -2.8435],
#         [-69.0926,   6.3822,  -0.4390]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -1.6000,  23.2200,   3.1416,  15.8600,   1.0000,   0.0000],
#         [  1.6000, -64.8100,   0.0000,   9.6500,   1.0000,   0.0000],
#         [-94.9000,  -1.6000,   1.5708,   0.0000,   0.0000,   0.0000]]),
# edge_index=tensor([[1, 0, 0],
#         [2, 2, 1]]),
# edge_attr=tensor([1.5000, 1.6000, 2.1000])
#
#
#  TARGET
# tensor([[ -1.6000, -12.7300,   3.1416],
#         [  1.6000, -40.6300,   0.0000],
#         [-90.0600,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[ 23.9992,  61.0867,  -0.6468],
#         [ 19.4557, -63.4129,  -2.8435],
#         [-69.0926,   6.3822,  -0.4390]], grad_fn=<AddBackward0>)
# loss_value=19.738428115844727
# loss_value=19.738428115844727
# 75
#
#  INPUT
# x=tensor([[-8.2000, -1.6000,  1.5708,  0.0000,  0.0000,  1.0000],
#         [18.0800,  1.6000,  4.7124, 11.5000,  3.0000,  0.0000],
#         [63.4000,  1.6000,  4.7124, 10.6600,  1.0000,  0.0000]]),
# edge_index=tensor([[0, 1, 0],
#         [2, 2, 1]]),
# edge_attr=tensor([2.3000, 2.7000, 7.4000])
#
#
#  TARGET
# tensor([[-8.2000, -1.6000,  1.5708],
#         [ 8.5800,  1.6000,  4.7124],
#         [35.7900,  1.6000,  4.7124]])
#
#  PREDICTION
# tensor([[-51.2760,   5.7195,  -0.3650],
#         [-55.6123, -10.0630,   3.5434],
#         [ 80.7175,   2.5462,   2.1914]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[-8.2000, -1.6000,  1.5708,  0.0000,  0.0000,  1.0000],
#         [18.0800,  1.6000,  4.7124, 11.5000,  3.0000,  0.0000],
#         [63.4000,  1.6000,  4.7124, 10.6600,  1.0000,  0.0000]]),
# edge_index=tensor([[0, 1, 0],
#         [2, 2, 1]]),
# edge_attr=tensor([2.3000, 2.7000, 7.4000])
#
#
#  TARGET
# tensor([[-8.2000, -1.6000,  1.5708],
#         [ 8.5800,  1.6000,  4.7124],
#         [35.7900,  1.6000,  4.7124]])
#
#  PREDICTION
# tensor([[-51.2760,   5.7195,  -0.3650],
#         [-55.6123, -10.0630,   3.5434],
#         [ 80.7175,   2.5462,   2.1914]], grad_fn=<AddBackward0>)
# loss_value=19.750028610229492
# loss_value=19.750028610229492
# 119
#
#  INPUT
# x=tensor([[ -1.6000,   5.6100,   3.1416,  17.6100,   1.0000,   0.0000],
#         [  1.6000, -53.7600,   0.0000,  11.0600,   1.0000,   0.0000],
#         [-93.5000,  -1.6000,   1.5708,   1.4000,   0.0000,   0.0000]]),
# edge_index=tensor([[1, 0, 0],
#         [2, 2, 1]]),
# edge_attr=tensor([1.6000, 1.6000, 2.7000])
#
#
#  TARGET
# tensor([[ -1.6000, -31.8400,   3.1416],
#         [  1.6000, -25.9600,   0.0000],
#         [-84.9700,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[ 20.8959,  44.3477,   4.8227],
#         [ 36.6972, -48.8618,  -4.1455],
#         [-71.1713,   6.8910,  -0.8069]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -1.6000,   5.6100,   3.1416,  17.6100,   1.0000,   0.0000],
#         [  1.6000, -53.7600,   0.0000,  11.0600,   1.0000,   0.0000],
#         [-93.5000,  -1.6000,   1.5708,   1.4000,   0.0000,   0.0000]]),
# edge_index=tensor([[1, 0, 0],
#         [2, 2, 1]]),
# edge_attr=tensor([1.6000, 1.6000, 2.7000])
#
#
#  TARGET
# tensor([[ -1.6000, -31.8400,   3.1416],
#         [  1.6000, -25.9600,   0.0000],
#         [-84.9700,  -1.6000,   1.5708]])
#
#  PREDICTION
# tensor([[ 20.8959,  44.3477,   4.8227],
#         [ 36.6972, -48.8618,  -4.1455],
#         [-71.1713,   6.8910,  -0.8069]], grad_fn=<AddBackward0>)
# loss_value=20.797388076782227
# loss_value=20.797388076782227
