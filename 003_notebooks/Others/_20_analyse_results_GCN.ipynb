# %%
#--------------------------------
## IMPORTS
#--------------------------------
import sys
import os

# set the path to find the modules
sys.path.insert(0, '../005_src/') #use relative path
#os.chdir("../005_src")

from config import *
# Out:
# ----------------------------------------
# Packages import successful
# Variables import successful
# Helper Functions import successful
# Functions import successful
# Functions xml import successful
# Functions graph import successful
# Functions GCN import successful
# Functions Plotting import successful
# Functions Data Adjustments import successful
# ----------------------------------------
# root directory: /storage/remote/atcremers50/ss21_multiagentcontrol/
# input directory: /storage/remote/atcremers50/ss21_multiagentcontrol/004_data/
# output directory: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/
# ----------------------------------------

# %%
device = cudaOverview()
# Out:
# CUDA available
# Number of Devices: 1
# ID current Device NVIDIA GeForce GTX 1050 Ti: 0
# 	current GPU memory usage by tensors in bytes:0
# 	current GPU memory managed by caching allocator in bytes:0

# %%
this_date = "20210720"
ts = "16h45m18s"
GCN_num = "011"
this_GCN = f"GCN_{GCN_num}"
print (this_GCN)
# Out:
# GCN_011

# %%
# do NOT overwrite this_date and ts above
import_specific_GCN_model(GCN_num)
# Out:
# at 19h47m57s imported models:
# ['GCN_HL01', 'GCN_HL02', 'GCN_HL03']
# edges_attr=True
# imported trainer: GCN_011 at 19h47m57s
# ('GCN_011', '19h47m57s')

# %% [markdown]
# ## Reload dictionary

# %%
MODEL_OUTPUT_PATH = os.path.join(OUTPUT_DIR,f"{this_GCN}/")
MODEL_OUTPUT_PATH_TODAY = os.path.join(MODEL_OUTPUT_PATH,f"{this_date}-{ts}/")
print (MODEL_OUTPUT_PATH_TODAY)

dateset_test_path = f"/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/{this_GCN}/{this_date}-{ts}/dataset_test"
dict_text_output_path = f"/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/{this_GCN}/{this_date}-{ts}/{this_date}-{ts}_training_parameters"

#dateset_test = pkl.load(open(f'{dateset_test_path}.pkl',"rb"))

reloaded_dict = pkl.load(open(f'{dict_text_output_path}.pkl',"rb"))
reloaded_dict
# Out:
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/
# {'input_file_name': '20210710-11h46m35s_timesteps200_ec3500_em7000',
#  'max_num_veh': 10,
#  'sim_duration_timesteps': '200',
#  'run_time': '16h45m18s',
#  'model': 'GCN_011',
#  'random_seed': 457362,
#  'train_size': 0.9,
#  'batch_size': 512,
#  'Nepochs': 10000,
#  'save_every': 5000,
#  'transformstat': False,
#  'plotstat': True,
#  'printstat': False,
#  'intentionstat': 'obsoleted',
#  'shuttle_train_frame': None,
#  'shuttle_val_frame': None,
#  'num_rows_training': 127,
#  'num_rows_validation': 13,
#  'num_rows_test': 2,
#  'exclude_yaw': 'obsoleted',
#  'concatenatestat': 'obsoleted',
#  'paddingstat': 'obsoleted',
#  'size_input': 6,
#  'size_output': 3,
#  'model_architecture': GCN_HL03(
#    (conv1): GCNConv(6, 128)
#    (conv2): GCNConv(128, 256)
#    (conv3): GCNConv(256, 64)
#    (conv4): GCNConv(64, 3)
#  ),
#  'hidden_layers_sizes': [128, 256, 64],
#  'criterion': L1Loss(),
#  'optimizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      eps: 1e-08
#      lr: 0.001
#      weight_decay: 0
#  ),
#  'model_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/20210720-16h45m18sEPOCH_10000of10000_FINAL__GCN_011.pt',
#  'train_losses_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/20210720-16h45m18sEPOCH_10000of10000_FINAL__FINAL__training_loss.pkl',
#  'val_losses_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/20210720-16h45m18sEPOCH_10000of10000_FINAL__FINAL__validation_loss.pkl',
#  'lr_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/20210720-16h45m18sEPOCH_10000of10000_FINAL__FINAL__learning_rate.pkl',
#  'figure_paths': ['/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000010of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000010of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000020of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000020of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000030of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000030of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000040of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000040of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000050of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000050of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000060of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000060of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000070of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000070of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000080of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000080of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000090of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000090of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000100of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000100of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000200of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000200of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000300of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000300of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000400of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000400of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000500of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000500of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000600of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000600of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000700of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000700of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000800of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000800of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_000900of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_000900of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_001000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_001000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_002000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_002000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_003000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_003000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_004000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_004000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_005000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_005000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_006000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_006000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_007000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_007000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_008000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_008000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_009000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_009000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/20210720-16h45m18sModel_GCN_011_shuttle_train_epoch_010000of10000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/20210720-16h45m18sModel_GCN_011_shuttle_val_epoch_010000of10000.png'],
#  'final_train_loss': 8.61089038848877,
#  'final_val_loss': 10.859651565551758}

# %%
input_file_name = reloaded_dict["input_file_name"]
reloaded_dict["model_architecture"]
# Out:
# GCN_HL03(
#   (conv1): GCNConv(6, 128)
#   (conv2): GCNConv(128, 256)
#   (conv3): GCNConv(256, 64)
#   (conv4): GCNConv(64, 3)
# )

# %% [markdown]
# ## Plot losses

# %%
# load losses
t_losses_load = pkl.load(open( reloaded_dict['train_losses_path'], 'rb'))
v_losses_load = pkl.load(open( reloaded_dict['val_losses_path'], 'rb'))

# %%
##================================
# TRAIN AND VAL LOSSES
##================================
fig = plot_training(t_losses_load,
                  v_losses_load,
                  learning_rate = None,
                  gaussian=True,
                  sigma=2,
                  figsize=(8, 6),
                  mytitle = 'Training & validation loss'
                  )

description = f"{this_date}-{ts}"
new_png = f"{description}_train_val_loss_plot.png"
new_png_path = os.path.join(MODEL_OUTPUT_PATH_TODAY,new_png)
plt.savefig(new_png_path)
print (f"Plot saved in {new_png_path}")
# Out:
# Plot saved in /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/20210720-16h45m18s_train_val_loss_plot.png

# %% [markdown]
# ## Verification
# of results

# %%
hidden_layers_sizes = reloaded_dict["hidden_layers_sizes"]
size_input = reloaded_dict['size_input']
size_output = reloaded_dict['size_output']
random_seed = reloaded_dict["random_seed"]

# %%
from _03_Networks.GCN_011.GCN_model_011 import GCN_HL01,GCN_HL02,GCN_HL03
from _03_Networks.GCN_011.GCN_trainer_011 import Trainer, check_import

num_hidden_layers = len(hidden_layers_sizes)
if num_hidden_layers == 1:

            hc_1 = hidden_layers_sizes[0]
            hc_2 = None
            hc_3 = None

            model = GCN_HL01(
                                num_input_features=size_input,
                                num_output_features =size_output,
                                random_seed = random_seed,
                                hc_1 = hc_1,
                               )
elif num_hidden_layers == 2:

            hc_1 = hidden_layers_sizes[0]
            hc_2 = hidden_layers_sizes[1]
            hc_3 = None

            model = GCN_HL02(
                                num_input_features=size_input,
                                num_output_features =size_output,
                                random_seed = random_seed,
                                hc_1 = hc_1,
                                hc_2 = hc_2,
                               )
elif num_hidden_layers == 3:

            hc_1 = hidden_layers_sizes[0]
            hc_2 = hidden_layers_sizes[1]
            hc_3 = hidden_layers_sizes[2]

            model = GCN_HL03(
                                num_input_features=size_input,
                                num_output_features =size_output,
                                random_seed = random_seed,
                                hc_1 = hc_1,
                                hc_2 = hc_2,
                                hc_3 = hc_3,
                               )
else:
            print (f"ERROR: model with {num_hidden_layers=} not implemented")
            print (f"using first three layers")

            hc_1 = hidden_layers_sizes[0]
            hc_2 = hidden_layers_sizes[1]
            hc_3 = hidden_layers_sizes[2]

            model = GCN_HL03(num_input_features=size_input,
                        num_output_features =size_output,
                        random_seed = random_seed,
                        hc_1 = hc_1,
                        hc_2 = hc_2,
                        hc_3 = hc_3,
                       )
load_model = model

# %%
load_path = reloaded_dict['model_path']
load_model.load_state_dict(torch.load(load_path))
load_model.eval()
# Out:
# GCN_HL03(
#   (conv1): GCNConv(6, 128)
#   (conv2): GCNConv(128, 256)
#   (conv3): GCNConv(256, 64)
#   (conv4): GCNConv(64, 3)
# )

# %%
MODEL_OUTPUT_PATH = os.path.join(OUTPUT_DIR,f"{this_GCN}/")
MODEL_OUTPUT_PATH_DATASETS = os.path.join(MODEL_OUTPUT_PATH,f"DATASETS/")
datasets_list = sorted(glob.glob(f"{MODEL_OUTPUT_PATH_DATASETS}"+"/**/*"+f'{input_file_name}_dataset*',
                                     recursive=True))
if len( datasets_list) == 5:                               
        print ("\n> DATASETS FOUND")
        print (*datasets_list, sep = "\n")
        
        dataset_train = torch.load(datasets_list[0], map_location=torch.device('cpu') )
        # map_location=lambda storage, loc: storage.cuda(0))
        dataset_val = torch.load(datasets_list[1], map_location=torch.device('cpu') )
        dataset_test = torch.load(datasets_list[2], map_location=torch.device('cpu') )
        dataset_shuttle_train = torch.load(datasets_list[3], map_location=torch.device('cpu') )
        dataset_shuttle_val = torch.load(datasets_list[4], map_location=torch.device('cpu') )
# Out:
# > DATASETS FOUND
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/DATASETS/20210710-11h46m35s_timesteps200_ec3500_em7000_dataset_01_train.pt
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/DATASETS/20210710-11h46m35s_timesteps200_ec3500_em7000_dataset_02_validation.pt
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/DATASETS/20210710-11h46m35s_timesteps200_ec3500_em7000_dataset_03_test.pt
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/DATASETS/20210710-11h46m35s_timesteps200_ec3500_em7000_dataset_04_shuttle_train.pt
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/DATASETS/20210710-11h46m35s_timesteps200_ec3500_em7000_dataset_05_shuttle_val.pt

# %%
dataset_test
# Out:
# [Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 3])]

# %%
plot_results_model(
                   load_model, 
                   dataset_test[1],
                   start_from = 0,
                   end_at = 10,
                   edges_attr = True,
                   figsize = (15,15),
                   plot_input = True,
                   plot_target = True,
                   plot_prediction = True,
                   plot_intention = False, 
                   title = "test",
    
                   xlim = (-100,100),
                   ylim = (-100,100),
                  )

# %%
path_GIF= build_gif(folder = f'/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_{GCN_num}/{this_date}-{ts}/figures_validation_set/',
              title = "Predictions over epochs",
              search = "", 
              fps=0.5,
              recursive = True,
              delete_tempFiles = False,
              max_n_images = 200
             )
# Out:
# 1it [00:00,  8.48it/s]
# found 28 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_validation_set/
# the gif will be create using the first 28 images
# 28it [00:03,  9.24it/s]

# %%
Image(open(f'{path_GIF}','rb').read())

# %%
path_GIF= build_gif(folder = f'/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_{GCN_num}/{this_date}-{ts}/figures_training_set/',
              title = "Predictions over epochs",
              search = "", 
              fps=0.5,
              recursive = True,
              delete_tempFiles = False,
              max_n_images = 200
             )
# Out:
# 1it [00:00,  9.72it/s]
# found 28 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_011/20210720-16h45m18s/figures_training_set/
# the gif will be create using the first 28 images
# 28it [00:02, 10.19it/s]

# %%
Image(open(f'{path_GIF}','rb').read())

# %%
deleted_folders = delete_empty_r(directory= OUTPUT_DIR,printstat = True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-19-267e6782ca96> in <module>
# ----> 1 deleted_folders = delete_empty_r(directory= OUTPUT_DIR,printstat = True)
#
# /storage/remote/atcremers50/ss21_multiagentcontrol/005_src/_01_functions/_00_helper_functions.py in delete_empty_r(directory, printstat)
#     154         )
#     155         if not any(files) and not still_has_subdirs:
# --> 156             os.rmdir(current_dir)
#     157             deleted.add(current_dir)
#     158             printif(f"deleted path: {current_dir}", printstat)
#
# PermissionError: [Errno 13] Permission denied: '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_010/20210718-13h56m48s/figures'
