# %%
#--------------------------------
## IMPORTS
#--------------------------------
import sys
import os

# set the path to find the modules
sys.path.insert(0, '../../005_src/') #use relative path
os.chdir("../../005_src")

from config import *
##--------------------------------
# LOAD BEST COMBOS
##--------------------------------       
GCN_MODEL = "GCN_013"
MODEL_PATH =os.path.join(OUTPUT_DIR,GCN_MODEL)
dict_best_combos_descr = f"{GCN_MODEL}_best_combos"
dict_best_combos_path = os.path.join(MODEL_PATH,dict_best_combos_descr)
reloaded_best_combos = pkl.load(open(f'{dict_best_combos_path}.pkl',"rb"))
    
# get all the best combination
all_combo = [v[0] for k,v in reloaded_best_combos.items()]
l = len(all_combo)
# Out:
# ----------------------------------------
# Packages import successful
# Variables import successful
# Helper Functions import successful
# Functions import successful
# Functions xml import successful
# Functions graph import successful
# Functions GCN import successful
# Functions Plotting import successful
# Functions Data Adjustments import successful
# ----------------------------------------
# root directory: /storage/remote/atcremers50/ss21_multiagentcontrol/
# input directory: /storage/remote/atcremers50/ss21_multiagentcontrol/004_data/
# output directory: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/
# ----------------------------------------
#
# ----------------------------------------
# root directory: /storage/remote/atcremers50/ss21_multiagentcontrol/
# input directory: /storage/remote/atcremers50/ss21_multiagentcontrol/004_data/
# output directory: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/
# ----------------------------------------
#
# at 21h20m58s imported models:
# ['GCN_HL01_leaky_relu', 'GCN_HL01_relu', 'GCN_HL01_tanh', 'GCN_HL02_leaky_relu', 'GCN_HL02_relu', 'GCN_HL02_tanh', 'GCN_HL03_leaky_relu', 'GCN_HL03_relu', 'GCN_HL03_tanh']

# %%
import PIL.Image
from IPython.display import Image as Image_disp

# %%
device = cudaOverview()
# Out:
# CUDA available
# Number of Devices: 1
# ID current Device NVIDIA GeForce GTX 1050 Ti: 0
# 	current GPU memory usage by tensors in bytes:0
# 	current GPU memory managed by caching allocator in bytes:0

# %%
from _03_Networks.GCN_013.GCN_model_013 import *
from _03_Networks.GCN_013.GCN_trainer_013 import *
this_GCN, ts_import = check_import()

for k,v in reloaded_best_combos.items():
    this_date,ts = k.split("-")
    GCN_num = "013"
    this_GCN = f"GCN_{GCN_num}"
    print ()
    print ()
    print (f"{this_GCN}: {k}")  
    
    # reload dictionary
    MODEL_OUTPUT_PATH = os.path.join(OUTPUT_DIR,f"{this_GCN}/")
    MODEL_OUTPUT_PATH_TODAY = os.path.join(MODEL_OUTPUT_PATH,f"{this_date}-{ts}/")
    #print (MODEL_OUTPUT_PATH_TODAY)

    dateset_test_path = f"/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/{this_GCN}/{this_date}-{ts}/dataset_test"
    dict_text_output_path = f"/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/{this_GCN}/{this_date}-{ts}/{this_date}-{ts}_training_parameters"

    reloaded_dict = pkl.load(open(f'{dict_text_output_path}.pkl',"rb"))
    
    input_file_name = reloaded_dict["input_file_name"]
    architecture = reloaded_dict["model_architecture"]
    hidden_layers_sizes = reloaded_dict["hidden_layers_sizes"]
    size_input = reloaded_dict['size_input']
    size_output = reloaded_dict['size_output']
    random_seed = reloaded_dict["random_seed"]
    activation_fun = reloaded_dict["activation_function"]   
    
    print (f"{architecture=}")
    
    # load losses
    t_losses_load = pkl.load(open( reloaded_dict['train_losses_path'], 'rb'))
    v_losses_load = pkl.load(open( reloaded_dict['val_losses_path'], 'rb'))
    lr_load = pkl.load(open( reloaded_dict['lr_path'], 'rb'))
    
    ##================================
    # TRAIN AND VAL LOSSES
    ##================================
    fig = plot_training(t_losses_load,
                      v_losses_load,
                      learning_rate = lr_load,
                      gaussian=True,
                      sigma=2,
                      figsize=(20, 6),
                      mytitle = 'Training & validation loss'
                      )

    description = f"{this_date}-{ts}"
    new_png = f"{description}_train_val_loss_plot.png"
    new_png_path = os.path.join(MODEL_OUTPUT_PATH_TODAY,new_png)
    plt.savefig(new_png_path)
    plt.show()
    print (f"Plot saved in {new_png_path}")
    
    
    ##================================
    ## MODEL INIT
    ##================================
    num_hidden_layers = len(hidden_layers_sizes)

    ## TANH

    if activation_fun == "tanh":
        if num_hidden_layers == 1:

            hc_1 = hidden_layers_sizes[0]
            hc_2 = None
            hc_3 = None

            model = GCN_HL01_tanh(
                                num_input_features=size_input,
                                num_output_features =size_output,
                                random_seed = random_seed,
                                hc_1 = hc_1,
                                )
        elif num_hidden_layers == 2:

            hc_1 = hidden_layers_sizes[0]
            hc_2 = hidden_layers_sizes[1]
            hc_3 = None

            model = GCN_HL02_tanh(
                                num_input_features=size_input,
                                num_output_features =size_output,
                                random_seed = random_seed,
                                hc_1 = hc_1,
                                hc_2 = hc_2,
                                )
        elif num_hidden_layers == 3:

            hc_1 = hidden_layers_sizes[0]
            hc_2 = hidden_layers_sizes[1]
            hc_3 = hidden_layers_sizes[2]

            model = GCN_HL03_tanh(
                                num_input_features=size_input,
                                num_output_features =size_output,
                                random_seed = random_seed,
                                hc_1 = hc_1,
                                hc_2 = hc_2,
                                hc_3 = hc_3,
                                )
        else:
            print (f"ERROR: model with {num_hidden_layers=} not implemented")
            print (f"using first three layers")

            hc_1 = hidden_layers_sizes[0]
            hc_2 = hidden_layers_sizes[1]
            hc_3 = hidden_layers_sizes[2]

            model = GCN_HL03_tanh(num_input_features=size_input,
                        num_output_features =size_output,
                        random_seed = random_seed,
                        hc_1 = hc_1,
                        hc_2 = hc_2,
                        hc_3 = hc_3,
                        )

    #### RELU       

    elif activation_fun == "relu": 
        if num_hidden_layers == 1:

            hc_1 = hidden_layers_sizes[0]
            hc_2 = None
            hc_3 = None

            model = GCN_HL01_relu(
                                num_input_features=size_input,
                                num_output_features =size_output,
                                random_seed = random_seed,
                                hc_1 = hc_1,
                                )
        elif num_hidden_layers == 2:

            hc_1 = hidden_layers_sizes[0]
            hc_2 = hidden_layers_sizes[1]
            hc_3 = None

            model = GCN_HL02_relu(
                                num_input_features=size_input,
                                num_output_features =size_output,
                                random_seed = random_seed,
                                hc_1 = hc_1,
                                hc_2 = hc_2,
                                )
        elif num_hidden_layers == 3:

            hc_1 = hidden_layers_sizes[0]
            hc_2 = hidden_layers_sizes[1]
            hc_3 = hidden_layers_sizes[2]

            model = GCN_HL03_relu(
                                num_input_features=size_input,
                                num_output_features =size_output,
                                random_seed = random_seed,
                                hc_1 = hc_1,
                                hc_2 = hc_2,
                                hc_3 = hc_3,
                                )
        else:
            print (f"ERROR: model with {num_hidden_layers=} not implemented")
            print (f"using first three layers")

            hc_1 = hidden_layers_sizes[0]
            hc_2 = hidden_layers_sizes[1]
            hc_3 = hidden_layers_sizes[2]

            model = GCN_HL03_relu(num_input_features=size_input,
                        num_output_features =size_output,
                        random_seed = random_seed,
                        hc_1 = hc_1,
                        hc_2 = hc_2,
                        hc_3 = hc_3,
                        )

    elif activation_fun == "leaky_relu": 
        if num_hidden_layers == 1:

            hc_1 = hidden_layers_sizes[0]
            hc_2 = None
            hc_3 = None

            model = GCN_HL01_leaky_relu(
                                num_input_features=size_input,
                                num_output_features =size_output,
                                random_seed = random_seed,
                                hc_1 = hc_1,
                                )
        elif num_hidden_layers == 2:

            hc_1 = hidden_layers_sizes[0]
            hc_2 = hidden_layers_sizes[1]
            hc_3 = None

            model = GCN_HL02_leaky_relu(
                                num_input_features=size_input,
                                num_output_features =size_output,
                                random_seed = random_seed,
                                hc_1 = hc_1,
                                hc_2 = hc_2,
                                )
        elif num_hidden_layers == 3:

            hc_1 = hidden_layers_sizes[0]
            hc_2 = hidden_layers_sizes[1]
            hc_3 = hidden_layers_sizes[2]

            model = GCN_HL03_rrelu(
                                num_input_features=size_input,
                                num_output_features =size_output,
                                random_seed = random_seed,
                                hc_1 = hc_1,
                                hc_2 = hc_2,
                                hc_3 = hc_3,
                                )
        else:
            print (f"ERROR: model with {num_hidden_layers=} not implemented")
            print (f"using first three layers")

            hc_1 = hidden_layers_sizes[0]
            hc_2 = hidden_layers_sizes[1]
            hc_3 = hidden_layers_sizes[2]

            model = GCN_HL03_leaky_relu(num_input_features=size_input,
                        num_output_features =size_output,
                        random_seed = random_seed,
                        hc_1 = hc_1,
                        hc_2 = hc_2,
                        hc_3 = hc_3,
                        )
    load_model = model
    load_path = reloaded_dict['model_path']
    load_model.load_state_dict(torch.load(load_path))
    load_model.eval()
    
    
    MODEL_OUTPUT_PATH = os.path.join(OUTPUT_DIR,f"{this_GCN}/")
    MODEL_OUTPUT_PATH_DATASETS = os.path.join(MODEL_OUTPUT_PATH,f"DATASETS/")
    datasets_list = sorted(glob.glob(f"{MODEL_OUTPUT_PATH_DATASETS}"+"/**/*"+f'{input_file_name}_dataset*',
                                         recursive=True))
    if len( datasets_list) == 5:                               
            print ("\n> DATASETS FOUND")
            #print (*datasets_list, sep = "\n")

            dataset_train = torch.load(datasets_list[0], map_location=torch.device('cpu') )
            # map_location=lambda storage, loc: storage.cuda(0))
            dataset_val = torch.load(datasets_list[1], map_location=torch.device('cpu') )
            dataset_test = torch.load(datasets_list[2], map_location=torch.device('cpu') )
            dataset_shuttle_train = torch.load(datasets_list[3], map_location=torch.device('cpu') )
            dataset_shuttle_val = torch.load(datasets_list[4], map_location=torch.device('cpu') )
    
    val_path_GIF= build_gif(folder = f'/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_{GCN_num}/{this_date}-{ts}/figures_validation_set/',
              title = "Validation Predictions over epochs",
              search = "", 
              fps=0.5,
              recursive = True,
              delete_tempFiles = False,
              max_n_images = 200
             )
    
    
    #im  = PIL.Image.open(f'{val_path_GIF}')
    #im  = PIL.Image.open(f'{val_path_GIF}').resize((400, 400))
    #Image(open(f'{val_path_GIF}','rb').read())
    #im = Image_disp(f'{val_path_GIF}','r')
    #plt.imshow(np.asarray(im))
    #im.show()
    #display(im)
    train_path_GIF= build_gif(folder = f'/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_{GCN_num}/{this_date}-{ts}/figures_training_set/',
                  title = "Trainin Predictions over epochs",
                  search = "", 
                  fps=0.5,
                  recursive = True,
                  delete_tempFiles = False,
                  max_n_images = 200
                 )
    #im  = Image(open(f'{train_path_GIF}','rb').read())
# Out:
# imported trainer: GCN_013 at 21h57m31s
#
#
# GCN_013: 20210721-22h28m11s
# architecture=GCN_HL03_tanh(
#   (conv1): GCNConv(6, 128)
#   (conv2): GCNConv(128, 256)
#   (conv3): GCNConv(256, 64)
#   (conv4): GCNConv(64, 3)
# )
# Plot saved in /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-22h28m11s/20210721-22h28m11s_train_val_loss_plot.png
#
# > DATASETS FOUND
# 2it [00:00, 11.16it/s]
# found 5 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-22h28m11s/figures_validation_set/
# the gif will be create using the first 5 images
# 5it [00:00, 11.09it/s]
# 1it [00:00,  9.54it/s]
# found 5 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-22h28m11s/figures_training_set/
# the gif will be create using the first 5 images
# 5it [00:00, 10.86it/s]
# GCN_013: 20210721-20h33m28s
# architecture=GCN_HL03_tanh(
#   (conv1): GCNConv(6, 128)
#   (conv2): GCNConv(128, 256)
#   (conv3): GCNConv(256, 64)
#   (conv4): GCNConv(64, 3)
# )
# Plot saved in /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-20h33m28s/20210721-20h33m28s_train_val_loss_plot.png
#
# > DATASETS FOUND
# 2it [00:00, 11.14it/s]
# found 5 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-20h33m28s/figures_validation_set/
# the gif will be create using the first 5 images
# 5it [00:00, 11.87it/s]
# 2it [00:00, 11.81it/s]
# found 5 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-20h33m28s/figures_training_set/
# the gif will be create using the first 5 images
# 5it [00:00, 11.70it/s]
# GCN_013: 20210721-15h22m13s
# architecture=GCN_HL03_tanh(
#   (conv1): GCNConv(6, 128)
#   (conv2): GCNConv(128, 256)
#   (conv3): GCNConv(256, 64)
#   (conv4): GCNConv(64, 3)
# )
# Plot saved in /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-15h22m13s/20210721-15h22m13s_train_val_loss_plot.png
#
# > DATASETS FOUND
# 2it [00:00, 11.04it/s]
# found 5 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-15h22m13s/figures_validation_set/
# the gif will be create using the first 5 images
# 5it [00:00, 11.05it/s]
# 1it [00:00,  9.82it/s]
# found 5 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-15h22m13s/figures_training_set/
# the gif will be create using the first 5 images
# 5it [00:00, 10.50it/s]
# GCN_013: 20210721-04h08m35s
# architecture=GCN_HL03_tanh(
#   (conv1): GCNConv(6, 128)
#   (conv2): GCNConv(128, 256)
#   (conv3): GCNConv(256, 64)
#   (conv4): GCNConv(64, 3)
# )
# Plot saved in /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-04h08m35s/20210721-04h08m35s_train_val_loss_plot.png
#
# > DATASETS FOUND
# 2it [00:00, 10.95it/s]
# found 5 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-04h08m35s/figures_validation_set/
# the gif will be create using the first 5 images
# 5it [00:00, 11.59it/s]
# 2it [00:00, 10.97it/s]
# found 5 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-04h08m35s/figures_training_set/
# the gif will be create using the first 5 images
# 5it [00:00, 11.42it/s]
# GCN_013: 20210721-13h28m10s
# architecture=GCN_HL03_tanh(
#   (conv1): GCNConv(6, 128)
#   (conv2): GCNConv(128, 256)
#   (conv3): GCNConv(256, 64)
#   (conv4): GCNConv(64, 3)
# )
# Plot saved in /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-13h28m10s/20210721-13h28m10s_train_val_loss_plot.png
#
# > DATASETS FOUND
# 2it [00:00, 10.25it/s]
# found 5 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-13h28m10s/figures_validation_set/
# the gif will be create using the first 5 images
# 5it [00:00, 10.73it/s]
# 2it [00:00, 10.84it/s]
# found 5 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-13h28m10s/figures_training_set/
# the gif will be create using the first 5 images
# 5it [00:00, 11.07it/s]
# GCN_013: 20210721-05h58m07s
# architecture=GCN_HL03_tanh(
#   (conv1): GCNConv(6, 128)
#   (conv2): GCNConv(128, 256)
#   (conv3): GCNConv(256, 64)
#   (conv4): GCNConv(64, 3)
# )
# Plot saved in /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-05h58m07s/20210721-05h58m07s_train_val_loss_plot.png
#
# > DATASETS FOUND
# 2it [00:00, 11.88it/s]
# found 5 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-05h58m07s/figures_validation_set/
# the gif will be create using the first 5 images
# 5it [00:00, 11.70it/s]
# 2it [00:00, 10.74it/s]
# found 5 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_013/20210721-05h58m07s/figures_training_set/
# the gif will be create using the first 5 images
# 5it [00:00, 11.17it/s]

# %%
deleted_folders = delete_empty_r(directory= MODEL_OUTPUT_PATH,printstat = True)
