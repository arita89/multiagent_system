# %%
#--------------------------------
## IMPORTS
#--------------------------------
import sys
import os

# set the path to find the modules
sys.path.insert(0, '../005_src/') #use relative path
#os.chdir("../005_src")

from config import *
# Out:
# ----------------------------------------
# Packages import successful
# Variables import successful
# Helper Functions import successful
# Functions import successful
# Functions xml import successful
# Functions graph import successful
# Functions GCN import successful
# Functions Plotting import successful
# Functions Data Adjustments import successful
# ----------------------------------------
# root directory: /storage/remote/atcremers50/ss21_multiagentcontrol/
# input directory: /storage/remote/atcremers50/ss21_multiagentcontrol/004_data/
# output directory: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/
# ----------------------------------------
#
# ----------------------------------------
# root directory: /storage/remote/atcremers50/ss21_multiagentcontrol/
# input directory: /storage/remote/atcremers50/ss21_multiagentcontrol/004_data/
# output directory: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/
# ----------------------------------------

# %%
device = cudaOverview()
# Out:
# CUDA available
# Number of Devices: 1
# ID current Device NVIDIA GeForce GTX 1050 Ti: 0
# 	current GPU memory usage by tensors in bytes:0
# 	current GPU memory managed by caching allocator in bytes:0

# %%
this_date = "20210711"
ts = "18h36m56s"
GCN_num = "008"
this_GCN = f"GCN_{GCN_num}"

# %%
if GCN_num == "006": 
    from _03_Networks.GCN_006.GCN_model_006 import *
    check_import()
    from _03_Networks.GCN_006.GCN_trainer_006 import *

elif GCN_num == "007": 
    from _03_Networks.GCN_007.GCN_model_007 import *
    check_import()
    from _03_Networks.GCN_007.GCN_trainer_007 import *
    
elif GCN_num == "008": 
    from _03_Networks.GCN_008.GCN_model_008 import *
    check_import()
    from _03_Networks.GCN_008.GCN_trainer_008 import *
# Out:
# imported model: GCN_008 at 15h25m35s
# edges_attr=False

# %% [markdown]
# ## RELOAD

# %%
MODEL_OUTPUT_PATH = os.path.join(OUTPUT_DIR,f"{this_GCN}/")
MODEL_OUTPUT_PATH_TODAY = os.path.join(MODEL_OUTPUT_PATH,f"{this_date}-{ts}/")
print (MODEL_OUTPUT_PATH_TODAY)

dateset_test_path = f"/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/{this_GCN}/{this_date}-{ts}/dataset_test"
dict_text_output_path = f"/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/{this_GCN}/{this_date}-{ts}/{this_date}-{ts}_training_parameters"

dateset_test = pkl.load(open(f'{dateset_test_path}.pkl',"rb"))

reloaded_dict = pkl.load(open(f'{dict_text_output_path}.pkl',"rb"))
#reloaded_dict
# Out:
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/

# %%
# load losses
t_losses_load = pkl.load(open( reloaded_dict['train_losses_path'], 'rb'))
v_losses_load = pkl.load(open( reloaded_dict['val_losses_path'], 'rb'))

# %%
##================================
# TRAIN AND VAL LOSSES
##================================
fig = plot_training(t_losses_load,
                  v_losses_load,
                  learning_rate = None,
                  gaussian=True,
                  sigma=2,
                  figsize=(8, 6),
                  mytitle = 'Training & validation loss'
                  )

description = f"{this_date}-{ts}"
new_png = f"{description}_train_val_loss_plot.png"
new_png_path = os.path.join(MODEL_OUTPUT_PATH_TODAY,new_png)
plt.savefig(new_png_path)
print (f"Plot saved in {new_png_path}")
# Out:
# Plot saved in /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/20210711-18h36m56s_train_val_loss_plot.png

# %%
reloaded_dict
# Out:
# {'input_file_name': '20210710-20h38m27s_timesteps14930_ec3500_em7000',
#  'max_num_veh': 10,
#  'sim_duration_timesteps': '15000',
#  'run_time': '18h36m56s',
#  'model': 'GCN_008',
#  'random_seed': 42,
#  'train_size': 0.9,
#  'batch_size': 8,
#  'Nepochs': 100,
#  'save_every': 50,
#  'transformstat': False,
#  'plotstat': True,
#  'printstat': True,
#  'intentionstat': False,
#  'num_rows_training': 10588,
#  'num_rows_validation': 1059,
#  'num_rows_test': 118,
#  'exclude_yaw': True,
#  'concatenatestat': True,
#  'paddingstat': False,
#  'size_input': 4,
#  'size_output': 2,
#  'model_architecture': GCN(
#    (conv1): GCNConv(4, 64)
#    (conv2): GCNConv(64, 2)
#  ),
#  'criterion': MSELoss(),
#  'optimizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      eps: 1e-08
#      lr: 0.001
#      weight_decay: 0.0005
#  ),
#  'model_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/20210711-18h36m56sEPOCH_100of100_FINAL__GCN_008.pt',
#  'train_losses_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/20210711-18h36m56sEPOCH_100of100_FINAL__FINAL__training_loss.pkl',
#  'val_losses_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/20210711-18h36m56sEPOCH_100of100_FINAL__FINAL__validation_loss.pkl',
#  'lr_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/20210711-18h36m56sEPOCH_100of100_FINAL__FINAL__learning_rate.pkl',
#  'figure_paths': ['/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_010of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_020of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_030of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_040of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_050of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_060of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_070of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_080of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_090of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_100of100.png'],
#  'final_train_loss': 526.9146412160821,
#  'final_val_loss': 546.1482058646984}

# %% [markdown]
# ## Verification
# of results

# %%
# load model
# defining the model
load_model = GCN(num_input_features=reloaded_dict['size_input'],
            num_output_features =reloaded_dict['size_output'],
            random_seed = 42,
            hc_1 = 64,
           )

# %%
load_path = reloaded_dict['model_path']
load_model.load_state_dict(torch.load(load_path))
load_model.eval()
# Out:
# GCN(
#   (conv1): GCNConv(4, 64)
#   (conv2): GCNConv(64, 2)
# )

# %%
plot_results_model(
                   load_model, 
                   dateset_test[0],
                   start_from = 0,
                   end_at = 10,
                   edges_attr = False,
                   figsize = (15,15),
                   plot_input = True,
                   plot_target = True,
                   plot_prediction = True,
                   plot_intention = False, 
                   title = "test",
                  )

# %%
reloaded_dict
# Out:
# {'input_file_name': '20210710-20h38m27s_timesteps14930_ec3500_em7000',
#  'max_num_veh': 10,
#  'sim_duration_timesteps': '15000',
#  'run_time': '18h36m56s',
#  'model': 'GCN_008',
#  'random_seed': 42,
#  'train_size': 0.9,
#  'batch_size': 8,
#  'Nepochs': 100,
#  'save_every': 50,
#  'transformstat': False,
#  'plotstat': True,
#  'printstat': True,
#  'intentionstat': False,
#  'num_rows_training': 10588,
#  'num_rows_validation': 1059,
#  'num_rows_test': 118,
#  'exclude_yaw': True,
#  'concatenatestat': True,
#  'paddingstat': False,
#  'size_input': 4,
#  'size_output': 2,
#  'model_architecture': GCN(
#    (conv1): GCNConv(4, 64)
#    (conv2): GCNConv(64, 2)
#  ),
#  'criterion': MSELoss(),
#  'optimizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      eps: 1e-08
#      lr: 0.001
#      weight_decay: 0.0005
#  ),
#  'model_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/20210711-18h36m56sEPOCH_100of100_FINAL__GCN_008.pt',
#  'train_losses_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/20210711-18h36m56sEPOCH_100of100_FINAL__FINAL__training_loss.pkl',
#  'val_losses_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/20210711-18h36m56sEPOCH_100of100_FINAL__FINAL__validation_loss.pkl',
#  'lr_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/20210711-18h36m56sEPOCH_100of100_FINAL__FINAL__learning_rate.pkl',
#  'figure_paths': ['/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_010of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_020of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_030of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_040of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_050of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_060of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_070of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_080of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_090of100.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/20210711-18h36m56sModel_GCN_008_epoch_100of100.png'],
#  'final_train_loss': 526.9146412160821,
#  'final_val_loss': 546.1482058646984}

# %%
path_GIF= build_gif(folder = f'/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_{GCN_num}/{this_date}-{ts}/figures/',
              title = f"{this_date}-{ts}_validation_shuttle",
              search = "", 
              fps=0.75,
              recursive = True,
              delete_tempFiles = False,
              max_n_images = 200
             )
# Out:
# 2it [00:00, 10.07it/s]
# found 10 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/figures/
# the gif will be create using the first 10 images
# 10it [00:01,  9.51it/s]

# %%
path_GIF
# Out:
# '../004_data/gifs/20210711-18h36m56s_validation_shuttle.gif'

# %%
Image(open(f'{path_GIF}','rb').read())

# %%
deleted_folders = delete_empty_r(directory= OUTPUT_DIR,printstat = True)
