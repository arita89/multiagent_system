# %%
#--------------------------------
## IMPORTS
#--------------------------------
import sys
import os

# set the path to find the modules
os.chdir("../../005_src")

from config import *
print (os.getenv('CONDA_PREFIX'))
# Out:
# ----------------------------------------
# Packages import successful
# Variables import successful
# Helper Functions import successful
# Functions import successful
# Functions xml import successful
# Functions graph import successful
# Functions GCN import successful
# Custom loss imported
# Functions Plotting import successful
# Functions Data Adjustments import successful
# ----------------------------------------
# root directory: /storage/remote/atcremers50/ss21_multiagentcontrol/
# input directory: /storage/remote/atcremers50/ss21_multiagentcontrol/004_data/
# output directory: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/
# ----------------------------------------
#
# ----------------------------------------
# root directory: /storage/remote/atcremers50/ss21_multiagentcontrol/
# input directory: /storage/remote/atcremers50/ss21_multiagentcontrol/004_data/
# output directory: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/
# ----------------------------------------
#
# /usr/prakt/s0014/anaconda3/envs/p37_GCN_GPU

# %%
device = cudaOverview()
device
# Out:
# CUDA available
# Number of Devices: 1
# ID current Device NVIDIA GeForce GTX 1050 Ti: 0
# 	current GPU memory usage by tensors in bytes:0
# 	current GPU memory managed by caching allocator in bytes:0
# device(type='cuda', index=0)

# %%
filenames = sorted(glob.glob(f"{OUTPUT_DIR}"+"/**/*"+f"*training_parameters.pkl", recursive=True))
filenames
# Out:
# ['/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_004/20210710-17h55m10s/20210710-17h55m10s100_FINAL_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_004/20210710-18h23m49s/20210710-18h23m49s_epoch100_FINAL_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_004/20210710-19h08m29s/20210710-19h08m29s_epoch100_FINAL_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_005/20210710-19h42m38s/20210710-19h42m38s_epoch100_FINAL_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_005/20210710-20h00m36s/20210710-20h00m36s_epoch100_FINAL_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_005/20210710-20h14m31s/20210710-20h14m31s_epoch100_FINAL_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_005/20210710-20h32m49s/None_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_006/20210711-10h48m33s/20210711-10h48m33s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_006/20210711-11h26m51s/20210711-11h26m51s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_006/20210711-12h22m43s/20210711-12h22m43s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_006/20210711-12h37m50s/20210711-12h37m50s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_007/20210711-13h15m14s/20210711-13h15m14s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_007/20210711-13h23m09s/20210711-13h23m09s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_007/20210711-14h15m05s/20210711-14h15m05s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_007/20210711-14h18m53s/20210711-14h18m53s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_007/20210711-16h57m29s/20210711-16h57m29s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_007/20210711-17h14m43s/20210711-17h14m43s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_007/20210711-17h22m18s/20210711-17h22m18s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_007/20210711-20h29m48s/20210711-20h29m48s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_007/20210711-20h48m14s/20210711-20h48m14s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_007/20210711-20h53m44s/20210711-20h53m44s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_007/20210711-22h04m22s/20210711-22h04m22s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_007/20210711-22h15m10s/20210711-22h15m10s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_007/20210711-22h25m55s/20210711-22h25m55s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_007/20210711-22h36m46s/20210711-22h36m46s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h17m19s/20210711-18h17m19s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h27m15s/20210711-18h27m15s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-18h36m56s/20210711-18h36m56s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-19h49m16s/20210711-19h49m16s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-19h54m12s/20210711-19h54m12s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_008/20210711-20h14m32s/20210711-20h14m32s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_009/20210714-16h24m31s/20210714-16h24m31s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_009/20210714-19h26m06s/20210714-19h26m06s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN
_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-11h51m42s/20210731-11h51m42s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-11h52m03s/20210731-11h52m03s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-11h52m13s/20210731-11h52m13s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-11h52m24s/20210731-11h52m24s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-12h00m24s/20210731-12h00m24s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-12h06m45s/20210731-12h06m45s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-12h15m02s/20210731-12h15m02s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-12h15m53s/20210731-12h15m53s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-12h18m11s/20210731-12h18m11s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-12h19m00s/20210731-12h19m00s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-12h20m25s/20210731-12h20m25s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-12h21m11s/20210731-12h21m11s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-12h21m48s/20210731-12h21m48s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-12h22m26s/20210731-12h22m26s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-12h31m41s/20210731-12h31m41s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-12h32m29s/20210731-12h32m29s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h16m39s/20210731-15h16m39s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h21m51s/20210731-15h21m51s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h24m53s/20210731-15h24m53s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/20210731-15h28m46s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-16h53m51s/20210731-16h53m51s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-18h16m02s/20210731-18h16m02s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-19h50m12s/20210731-19h50m12s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-21h40m35s/20210731-21h40m35s_training_parameters.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-23h27m25s/20210731-23h27m25s_training_parameters.pkl']

# %%
filenames = sorted(glob.glob(f"{OUTPUT_DIR}"+"/**/*"+f"*training_parameters.pkl", recursive=True))
all_dict = [pkl.load(open(this_file,"rb"))for this_file in filenames]
#all_dict = [pkl.loads(memoryview(open(this_file,"rb"))) for this_file in filenames]

df = pd.DataFrame(all_dict)
# Out:
# at 09h07m23s imported models:
# ['GCN_HL01', 'GCN_HL02', 'GCN_HL03']
# edges_attr=True
# at 09h07m24s imported models:
# ['GCN_HL01_relu', 'GCN_HL01_tanh', 'GCN_HL02_relu', 'GCN_HL02_tanh', 'GCN_HL03_relu', 'GCN_HL03_tanh']
# edges_attr=True
# at 09h07m26s imported models:
# ['GCN_HL01_leaky_relu', 'GCN_HL01_relu', 'GCN_HL01_tanh', 'GCN_HL02_leaky_relu', 'GCN_HL02_relu', 'GCN_HL02_tanh', 'GCN_HL03_leaky_relu', 'GCN_HL03_relu', 'GCN_HL03_tanh']
# at 09h07m32s imported models:
# ['GCN_HL01_bn_relu', 'GCN_HL01_bn_tanh', 'GCN_HL02_bn_relu', 'GCN_HL02_bn_tanh', 'GCN_HL03_bn_relu', 'GCN_HL03_bn_tanh']
# at 09h07m36s imported models:
# ['GCN_HL01_bn_relu', 'GCN_HL01_bn_tanh', 'GCN_HL02_bn_relu', 'GCN_HL02_bn_tanh', 'GCN_HL03_bn_relu', 'GCN_HL03_bn_tanh']
# at 09h07m38s imported models:
# ['HL03_bn']

# %%
df.columns
# Out:
# Index(['run_time', 'model', 'random_seed', 'train_size', 'batch_size',
#        'Nepochs', 'save_every', 'transformstat', 'plotstat', 'printstat',
#        ...
#        'batch_size_023', 'Nepochs_023', 'input_file_name_024',
#        'train_size_024', 'batch_size_024', 'Nepochs_024',
#        'input_file_name_025', 'train_size_025', 'batch_size_025',
#        'Nepochs_025'],
#       dtype='object', length=252)

# %% [markdown]
# # TABLE TRAININGS OVERVIEW
#
# here all the trainings completed succcessfully with a txt file

# %%
df.scheduler.unique()
# Out:
# array([nan,
#        <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7f1b58d47280>,
#        <torch.optim.lr_scheduler.MultiStepLR object at 0x7f1b58d47a00>,
#        <torch.optim.lr_scheduler.CosineAnnealingWarmRestarts object at 0x7f1b58d47d60>,
#        None, 'ReduceLROnPlateau', 'MultiStepLR',
#        'CosineAnnealingWarmRestarts', 'NoneType'], dtype=object)

# %% [markdown]
# # Comparative overviews

# %%
GCN_MODEL = "GCN_017"
MODEL_PATH =os.path.join(OUTPUT_DIR,GCN_MODEL)
MODEL_PATH
# Out:
# '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017'

# %%
columns_with_final_val_losses = sorted([col for col in df.columns if "val_loss" in col])
epoch_val_losses = [re.findall(r'\d+', col) for col in columns_with_final_val_losses]
print (list(zip(columns_with_final_val_losses,epoch_val_losses)))
columns_with_final_train_losses = sorted([col for col in df.columns if "train_loss" in col])
columns_with_final_train_losses
# Out:
# [('epoch100000_final_val_loss', ['100000']), ('epoch10000_final_val_loss', ['10000']), ('epoch1000_final_val_loss', ['1000']), ('epoch100_final_val_loss', ['100']), ('epoch10_final_val_loss', ['10']), ('epoch12000_final_val_loss', ['12000']), ('epoch14000_final_val_loss', ['14000']), ('epoch1500_final_val_loss', ['1500']), ('epoch16000_final_val_loss', ['16000']), ('epoch1_final_val_loss', ['1']), ('epoch20000_final_val_loss', ['20000']), ('epoch2000_final_val_loss', ['2000']), ('epoch200_final_val_loss', ['200']), ('epoch20_final_val_loss', ['20']), ('epoch2500_final_val_loss', ['2500']), ('epoch28000_final_val_loss', ['28000']), ('epoch2_final_val_loss', ['2']), ('epoch30000_final_val_loss', ['30000']), ('epoch3000_final_val_loss', ['3000']), ('epoch300_final_val_loss', ['300']), ('epoch30_final_val_loss', ['30']), ('epoch3500_final_val_loss', ['3500']), ('epoch3_final_val_loss', ['3']), ('epoch40000_final_val_loss', ['40000']), ('epoch4000_final_val_loss', ['4000']), ('epoch400_final_val_loss', ['400']), ('epoch40_final_val_loss', ['40']), ('epoch4500_final_val_loss', ['4500']), ('epoch4_final_val_loss', ['4']), ('epoch50000_final_val_loss', ['50000']), ('epoch5000_final_val_loss', ['5000']), ('epoch500_final_val_loss', ['500']), ('epoch50_final_val_loss', ['50']), ('epoch5_final_val_loss', ['5']), ('epoch60000_final_val_loss', ['60000']), ('epoch6000_final_val_loss', ['6000']), ('epoch600_final_val_loss', ['600']), ('epoch60_final_val_loss', ['60']), ('epoch6_final_val_loss', ['6']), ('epoch70000_final_val_loss', ['70000']), ('epoch7000_final_val_loss', ['7000']), ('epoch700_final_val_loss', ['700']), ('epoch70_final_val_loss', ['70']), ('epoch7_final_val_loss', ['7']), ('epoch80000_final_val_loss', ['80000']), ('epoch8000_final_val_loss', ['8000']), ('epoch800_final_val_loss', ['800']), ('epoch80_final_val_loss', ['80']), ('epoch8_final_val_loss', ['8']), ('epoch90000_final_val_loss', ['90000']), ('epoch9000_final_val_loss', ['9000']), ('epoch900_final_val_loss', ['900']), ('epoch90_final_val_loss', ['90']), ('epoch9_final_val_loss', ['9']), ('final_val_loss', []), ('val_losses_path', [])]
# ['epoch100000_train_loss',
#  'epoch10000_train_loss',
#  'epoch1000_train_loss',
#  'epoch100_train_loss',
#  'epoch10_train_loss',
#  'epoch12000_train_loss',
#  'epoch14000_train_loss',
#  'epoch1500_train_loss',
#  'epoch16000_train_loss',
#  'epoch1_train_loss',
#  'epoch20000_train_loss',
#  'epoch2000_train_loss',
#  'epoch200_train_loss',
#  'epoch20_train_loss',
#  'epoch2500_train_loss',
#  'epoch28000_train_loss',
#  'epoch2_train_loss',
#  'epoch30000_train_loss',
#  'epoch3000_train_loss',
#  'epoch300_train_loss',
#  'epoch30_train_loss',
#  'epoch3500_train_loss',
#  'epoch3_train_loss',
#  'epoch40000_train_loss',
#  'epoch4000_train_loss',
#  'epoch400_train_loss',
#  'epoch40_train_loss',
#  'epoch4500_train_loss',
#  'epoch4_train_loss',
#  'epoch50000_train_loss',
#  'epoch5000_train_loss',
#  'epoch500_train_loss',
#  'epoch50_train_loss',
#  'epoch5_train_loss',
#  'epoch60000_train_loss',
#  'epoch6000_train_loss',
#  'epoch600_train_loss',
#  'epoch60_train_loss',
#  'epoch6_train_loss',
#  'epoch70000_train_loss',
#  'epoch7000_train_loss',
#  'epoch700_train_loss',
#  'epoch70_train_loss',
#  'epoch7_train_loss',
#  'epoch80000_train_loss',
#  'epoch8000_train_loss',
#  'epoch800_train_loss',
#  'epoch80_train_loss',
#  'epoch8_train_loss',
#  'epoch90000_train_loss',
#  'epoch9000_train_loss',
#  'epoch900_train_loss',
#  'epoch90_train_loss',
#  'epoch9_train_loss',
#  'final_train_loss',
#  'train_losses_path']

# %%
abs_min_val = df[columns_with_final_val_losses].min().min()
abs_min_val
# Out:
# 0.11916106045246125

# %%
for col in columns_with_final_val_losses:
    try: 
        min_col = df[col].min()
        if min_col == abs_min_val:
            print (col)
    except Exception as e:
        print (col)
        print (e)
# Out:
# epoch7000_final_val_loss
# val_losses_path
# '<=' not supported between instances of 'float' and 'str'

# %%
df[df["epoch7000_final_val_loss"] == df[columns_with_final_val_losses].min().min()].index
# Out:
# Int64Index([373], dtype='int64')

# %%
abs_min_train = df[columns_with_final_train_losses].min().min()
abs_min_train
# Out:
# 0.026263054460287094

# %%
for col in columns_with_final_train_losses:
    try: 
        min_col = df[col].min()
        if min_col == abs_min_train:
            print (col)
    except Exception as e:
        print (col)
        print (e)
# Out:
# final_train_loss
# train_losses_path
# '<=' not supported between instances of 'float' and 'str'

# %%
df[df["final_train_loss"] == abs_min_train].index
# Out:
# Int64Index([502], dtype='int64')

# %% [markdown]
# ## Compare GCN_017

# %%
df.columns
# Out:
# Index(['run_time', 'model', 'random_seed', 'train_size', 'batch_size',
#        'Nepochs', 'save_every', 'transformstat', 'plotstat', 'printstat',
#        ...
#        'batch_size_023', 'Nepochs_023', 'input_file_name_024',
#        'train_size_024', 'batch_size_024', 'Nepochs_024',
#        'input_file_name_025', 'train_size_025', 'batch_size_025',
#        'Nepochs_025'],
#       dtype='object', length=252)

# %%
mask = (df.model == GCN_MODEL) #and (df.Nepochs == 5000)
df_model = df[mask][[
                'run_date',
                'run_time', 
                'model',
                'Nepochs',
                'batch_size',
                #'input_file_name',
                #'size_input', 
                #'size_output', 
                'model_architecture', 
                'num_rows_training',

                'criterion', 
                'optimizer', 
                #'reduction',
                'scheduler',

                'final_train_loss', 
                'final_val_loss', 
                #'intentionstat', 
                #'model_path',
                'train_losses_path', 
                'val_losses_path',
            
               #'lr',
                'use_edges_attr',
                'activation_function',
                'combo'
                
                   
           ]]
df_model
# Out:
#       run_date   run_time    model  Nepochs  batch_size  \
# 458  20210729-  00h14m26s  GCN_017      500          32
# 459  20210729-  00h38m01s  GCN_017      500          32
# 460  20210729-  01h01m31s  GCN_017      500          32
# 461  20210729-  01h24m34s  GCN_017      500          32
# 462  20210729-  01h47m41s  GCN_017      500          32
# ..         ...        ...      ...      ...         ...
# 527  20210731-  16h53m51s  GCN_017     5000         512
# 528  20210731-  18h16m02s  GCN_017     5000         512
# 529  20210731-  19h50m12s  GCN_017     5000         512
# 530  20210731-  21h40m35s  GCN_017     5000         512
# 531  20210731-  23h27m25s  GCN_017     5000         512
#
#                                     model_architecture  num_rows_training  \
# 458  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
# 459  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
# 460  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
# 461  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
# 462  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
# ..                                                 ...                ...
# 527  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               9412
# 528  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
# 529  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
# 530  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
# 531  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
#
#          criterion                                          optimizer  \
# 458            MSE  Adam (\nParameter Group 0\n    amsgrad: False\...
# 459            MSE  Adam (\nParameter Group 0\n    amsgrad: False\...
# 460            MSE  Adam (\nParameter Group 0\n    amsgrad: False\...
# 461            MSE  Adam (\nParameter Group 0\n    amsgrad: False\...
# 462            MSE  Adam (\nParameter Group 0\n    amsgrad: False\...
# ..             ...                                                ...
# 527  Custom_Loss_2  Adam (\nParameter Group 0\n    amsgrad: False\...
# 528             L1  Adam (\nParameter Group 0\n    amsgrad: False\...
# 529             L1  Adam (\nParameter Group 0\n    amsgrad: False\...
# 530             L1  Adam (\nParameter Group 0\n    amsgrad: False\...
# 531             L1  Adam (\nParameter Group 0\n    amsgrad: False\...
#
#                        scheduler  final_train_loss  final_val_loss  \
# 458  CosineAnnealingWarmRestarts          1.625295        8.810307
# 459  CosineAnnealingWarmRestarts          1.451901        8.375011
# 460                     NoneType          1.486769        4.847999
# 461                     NoneType          0.894670        4.369745
# 462                     NoneType          1.361484        6.550852
# ..                           ...               ...             ...
# 527  CosineAnnealingWarmRestarts         27.191112       26.970671
# 528  CosineAnnealingWarmRestarts          0.374190        0.989920
# 529  CosineAnnealingWarmRestarts          0.720005        1.157170
# 530            ReduceLROnPlateau          0.829010        1.025306
# 531            ReduceLROnPlateau          1.256735        1.509611
#
#                                      train_losses_path  \
# 458  /storage/remote/atcremers50/ss21_multiagentcon...
# 459  /storage/remote/atcremers50/ss21_multiagentcon...
# 460  /storage/remote/atcremers50/ss21_multiagentcon...
# 461  /storage/remote/atcremers50/ss21_multiagentcon...
# 462  /storage/remote/atcremers50/ss21_multiagentcon...
# ..                                                 ...
# 527  /storage/remote/atcremers50/ss21_multiagentcon...
# 528  /storage/remote/atcremers50/ss21_multiagentcon...
# 529  /storage/remote/atcremers50/ss21_multiagentcon...
# 530  /storage/remote/atcremers50/ss21_multiagentcon...
# 531  /storage/remote/atcremers50/ss21_multiagentcon...
#
#                                        val_losses_path use_edges_attr  \
# 458  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 459  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 460  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 461  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 462  /storage/remote/atcremers50/ss21_multiagentcon...           True
# ..                                                 ...            ...
# 527  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 528  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 529  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 530  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 531  /storage/remote/atcremers50/ss21_multiagentcon...           True
#
#     activation_function                                              combo
# 458                relu  (mean, 32, Adam, MSE, [64, 128, 256], 0.001, 0...
# 459      leakyrelurrelu  (mean, 32, Adam, MSE, [64, 128, 256], 0.001, 0...
# 460                relu  (mean, 32, Adam, MSE, [64, 128, 256], 0.001, 0...
# 461      leakyrelurrelu  (mean, 32, Adam, MSE, [64, 128, 256], 0.001, 0...
# 462                relu  (mean, 32, Adam, MSE, [64, 128, 256], 0.001, 0...
# ..                  ...                                                ...
# 527                relu  (mean, 512, Adam, Custom_Loss_2, [64, 128, 256...
# 528                relu  (mean, 512, Adam, L1, [64, 128, 256], 0.01, 0....
# 529                relu  (mean, 512, Adam, L1, [64, 128, 256], 0.01, 0....
# 530                relu  (mean, 512, Adam, L1, [64, 128, 256], 0.01, 0....
# 531                relu  (mean, 512, Adam, L1, [64, 128, 256], 0.01, 0....
#
# [74 rows x 17 columns]

# %%
df.iloc[502].tolist()
# Out:
# ['21h00m16s',
#  'GCN_017',
#  42657,
#  0.8,
#  64,
#  15000,
#  750,
#  False,
#  True,
#  False,
#  'df_only_moving_vehicles',
#  8128,
#  1828,
#  204,
#  'obsoleted',
#  'obsoleted',
#  'obsoleted',
#  6,
#  2,
#  HL03_bn(
#    (actfun): ReLU()
#    (conv1): GraphConv(6, 256)
#    (conv2): GraphConv(256, 512)
#    (conv3): GraphConv(512, 256)
#    (conv4): GraphConv(256, 2)
#    (bn1): GraphNorm(256)
#    (bn2): GraphNorm(512)
#    (bn3): GraphNorm(256)
#  ),
#  nan,
#  'MSE',
#  Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      eps: 1e-08
#      initial_lr: 0.01
#      lr: 0.0008555807786180774
#      weight_decay: 0
#  ),
#  nan,
#  nan,
#  nan,
#  nan,
#  0.026263054460287094,
#  4.8543392296495105,
#  'obsoleted',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/20210730-21h00m16sEPOCH_15000of15000_FINAL__GCN_017.pt',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/20210730-21h00m16sEPOCH_15000of15000_FINAL__FINAL__training_loss.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/20210730-21h00m16sEPOCH_15000of15000_FINAL__FINAL__validation_loss.pkl',
#  '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/20210730-21h00m16sEPOCH_15000of15000_FINAL__FINAL__learning_rate.pkl',
#  10.0,
#  10160,
#  ['/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_000750of15000_611.0928955078125.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_000750of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_000750of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_000750of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_001500of15000_843.8275146484375.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_001500of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_001500of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_001500of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_002250of15000_1014.7360229492188.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_002250of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_002250of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_002250of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_003000of15000_723.618408203125.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_003000of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_003000of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_003000of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_003750of15000_953.1049194335938.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_003750of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_003750of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_003750of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_004500of15000_627.4525756835938.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_004500of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_004500of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_004500of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_005250of15000_686.5015869140625.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_005250of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_005250of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_005250of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_006000of15000_933.5047607421875.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_006000of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_006000of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_006000of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_006750of15000_963.0735473632812.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_006750of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_006750of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_006750of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_007500of15000_897.5663452148438.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_007500of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_007500of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_007500of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_008250of15000_1007.607421875.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_008250of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_008250of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_008250of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_009000of15000_900.0379638671875.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_009000of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_009000of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_009000of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_009750of15000_1083.3267822265625.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_009750of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_009750of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_009750of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_010500of15000_2057.446533203125.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_010500of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_010500of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_010500of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_011250of15000_937.0375366210938.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_011250of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_011250of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_011250of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_012000of15000_988.1375732421875.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_012000of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_012000of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_012000of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_012750of15000_1140.0140380859375.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_012750of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_012750of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_012750of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_013500of15000_1154.1097412109375.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_013500of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_013500of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_013500of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_014250of15000_2705.119873046875.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_014250of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_014250of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_014250of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_015000of15000_2362.133544921875.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_training_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_train_epoch_015000of15000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_015000of15000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210730-21h00m16s/figures_validation_set/ZOOM/20210730-21h00m16sModel_GCN_017_shuttle_val_epoch_015000of15000_ZOOM25.png'],
#  nan,
#  nan,
#  [256, 512, 256],
#  'mean',
#  'CosineAnnealingWarmRestarts',
#  '20210730-',
#  ('mean',
#   64,
#   'Adam',
#   'MSE',
#   [256, 512, 256],
#   0.01,
#   0.6,
#   0,
#   'CosineAnnealingWarmRestarts',
#   False,
#   'relu'),
#  False,
#  'relu',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'GraphConv',
#  'GraphNorm',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
df_top = df_model.sort_values(by=['final_val_loss'])
df_top#[df_top.batch_size == 1024]
# Out:
#       run_date   run_time    model  Nepochs  batch_size  \
# 526  20210731-  15h28m46s  GCN_017     5000         512
# 481  20210729-  15h18m11s  GCN_017     5000         512
# 528  20210731-  18h16m02s  GCN_017     5000         512
# 492  20210730-  15h48m42s  GCN_017      500         512
# 530  20210731-  21h40m35s  GCN_017     5000         512
# ..         ...        ...      ...      ...         ...
# 513  20210731-  12h15m02s  GCN_017       10           4
# 514  20210731-  12h15m53s  GCN_017       10           4
# 508  20210731-  11h52m03s  GCN_017        2           4
# 507  20210731-  11h51m42s  GCN_017        2           4
# 524  20210731-  15h21m51s  GCN_017     5000         512
#
#                                     model_architecture  num_rows_training  \
# 526  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...              19980
# 481  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               9144
# 528  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
# 492  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
# 530  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
# ..                                                 ...                ...
# 513  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...                  8
# 514  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...                  8
# 508  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...                  8
# 507  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...                  8
# 524  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...                130
#
#          criterion                                          optimizer  \
# 526             L1  Adam (\nParameter Group 0\n    amsgrad: False\...
# 481             L1  Adam (\nParameter Group 0\n    amsgrad: False\...
# 528             L1  Adam (\nParameter Group 0\n    amsgrad: False\...
# 492             L1  Adam (\nParameter Group 0\n    amsgrad: False\...
# 530             L1  Adam (\nParameter Group 0\n    amsgrad: False\...
# ..             ...                                                ...
# 513            MSE  Adam (\nParameter Group 0\n    amsgrad: False\...
# 514            MSE  Adam (\nParameter Group 0\n    amsgrad: False\...
# 508            MSE  Adam (\nParameter Group 0\n    amsgrad: False\...
# 507            MSE  Adam (\nParameter Group 0\n    amsgrad: False\...
# 524  Custom_Loss_2  Adam (\nParameter Group 0\n    amsgrad: False\...
#
#                        scheduler  final_train_loss  final_val_loss  \
# 526            ReduceLROnPlateau          0.326645        0.400139
# 481  CosineAnnealingWarmRestarts          0.305009        0.806420
# 528  CosineAnnealingWarmRestarts          0.374190        0.989920
# 492  CosineAnnealingWarmRestarts          0.368672        1.000626
# 530            ReduceLROnPlateau          0.829010        1.025306
# ..                           ...               ...             ...
# 513  CosineAnnealingWarmRestarts        352.278519      793.169128
# 514  CosineAnnealingWarmRestarts       1029.905670     1053.118042
# 508  CosineAnnealingWarmRestarts       1442.812988     1325.805908
# 507  CosineAnnealingWarmRestarts       1345.749084     1370.808350
# 524  CosineAnnealingWarmRestarts      15466.395372     3373.391604
#
#                                      train_losses_path  \
# 526  /storage/remote/atcremers50/ss21_multiagentcon...
# 481  /storage/remote/atcremers50/ss21_multiagentcon...
# 528  /storage/remote/atcremers50/ss21_multiagentcon...
# 492  /storage/remote/atcremers50/ss21_multiagentcon...
# 530  /storage/remote/atcremers50/ss21_multiagentcon...
# ..                                                 ...
# 513  /storage/remote/atcremers50/ss21_multiagentcon...
# 514  /storage/remote/atcremers50/ss21_multiagentcon...
# 508  /storage/remote/atcremers50/ss21_multiagentcon...
# 507  /storage/remote/atcremers50/ss21_multiagentcon...
# 524  /storage/remote/atcremers50/ss21_multiagentcon...
#
#                                        val_losses_path use_edges_attr  \
# 526  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 481  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 528  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 492  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 530  /storage/remote/atcremers50/ss21_multiagentcon...          False
# ..                                                 ...            ...
# 513  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 514  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 508  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 507  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 524  /storage/remote/atcremers50/ss21_multiagentcon...           True
#
#     activation_function                                              combo
# 526                relu  (mean, 512, Adam, L1, [64, 128, 256], 0.01, 0....
# 481                relu  (sum, 512, Adam, L1, [128, 256, 64], 0.001, 0....
# 528                relu  (mean, 512, Adam, L1, [64, 128, 256], 0.01, 0....
# 492                relu  (sum, 512, Adam, L1, [64, 128, 256], 0.001, 0....
# 530                relu  (mean, 512, Adam, L1, [64, 128, 256], 0.01, 0....
# ..                  ...                                                ...
# 513                relu  (mean, 4, Adam, MSE, [256, 512, 256], 0.01, 0....
# 514                relu  (mean, 4, Adam, MSE, [256, 512, 256], 0.01, 0....
# 508                relu  (mean, 4, Adam, MSE, [256, 512, 256], 0.01, 0....
# 507                relu  (mean, 4, Adam, MSE, [256, 512, 256], 0.01, 0....
# 524                relu  (sum, 512, Adam, Custom_Loss_2, [64, 128, 256]...
#
# [74 rows x 17 columns]

# %%
nan_indexes = df['final_val_loss'].index[df['final_val_loss'].apply(np.isnan)]
for idx in nan_indexes:
    print (df.loc[idx])
# Out:
# run_time               17h55m10s
# model                    GCN_004
# random_seed                   42
# train_size                   0.9
# batch_size                   100
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 0, Length: 252, dtype: object
# run_time               18h23m49s
# model                    GCN_004
# random_seed                   42
# train_size                   0.9
# batch_size                   100
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 1, Length: 252, dtype: object
# run_time               19h08m29s
# model                    GCN_004
# random_seed                   42
# train_size                   0.9
# batch_size                   100
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 2, Length: 252, dtype: object
# run_time               19h42m38s
# model                    GCN_005
# random_seed                   42
# train_size                   0.9
# batch_size                   100
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 3, Length: 252, dtype: object
# run_time               20h00m36s
# model                    GCN_005
# random_seed                   42
# train_size                   0.9
# batch_size                    32
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 4, Length: 252, dtype: object
# run_time               20h14m31s
# model                    GCN_005
# random_seed                   42
# train_size                   0.9
# batch_size                    32
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 5, Length: 252, dtype: object
# run_time               20h32m49s
# model                    GCN_005
# random_seed                   42
# train_size                   0.9
# batch_size                    64
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 6, Length: 252, dtype: object
# run_time               17h07m46s
# model                    GCN_011
# random_seed               457362
# train_size                   0.9
# batch_size                   256
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 149, Length: 252, dtype: object
# run_time               17h11m49s
# model                    GCN_011
# random_seed               457362
# train_size                   0.9
# batch_size                   256
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 150, Length: 252, dtype: object
# run_time               17h26m31s
# model                    GCN_011
# random_seed               457362
# train_size                   0.9
# batch_size                   512
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 155, Length: 252, dtype: object
# run_time               17h29m24s
# model                    GCN_011
# random_seed               457362
# train_size                   0.9
# batch_size                   512
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 156, Length: 252, dtype: object
# run_time               21h12m45s
# model                    GCN_013
# random_seed                   42
# train_size                   0.9
# batch_size                   512
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 317, Length: 252, dtype: object
# run_time               10h11m43s
# model                    GCN_013
# random_seed                   42
# train_size                   0.9
# batch_size                   512
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 319, Length: 252, dtype: object
# run_time               11h04m50s
# model                    GCN_013
# random_seed                   42
# train_size                   0.9
# batch_size                   512
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 337, Length: 252, dtype: object
# run_time               16h31m25s
# model                    GCN_014
# random_seed                   42
# train_size                   0.9
# batch_size                   128
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 353, Length: 252, dtype: object
# run_time               08h18m52s
# model                    GCN_014
# random_seed                42314
# train_size                   0.9
# batch_size                   512
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 373, Length: 252, dtype: object
# run_time               18h47m29s
# model                    GCN_015
# random_seed                   42
# train_size                   0.9
# batch_size                    32
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 398, Length: 252, dtype: object
# run_time               16h46m06s
# model                    GCN_015
# random_seed                   42
# train_size                   0.9
# batch_size                     1
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 437, Length: 252, dtype: object
# run_time               20h27m56s
# model                    GCN_015
# random_seed                   42
# train_size                   0.9
# batch_size                     1
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 438, Length: 252, dtype: object
# run_time               20h32m38s
# model                    GCN_015
# random_seed                   42
# train_size                   0.9
# batch_size                     1
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 439, Length: 252, dtype: object
# run_time               22h04m53s
# model                    GCN_015
# random_seed                   42
# train_size                   0.9
# batch_size                     1
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 448, Length: 252, dtype: object
# run_time               22h43m24s
# model                    GCN_015
# random_seed                   42
# train_size                   0.9
# batch_size                     1
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 453, Length: 252, dtype: object
# run_time               22h48m45s
# model                    GCN_015
# random_seed                   42
# train_size                   0.9
# batch_size                     1
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 454, Length: 252, dtype: object
# run_time               09h11m24s
# model                    GCN_015
# random_seed                   42
# train_size                   0.9
# batch_size                     1
#                          ...
# Nepochs_024                  NaN
# input_file_name_025          NaN
# train_size_025               NaN
# batch_size_025               NaN
# Nepochs_025                  NaN
# Name: 457, Length: 252, dtype: object

# %%
# correct incomplete training n 367 at 22h36m37s, stopped at 6000
df_top
# Out:
#       run_date   run_time    model  Nepochs  batch_size  \
# 526  20210731-  15h28m46s  GCN_017     5000         512
# 481  20210729-  15h18m11s  GCN_017     5000         512
# 528  20210731-  18h16m02s  GCN_017     5000         512
# 492  20210730-  15h48m42s  GCN_017      500         512
# 530  20210731-  21h40m35s  GCN_017     5000         512
# ..         ...        ...      ...      ...         ...
# 513  20210731-  12h15m02s  GCN_017       10           4
# 514  20210731-  12h15m53s  GCN_017       10           4
# 508  20210731-  11h52m03s  GCN_017        2           4
# 507  20210731-  11h51m42s  GCN_017        2           4
# 524  20210731-  15h21m51s  GCN_017     5000         512
#
#                                     model_architecture  num_rows_training  \
# 526  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...              19980
# 481  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               9144
# 528  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
# 492  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
# 530  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...               8128
# ..                                                 ...                ...
# 513  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...                  8
# 514  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...                  8
# 508  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...                  8
# 507  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...                  8
# 524  HL03_bn(\n  (actfun): ReLU()\n  (conv1): Graph...                130
#
#          criterion                                          optimizer  \
# 526             L1  Adam (\nParameter Group 0\n    amsgrad: False\...
# 481             L1  Adam (\nParameter Group 0\n    amsgrad: False\...
# 528             L1  Adam (\nParameter Group 0\n    amsgrad: False\...
# 492             L1  Adam (\nParameter Group 0\n    amsgrad: False\...
# 530             L1  Adam (\nParameter Group 0\n    amsgrad: False\...
# ..             ...                                                ...
# 513            MSE  Adam (\nParameter Group 0\n    amsgrad: False\...
# 514            MSE  Adam (\nParameter Group 0\n    amsgrad: False\...
# 508            MSE  Adam (\nParameter Group 0\n    amsgrad: False\...
# 507            MSE  Adam (\nParameter Group 0\n    amsgrad: False\...
# 524  Custom_Loss_2  Adam (\nParameter Group 0\n    amsgrad: False\...
#
#                        scheduler  final_train_loss  final_val_loss  \
# 526            ReduceLROnPlateau          0.326645        0.400139
# 481  CosineAnnealingWarmRestarts          0.305009        0.806420
# 528  CosineAnnealingWarmRestarts          0.374190        0.989920
# 492  CosineAnnealingWarmRestarts          0.368672        1.000626
# 530            ReduceLROnPlateau          0.829010        1.025306
# ..                           ...               ...             ...
# 513  CosineAnnealingWarmRestarts        352.278519      793.169128
# 514  CosineAnnealingWarmRestarts       1029.905670     1053.118042
# 508  CosineAnnealingWarmRestarts       1442.812988     1325.805908
# 507  CosineAnnealingWarmRestarts       1345.749084     1370.808350
# 524  CosineAnnealingWarmRestarts      15466.395372     3373.391604
#
#                                      train_losses_path  \
# 526  /storage/remote/atcremers50/ss21_multiagentcon...
# 481  /storage/remote/atcremers50/ss21_multiagentcon...
# 528  /storage/remote/atcremers50/ss21_multiagentcon...
# 492  /storage/remote/atcremers50/ss21_multiagentcon...
# 530  /storage/remote/atcremers50/ss21_multiagentcon...
# ..                                                 ...
# 513  /storage/remote/atcremers50/ss21_multiagentcon...
# 514  /storage/remote/atcremers50/ss21_multiagentcon...
# 508  /storage/remote/atcremers50/ss21_multiagentcon...
# 507  /storage/remote/atcremers50/ss21_multiagentcon...
# 524  /storage/remote/atcremers50/ss21_multiagentcon...
#
#                                        val_losses_path use_edges_attr  \
# 526  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 481  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 528  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 492  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 530  /storage/remote/atcremers50/ss21_multiagentcon...          False
# ..                                                 ...            ...
# 513  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 514  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 508  /storage/remote/atcremers50/ss21_multiagentcon...           True
# 507  /storage/remote/atcremers50/ss21_multiagentcon...          False
# 524  /storage/remote/atcremers50/ss21_multiagentcon...           True
#
#     activation_function                                              combo
# 526                relu  (mean, 512, Adam, L1, [64, 128, 256], 0.01, 0....
# 481                relu  (sum, 512, Adam, L1, [128, 256, 64], 0.001, 0....
# 528                relu  (mean, 512, Adam, L1, [64, 128, 256], 0.01, 0....
# 492                relu  (sum, 512, Adam, L1, [64, 128, 256], 0.001, 0....
# 530                relu  (mean, 512, Adam, L1, [64, 128, 256], 0.01, 0....
# ..                  ...                                                ...
# 513                relu  (mean, 4, Adam, MSE, [256, 512, 256], 0.01, 0....
# 514                relu  (mean, 4, Adam, MSE, [256, 512, 256], 0.01, 0....
# 508                relu  (mean, 4, Adam, MSE, [256, 512, 256], 0.01, 0....
# 507                relu  (mean, 4, Adam, MSE, [256, 512, 256], 0.01, 0....
# 524                relu  (sum, 512, Adam, Custom_Loss_2, [64, 128, 256]...
#
# [74 rows x 17 columns]

# %%
best_k = df_top.iloc[0].run_time

# %%
t_losses = {}
TOP = 1
for r in df_top.index[:TOP]:
    t_loss_path = df_top.loc[r]['train_losses_path']
    model_details = df_top.loc[r]
    t_loss_load = pkl.load(open(t_loss_path, 'rb'))
    t_losses[r] = (t_loss_load, model_details.to_dict())
v_losses = {}
for r in df_top.index[:TOP]:
    v_loss_path = df_top.loc[r]['val_losses_path']
    model_details = df_top.loc[r]
    v_loss_load = pkl.load(open(v_loss_path, 'rb'))
    v_losses[r] = (v_loss_load, model_details.to_dict())
fig = compare_losses(
                   t_losses,
                   title_1 = "losses_training",
                   columns = ["run_time","batch_size"],
                     
                   #losses_dict_2 = v_losses,
                   #title_2 = "losses_validation",
                   #columns_2 = ["model","scheduler"],
                   gaussian=True,
                   sigma=2,
                   figsize=(20, 8),
                ) 

fig = compare_losses(
                   v_losses,
                   title_1 = "losses_validation",
                   columns = ["scheduler",'use_edges_attr', "activation_function"],
                     
                   #losses_dict_2 = v_losses,
                   #title_2 = "losses_validation",
                   #columns_2 = ["model","scheduler"],
                   gaussian=True,
                   sigma=2,
                   figsize=(20, 8),
                )
# Out:
# Comparing 1 models
# possible keys to choose from:
# : ['run_date', 'run_time', 'model', 'Nepochs', 'batch_size', 'model_architecture', 'num_rows_training', 'criterion', 'optimizer', 'scheduler', 'final_train_loss', 'final_val_loss', 'train_losses_path', 'val_losses_path', 'use_edges_attr', 'activation_function', 'combo']
# min_len=18750
# Comparing 1 models
# possible keys to choose from:
# : ['run_date', 'run_time', 'model', 'Nepochs', 'batch_size', 'model_architecture', 'num_rows_training', 'criterion', 'optimizer', 'scheduler', 'final_train_loss', 'final_val_loss', 'train_losses_path', 'val_losses_path', 'use_edges_attr', 'activation_function', 'combo']
# min_len=18750

# %%
mask = df.run_time == best_k
print ("-"*80)
print (f"\n {best_k}\n")
print (dict(df[mask]['optimizer']))

architecture = dict(df[mask]['model_architecture'])
print (architecture)
#first_key = list(architecture.keys())[0]
#str(type(architecture[first_key]))[:]
#print (df[mask].T)
# Out:
# --------------------------------------------------------------------------------
#
#  15h28m46s
#
# {526: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.01
#     lr: 7.734740790612168e-11
#     weight_decay: 0
# )}
# {526: HL03_bn(
#   (actfun): ReLU()
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 2)
#   (bn1): GraphNorm(64)
#   (bn2): GraphNorm(128)
#   (bn3): GraphNorm(256)
# )}

# %% [markdown]
# ## details of all models

# %%
all_t_losses = {}
for r in df_top.index[:]:
    t_loss_path = df_top.loc[r]['train_losses_path']
    model_details = df_top.loc[r]
    t_loss_load = pkl.load(open(t_loss_path, 'rb'))
    all_t_losses[r] = (t_loss_load, model_details.to_dict())

for v in all_t_losses.values():
    k = v[1]['run_time']
    mask = df.run_time == k #"16h45m18s"
    print ("-"*80)
    print (f"\n>{k}")
    print (f"final training: {df[mask]['final_train_loss'].values}") 
    print (f"final validation: {df[mask]['final_val_loss'].values}\n ")
    
    print (list(df[mask]['batch_size']))
    print (list(df[mask]['scheduler']))
    print (list(df[mask]['optimizer']))
    print (list(df[mask]['model_architecture']))

# %% [markdown]
# ## details of best models

# %%
list(t_losses.keys())
# Out:
# [526]

# %%
best_combos = {}
for v in t_losses.values():
    k = v[1]['run_time']

    mask = df.run_time == k #"16h45m18s"
    print ("-"*80)
    date = df[mask]['run_date'].values[0]
    print (f"\n>{date}{k}")
    print (f"N epochs: {df[mask]['Nepochs'].values[0]}")
    print (f"num_rows_training: {df[mask]['num_rows_training'].values}") 
    print (f"final training: {df[mask]['final_train_loss'].values}") 
    print (f"final validation: {df[mask]['final_val_loss'].values}\n ")
    
    
    additional_info = {column:df[mask][column].values[0] 
                       for column in list(df.columns)} 
    
    combo =  df[mask]['combo'].values[0]
    combo = [e for e in combo]
    print (combo)
    best_combos[f"{date}{k}"] = [combo,additional_info]
# Out:
# --------------------------------------------------------------------------------
#
# >20210731-15h28m46s
# N epochs: 5000
# num_rows_training: [19980]
# final training: [0.32664456]
# final validation: [0.40013876]
#
# ['mean', 512, 'Adam', 'L1', [64, 128, 256], 0.01, 0.6, 0, 'CosineAnnealingWarmRestarts', True, 'relu']

# %%
#best_combos
#MODEL_PATH

#description = f"{this_date}{ts}"
dict_best_combos_descr = f"{GCN_MODEL}_best_combos"
dict_best_combos_path = os.path.join(MODEL_PATH,dict_best_combos_descr)

# store parameters as a pickle
with open(f'{dict_best_combos_path}.pkl', 'wb') as handle:
    pkl.dump(best_combos, handle, protocol=pkl.HIGHEST_PROTOCOL)

print (dict_best_combos_path)
# Out:
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/GCN_017_best_combos

# %%
# reload combos

reloaded_best_combos = pkl.load(open(f'{dict_best_combos_path}.pkl',"rb"))
for k,v in reloaded_best_combos.items():
    print ()
    print (v[0])
    print ()
    for kk,vv in v[1].items():
        print (f"{kk}:{vv}")
    #print (v[1])
# Out:
# ['mean', 512, 'Adam', 'L1', [64, 128, 256], 0.01, 0.6, 0, 'CosineAnnealingWarmRestarts', True, 'relu']
#
# run_time:15h28m46s
# model:GCN_017
# random_seed:4267
# train_size:0.8
# batch_size:512
# Nepochs:5000
# save_every:1250
# transformstat:False
# plotstat:True
# printstat:False
# input_file_name:20210710-20h38m27s_timesteps14930_ec3500_em7000
# num_rows_training:19980
# num_rows_validation:4496
# num_rows_test:500
# exclude_yaw:obsoleted
# concatenatestat:obsoleted
# paddingstat:obsoleted
# size_input:6
# size_output:2
# model_architecture:HL03_bn(
#   (actfun): ReLU()
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 2)
#   (bn1): GraphNorm(64)
#   (bn2): GraphNorm(128)
#   (bn3): GraphNorm(256)
# )
# tloss_path:nan
# criterion:L1
# optimizer:Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.01
#     lr: 7.734740790612168e-11
#     weight_decay: 0
# )
# final_loss:nan
# train:nan
# val:nan
# lr:nan
# final_train_loss:0.3266445604654459
# final_val_loss:0.4001387589507633
# intentionstat:obsoleted
# model_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/20210731-15h28m46sEPOCH_18750of30000_TEMP__GCN_017.pt
# train_losses_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/20210731-15h28m46sEPOCH_18750of30000_TEMP__TEMP__training_loss.pkl
# val_losses_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/20210731-15h28m46sEPOCH_18750of30000_TEMP__TEMP__validation_loss.pkl
# lr_path:/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/20210731-15h28m46sEPOCH_18750of30000_TEMP__TEMP__learning_rate.pkl
# max_num_veh:10.0
# sim_duration_timesteps:30000
# figure_paths:['/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_000250of5000_13.368646621704102.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_000250of5000_ZOOM25.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_000250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_000250of5000_ZOOM25.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_000500of5000_12.766286849975586.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_000500of5000_ZOOM25.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_000500of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_000500of5000_ZOOM25.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_000750of5000_11.111258506774902.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_000750of5000_ZOOM25.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_000750of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_000750of5000_ZOOM25.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_001000of5000_12.498326301574707.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_001000of5000_ZOOM25.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_001000of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_001000of5000_ZOOM25.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_001250of5000_11.940237045288086.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_001250of5000_ZOOM25.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_001250of5000.png', '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_001250of5000_ZOOM25.png', '/storage/r ...
# shuttle_train_frame:nan
# shuttle_val_frame:nan
# hidden_layers_sizes:[64, 128, 256]
# reduction:mean
# scheduler:ReduceLROnPlateau
# run_date:20210731-
# combo:('mean', 512, 'Adam', 'L1', [64, 128, 256], 0.01, 0.6, 0, 'CosineAnnealingWarmRestarts', True, 'relu')
# use_edges_attr:True
# activation_function:relu
# epoch14000_train_loss:nan
# epoch14000_final_val_loss:nan
# epoch28000_train_loss:nan
# epoch28000_final_val_loss:nan
# epoch2500_train_loss:nan
# epoch2500_final_val_loss:nan
# epoch5000_train_loss:nan
# epoch5000_final_val_loss:nan
# epoch4000_train_loss:nan
# epoch4000_final_val_loss:nan
# epoch8000_train_loss:nan
# epoch8000_final_val_loss:nan
# epoch12000_train_loss:nan
# epoch12000_final_val_loss:nan
# epoch16000_train_loss:nan
# epoch16000_final_val_loss:nan
# epoch20000_train_loss:nan
# epoch20000_final_val_loss:nan
# epoch1_train_loss:nan
# epoch1_final_val_loss:nan
# epoch2_train_loss:nan
# epoch2_final_val_loss:nan
# epoch3_train_loss:nan
# epoch3_final_val_loss:nan
# epoch4_train_loss:nan
# epoch4_final_val_loss:nan
# epoch5_train_loss:nan
# epoch5_final_val_loss:nan
# epoch500_train_loss:nan
# epoch500_final_val_loss:nan
# epoch1000_train_loss:nan
# epoch1000_final_val_loss:nan
# epoch1500_train_loss:nan
# epoch1500_final_val_loss:nan
# epoch2000_train_loss:nan
# epoch2000_final_val_loss:nan
# epoch3000_train_loss:nan
# epoch3000_final_val_loss:nan
# epoch3500_train_loss:nan
# epoch3500_final_val_loss:nan
# epoch4500_train_loss:nan
# epoch4500_final_val_loss:nan
# epoch6000_train_loss:nan
# epoch6000_final_val_loss:nan
# input_file_name_002:20210711-17h59m44s_timesteps30000_ec3500_em7000
# train_size_002:0.8
# batch_size_002:523.0
# Nepochs_002:25000.0
# epoch7000_train_loss:nan
# epoch7000_final_val_loss:nan
# input_file_name_003:nan
# train_size_003:nan
# batch_size_003:nan
# Nepochs_003:nan
# input_file_name_004:nan
# train_size_004:nan
# batch_size_004:nan
# Nepochs_004:nan
# input_file_name_005:nan
# train_size_005:nan
# batch_size_005:nan
# Nepochs_005:nan
# input_file_name_006:nan
# train_size_006:nan
# batch_size_006:nan
# Nepochs_006:nan
# input_file_name_007:nan
# train_size_007:nan
# batch_size_007:nan
# Nepochs_007:nan
# input_file_name_008:nan
# train_size_008:nan
# batch_size_008:nan
# Nepochs_008:nan
# epoch9000_train_loss:nan
# epoch9000_final_val_loss:nan
# epoch10000_train_loss:nan
# epoch10000_final_val_loss:nan
# epoch30000_train_loss:nan
# epoch30000_final_val_loss:nan
# epoch40000_train_loss:nan
# epoch40000_final_val_loss:nan
# epoch50000_train_loss:nan
# epoch50000_final_val_loss:nan
# epoch60000_train_loss:nan
# epoch60000_final_val_loss:nan
# epoch70000_train_loss:nan
# epoch70000_final_val_loss:nan
# epoch80000_train_loss:nan
# epoch80000_final_val_loss:nan
# epoch90000_train_loss:nan
# epoch90000_final_val_loss:nan
# epoch100000_train_loss:nan
# epoch100000_final_val_loss:nan
# epoch100_train_loss:nan
# epoch100_final_val_loss:nan
# epoch200_train_loss:nan
# epoch200_final_val_loss:nan
# epoch300_train_loss:nan
# epoch300_final_val_loss:nan
# epoch400_train_loss:nan
# epoch400_final_val_loss:nan
# epoch600_train_loss:nan
# epoch600_final_val_loss:nan
# epoch700_train_loss:nan
# epoch700_final_val_loss:nan
# epoch800_train_loss:nan
# epoch800_final_val_loss:nan
# epoch900_train_loss:nan
# epoch900_final_val_loss:nan
# epoch10_train_loss:nan
# epoch10_final_val_loss:nan
# epoch20_train_loss:nan
# epoch20_final_val_loss:nan
# epoch30_train_loss:nan
# epoch30_final_val_loss:nan
# epoch40_train_loss:nan
# epoch40_final_val_loss:nan
# epoch50_train_loss:nan
# epoch50_final_val_loss:nan
# epoch60_train_loss:nan
# epoch60_final_val_loss:nan
# epoch70_train_loss:nan
# epoch70_final_val_loss:nan
# epoch80_train_loss:nan
# epoch80_final_val_loss:nan
# epoch90_train_loss:nan
# epoch90_final_val_loss:nan
# epoch6_train_loss:nan
# epoch6_final_val_loss:nan
# epoch7_train_loss:nan
# epoch7_final_val_loss:nan
# epoch8_train_loss:nan
# epoch8_final_val_loss:nan
# epoch9_train_loss:nan
# epoch9_final_val_loss:nan
# layer_type:GraphConv
# normalization:GraphNorm
# input_file_name_009:nan
# train_size_009:nan
# batch_size_009:nan
# Nepochs_009:nan
# input_file_name_010:nan
# train_size_010:nan
# batch_size_010:nan
# Nepochs_010:nan
# input_file_name_011:nan
# train_size_011:nan
# batch_size_011:nan
# Nepochs_011:nan
# input_file_name_012:nan
# train_size_012:nan
# batch_size_012:nan
# Nepochs_012:nan
# input_file_name_013:nan
# train_size_013:nan
# batch_size_013:nan
# Nepochs_013:nan
# input_file_name_014:nan
# train_size_014:nan
# batch_size_014:nan
# Nepochs_014:nan
# input_file_name_015:nan
# train_size_015:nan
# batch_size_015:nan
# Nepochs_015:nan
# input_file_name_016:nan
# train_size_016:nan
# batch_size_016:nan
# Nepochs_016:nan
# input_file_name_017:nan
# train_size_017:nan
# batch_size_017:nan
# Nepochs_017:nan
# input_file_name_018:nan
# train_size_018:nan
# batch_size_018:nan
# Nepochs_018:nan
# input_file_name_019:nan
# train_size_019:nan
# batch_size_019:nan
# Nepochs_019:nan
# input_file_name_020:nan
# train_size_020:nan
# batch_size_020:nan
# Nepochs_020:nan
# input_file_name_021:nan
# train_size_021:nan
# batch_size_021:nan
# Nepochs_021:nan
# input_file_name_022:nan
# train_size_022:nan
# batch_size_022:nan
# Nepochs_022:nan
# input_file_name_023:nan
# train_size_023:nan
# batch_size_023:nan
# Nepochs_023:nan
# input_file_name_024:nan
# train_size_024:nan
# batch_size_024:nan
# Nepochs_024:nan
# input_file_name_025:nan
# train_size_025:nan
# batch_size_025:nan
# Nepochs_025:nan

# %%
all_combos = [v[0] for k,v in reloaded_best_combos.items()]
all_combos
# Out:
# [['mean',
#   512,
#   'Adam',
#   'L1',
#   [64, 128, 256],
#   0.01,
#   0.6,
#   0,
#   'CosineAnnealingWarmRestarts',
#   True,
#   'relu']]

# %%
# check if the value is in the bunch
