# %%
#--------------------------------
## IMPORTS
#--------------------------------
import sys
import os

# set the path to find the modules
sys.path.insert(0, '../../005_src/') #use relative path
os.chdir("../../005_src")

from config import *
# Out:
# ----------------------------------------
# Packages import successful
# Variables import successful
# Helper Functions import successful
# Functions import successful
# Functions xml import successful
# Functions graph import successful
# Functions GCN import successful
# Custom loss imported
# Functions Plotting import successful
# Functions Data Adjustments import successful
# ----------------------------------------
# root directory: /storage/remote/atcremers50/ss21_multiagentcontrol/
# input directory: /storage/remote/atcremers50/ss21_multiagentcontrol/004_data/
# output directory: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/
# ----------------------------------------
#
# ----------------------------------------
# root directory: /storage/remote/atcremers50/ss21_multiagentcontrol/
# input directory: /storage/remote/atcremers50/ss21_multiagentcontrol/004_data/
# output directory: /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/
# ----------------------------------------

# %%
device = cudaOverview()
# Out:
# CUDA available
# Number of Devices: 1
# ID current Device NVIDIA GeForce GTX 1050 Ti: 0
# 	current GPU memory usage by tensors in bytes:0
# 	current GPU memory managed by caching allocator in bytes:0

# %%
this_date = "20210731"
ts = "15h28m46s"
GCN_num = "017"
this_GCN = f"GCN_{GCN_num}"
print (this_GCN)

from _03_Networks.GCN_017.GCN_model_017 import *
from _03_Networks.GCN_017.GCN_trainer_017 import *
from _03_Networks.GCN_017.GCN_parameters_017 import *
from _03_Networks.GCN_017.Custom_losses import *
this_GCN, ts_import = check_import()
# Out:
# GCN_017
# at 17h53m47s imported models:
# ['HL03_bn']
# imported parameters from: GCN_parameters_017.py at 17h53m47s
# imported trainer: GCN_017 at 17h53m47s

# %% [markdown]
# ## Reload dictionary

# %%
MODEL_OUTPUT_PATH = os.path.join(OUTPUT_DIR,f"{this_GCN}/")
MODEL_OUTPUT_PATH_TODAY = os.path.join(MODEL_OUTPUT_PATH,f"{this_date}-{ts}/")
print (MODEL_OUTPUT_PATH_TODAY)
# Out:
# /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/

# %%
dict_text_output_path = f"/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/{this_GCN}/{this_date}-{ts}/{this_date}-{ts}_training_parameters"

reloaded_dict = pkl.load(open(f'{dict_text_output_path}.pkl',"rb"))
reloaded_dict
# Out:
# {'input_file_name': '20210710-20h38m27s_timesteps14930_ec3500_em7000',
#  'max_num_veh': 10,
#  'sim_duration_timesteps': '15000',
#  'train_size': 0.8,
#  'batch_size': 512,
#  'Nepochs': 5000,
#  'run_date': '20210731-',
#  'run_time': '15h28m46s',
#  'model': 'GCN_017',
#  'combo': ('mean',
#   512,
#   'Adam',
#   'L1',
#   [64, 128, 256],
#   0.01,
#   0.6,
#   0,
#   'CosineAnnealingWarmRestarts',
#   True,
#   'relu'),
#  'random_seed': 4267,
#  'save_every': 250,
#  'transformstat': False,
#  'plotstat': True,
#  'printstat': False,
#  'intentionstat': 'obsoleted',
#  'use_edges_attr': True,
#  'activation_function': 'relu',
#  'shuttle_train_frame': None,
#  'shuttle_val_frame': None,
#  'num_rows_training': 9412,
#  'num_rows_validation': 2117,
#  'num_rows_test': 236,
#  'exclude_yaw': 'obsoleted',
#  'concatenatestat': 'obsoleted',
#  'paddingstat': 'obsoleted',
#  'size_input': 6,
#  'size_output': 2,
#  'model_architecture': HL03_bn(
#    (actfun): ReLU()
#    (conv1): GraphConv(6, 64)
#    (conv2): GraphConv(64, 128)
#    (conv3): GraphConv(128, 256)
#    (conv4): GraphConv(256, 2)
#    (bn1): GraphNorm(64)
#    (bn2): GraphNorm(128)
#    (bn3): GraphNorm(256)
#  ),
#  'hidden_layers_sizes': [64, 128, 256],
#  'layer_type': 'GraphConv',
#  'normalization': 'GraphNorm',
#  'criterion': 'L1',
#  'optimizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      eps: 1e-08
#      initial_lr: 0.01
#      lr: 0.007734740790612167
#      weight_decay: 0
#  ),
#  'reduction': 'mean',
#  'scheduler': 'CosineAnnealingWarmRestarts',
#  'model_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/20210731-15h28m46sEPOCH_5000of5000_FINAL__GCN_017.pt',
#  'train_losses_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/20210731-15h28m46sEPOCH_5000of5000_FINAL__FINAL__training_loss.pkl',
#  'val_losses_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/20210731-15h28m46sEPOCH_5000of5000_FINAL__FINAL__validation_loss.pkl',
#  'lr_path': '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/20210731-15h28m46sEPOCH_5000of5000_FINAL__FINAL__learning_rate.pkl',
#  'final_train_loss': 0.3325507131062056,
#  'final_val_loss': 0.8098608970642089,
#  'figure_paths': ['/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_000250of5000_13.368646621704102.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_000250of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_000250of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_000250of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_000500of5000_12.766286849975586.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_000500of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_000500of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_000500of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_000750of5000_11.111258506774902.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_000750of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_000750of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_000750of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_001000of5000_12.498326301574707.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_001000of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_001000of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_001000of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_001250of5000_11.940237045288086.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_001250of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_001250of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_001250of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_001500of5000_12.051793098449707.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_001500of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_001500of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_001500of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_001750of5000_12.623371124267578.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_001750of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_001750of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_001750of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_002000of5000_10.447176933288574.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_002000of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_002000of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_002000of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_002250of5000_10.130427360534668.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_002250of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_002250of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_002250of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_002500of5000_11.411818504333496.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_002500of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_002500of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_002500of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_002750of5000_13.679896354675293.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_002750of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_002750of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_002750of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_003000of5000_12.619194984436035.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_003000of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_003000of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_003000of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_003250of5000_12.668006896972656.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_003250of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_003250of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_003250of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_003500of5000_12.0333833694458.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_003500of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_003500of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_003500of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_003750of5000_12.550605773925781.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_003750of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_003750of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_003750of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_004000of5000_12.602402687072754.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_004000of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_004000of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_004000of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_004250of5000_11.496417999267578.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_004250of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_004250of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_004250of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_004500of5000_12.304579734802246.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_004500of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_004500of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_004500of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_004750of5000_12.558419227600098.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_004750of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_004750of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_004750of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_005000of5000_13.36276912689209.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_train_epoch_005000of5000_ZOOM25.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_005000of5000.png',
#   '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/ZOOM/20210731-15h28m46sModel_GCN_017_shuttle_val_epoch_005000of5000_ZOOM25.png']}

# %%
input_file_name = reloaded_dict["input_file_name"]
reloaded_dict["model_architecture"]
# Out:
# HL03_bn(
#   (actfun): ReLU()
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 2)
#   (bn1): GraphNorm(64)
#   (bn2): GraphNorm(128)
#   (bn3): GraphNorm(256)
# )

# %% [markdown]
# ## Plot losses

# %%
# first lossess paths

curr_epoch = 5000
tot_epoch = 5000
type_epoch = "FINAL"

# %%
# load losses

#if type_epoch == "TEMP":
load_path_files = os.path.join(MODEL_OUTPUT_PATH_TODAY,f"{this_date}-{ts}EPOCH_{curr_epoch}of{tot_epoch}_{type_epoch}__{type_epoch}__")
t_0_5000_path =  f"{load_path_files}training_loss.pkl"
v_0_5000_path =  f"{load_path_files}validation_loss.pkl"
lr_0_5000_path = f"{load_path_files}learning_rate.pkl"
t_losses_load = pkl.load(open(t_0_5000_path, 'rb'))
v_losses_load = pkl.load(open(v_0_5000_path, 'rb'))
lr_load = pkl.load(open(lr_0_5000_path, 'rb'))
#else: 
  # load losses
    #t_losses_load.extend(pkl.load(open( reloaded_dict['train_losses_path'], 'rb')))
    #v_losses_load.extend(pkl.load(open( reloaded_dict['val_losses_path'], 'rb')))
    #lr_load.extend(pkl.load(open( reloaded_dict['lr_path'], 'rb')))

# %%
##================================
# TRAIN AND VAL LOSSES
##================================
fig = plot_training(t_losses_load,
                  v_losses_load,
                  learning_rate = lr_load,
                  gaussian=True,
                  sigma=2,
                  figsize=(20, 6),
                  mytitle = 'Training & validation loss'
                  )

description = f"{this_date}-{ts}"
new_png = f"{description}_train_val_loss_plot.png"
new_png_path = os.path.join(MODEL_OUTPUT_PATH_TODAY,new_png)
plt.savefig(new_png_path)
print (f"Plot saved in {new_png_path}")
# Out:
# Plot saved in /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/20210731-15h28m46s_train_val_loss_plot.png

# %% [markdown]
# ## Verification
# of results

# %%
hidden_layers_sizes = reloaded_dict["hidden_layers_sizes"]
size_input = reloaded_dict['size_input']
size_output = reloaded_dict['size_output']
random_seed = reloaded_dict["random_seed"]
activation_fun = reloaded_dict["activation_function"]

# %%
##================================
## MODEL INIT
##================================
num_hidden_layers = len(hidden_layers_sizes)
    
#print (printstat)
#pdb.set_trace()
if num_hidden_layers == 3:

            hc_1 = hidden_layers_sizes[0]
            hc_2 = hidden_layers_sizes[1]
            hc_3 = hidden_layers_sizes[2]

            model = HL03_bn(
                                num_input_features=size_input,
                                num_output_features =size_output,
                                random_seed = random_seed,
                                hc_1 = hc_1,
                                hc_2 = hc_2,
                                hc_3 = hc_3,
                                activation_function = activation_fun,
                                layer_type = layer_type,
                                normalization = normalization,
                                printstat = printstat,                
                                )
load_model = model

# %%
load_path = reloaded_dict['model_path']
load_model.load_state_dict(torch.load(load_path))
load_model.eval()
# Out:
# HL03_bn(
#   (actfun): ReLU()
#   (conv1): GraphConv(6, 64)
#   (conv2): GraphConv(64, 128)
#   (conv3): GraphConv(128, 256)
#   (conv4): GraphConv(256, 2)
#   (bn1): GraphNorm(64)
#   (bn2): GraphNorm(128)
#   (bn3): GraphNorm(256)
# )

# %%
MODEL_OUTPUT_PATH = os.path.join(OUTPUT_DIR,f"{this_GCN}/")
MODEL_OUTPUT_PATH_DATASETS = os.path.join(MODEL_OUTPUT_PATH,f"DATASETS/")
datasets_list = sorted(glob.glob(f"{MODEL_OUTPUT_PATH_DATASETS}"+"/**/*"+f'{input_file_name}_dataset*',
                                     recursive=True))
if len( datasets_list) == 5:                               
        print ("\n> DATASETS FOUND")
        print (*datasets_list, sep = "\n")
        
        dataset_train = torch.load(datasets_list[0], map_location=torch.device('cpu') )
        # map_location=lambda storage, loc: storage.cuda(0))
        dataset_val = torch.load(datasets_list[1], map_location=torch.device('cpu') )
        dataset_test = torch.load(datasets_list[2], map_location=torch.device('cpu') )
        dataset_shuttle_train = torch.load(datasets_list[3], map_location=torch.device('cpu') )
        dataset_shuttle_val = torch.load(datasets_list[4], map_location=torch.device('cpu') )

# %%
path_GIF= build_gif(folder = f'/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_{GCN_num}/{this_date}-{ts}/figures_validation_set/',
              title = "Predictions over epochs",
              search = "", 
              fps=0.5,
              recursive = True,
              delete_tempFiles = False,
              max_n_images = 200
             )
# Out:
# 2it [00:00, 12.66it/s]
# found 41 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_validation_set/
# the gif will be create using the first 41 images
# 22it [00:02,  5.26it/s]
# Could not find a format to read the specified file in single-image mode
# 41it [00:03, 10.32it/s]

# %%
Image(open(f'{path_GIF}','rb').read())

# %%
path_GIF= build_gif(folder = f'/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_{GCN_num}/{this_date}-{ts}/figures_training_set/',
              title = "Predictions over epochs",
              search = "", 
              fps=0.5,
              recursive = True,
              delete_tempFiles = False,
              max_n_images = 200
             )
# Out:
# 2it [00:00, 10.55it/s]
# found 41 images in folder : /storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/20210731-15h28m46s/figures_training_set/
# the gif will be create using the first 41 images
# 23it [00:02, 12.71it/s]
# Could not find a format to read the specified file in single-image mode
# 41it [00:03, 11.69it/s]

# %%
Image(open(f'{path_GIF}','rb').read())

# %%
#deleted_folders = delete_empty_r(directory= MODEL_OUTPUT_PATH,printstat = True)

# %% [markdown]
# ## try with many different images... any difference?

# %%
MODEL_OUTPUT_PATH
# Out:
# '/storage/remote/atcremers50/ss21_multiagentcontrol/006_model_output/GCN_017/'

# %%
dateset_train_path = f"{MODEL_OUTPUT_PATH}DATASETS/df_only_moving_vehicles_9144_IN_data_pos_zc_data_x_rad_still_vehicle_OUT_data_y_zc__dataset_01_train.pt"
dateset_train = torch.load(f'{dateset_train_path}')

# %%
dateset_train
# Out:
# [Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[36], edge_index=[2, 36], x=[9, 6], y=[9, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[36], edge_index=[2, 36], x=[9, 6], y=[9, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[36], edge_index=[2, 36], x=[9, 6], y=[9, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[28], edge_index=[2, 28], x=[8, 6], y=[8, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[6], edge_index=[2, 6], x=[4, 6], y=[4, 2]),
#  Data(edge_attr=[21], edge_index=[2, 21], x=[7, 6], y=[7, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[36], edge_index=[2, 36], x=[9, 6], y=[9, 2]),
#  Data(edge_attr=[45], edge_index=[2, 45], x=[10, 6], y=[10, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[10], edge_index=[2, 10], x=[5, 6], y=[5, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[3], edge_index=[2, 3], x=[3, 6], y=[3, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  Data(edge_attr=[15], edge_index=[2, 15], x=[6, 6], y=[6, 2]),
#  Data(edge_attr=[1], edge_index=[2, 1], x=[2, 6], y=[2, 2]),
#  ...]

# %%
len(dateset_train)
# Out:
# 9144

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
losses = losses_results_model(
                       load_model, 
                       dateset_train,
                       device = "cpu",
                       start_from = 0,
                       end_at = len(dateset_train),
                       edges_attr = True,
        
                       printstat = False,       
                       loss_stat = "L1"
                      )
print (min(losses))
print (max(losses))
print (mean(losses))
# Out:
# 1.274865746498108
# 50.086063385009766
# 15.626353867501933

# %%
min_ind = losses.index(min(losses))
max_ind = losses.index(max(losses))

# %%
space = 100
loss = plot_results_model(
                       load_model, 
                       dateset_train,
                       start_from = min_ind,
                       end_at = min_ind+1,
                       edges_attr = True,
                       figsize = (5,5),
                       plot_input = True,
                       plot_target = True,
                       plot_prediction = True,
                       plot_intention = False, 
                       title = None,
        
                       printstat = True,       

                       xlim = (-space,space),
                       ylim = (-space,space),
                       loss_stat = "L1"
                      )
# Out:
# 357
#
#  INPUT
# x=tensor([[-1.6000, 49.7900,  3.1416, 11.7800,  0.0000,  0.0000],
#         [55.8300,  1.6000,  4.7124, 11.6000,  0.0000,  0.0000]]),
# edge_index=tensor([[0],
#         [1]]),
# edge_attr=tensor([2.5000])
#
#
#  TARGET
# tensor([[-1.6000, 23.2300],
#         [26.8200,  1.6000]])
#
#  PREDICTION
# tensor([[-2.1848, 21.2735],
#         [27.1449, -0.6332]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[-1.6000, 49.7900,  3.1416, 11.7800,  0.0000,  0.0000],
#         [55.8300,  1.6000,  4.7124, 11.6000,  0.0000,  0.0000]]),
# edge_index=tensor([[0],
#         [1]]),
# edge_attr=tensor([2.5000])
#
#
#  TARGET
# tensor([[-1.6000, 23.2300],
#         [26.8200,  1.6000]])
#
#  PREDICTION
# tensor([[-2.1848, 21.2735],
#         [27.1449, -0.6332]], grad_fn=<AddBackward0>)
# loss_value=1.274865746498108
# loss_value=1.274865746498108

# %%
space = 100
loss = plot_results_model(
                       load_model, 
                       dateset_train,
                       start_from = max_ind,
                       end_at = max_ind+1,
                       edges_attr = True,
                       figsize = (15,15),
                       plot_input = True,
                       plot_target = True,
                       plot_prediction = True,
                       plot_intention = False, 
                       title = None,
        
                       printstat = True,       

                       xlim = (-space,space),
                       ylim = (-space,space),
                       loss_stat = "L1"
                      )
# Out:
# 631
#
#  INPUT
# x=tensor([[ -1.6000, -62.9900,   3.1416,  15.0000,   2.0000,   0.0000],
#         [  1.6000, -94.9000,   0.0000,   0.0000,   1.0000,   0.0000]]),
# edge_index=tensor([[0],
#         [1]]),
# edge_attr=tensor([2.7000])
#
#
#  TARGET
# tensor([[ -1.6000, -98.9600],
#         [  1.6000, -88.5300]])
#
#  PREDICTION
# tensor([[  4.8576,   4.2992],
#         [-25.4237, -24.9263]], grad_fn=<AddBackward0>)
#
#  INPUT
# x=tensor([[ -1.6000, -62.9900,   3.1416,  15.0000,   2.0000,   0.0000],
#         [  1.6000, -94.9000,   0.0000,   0.0000,   1.0000,   0.0000]]),
# edge_index=tensor([[0],
#         [1]]),
# edge_attr=tensor([2.7000])
#
#
#  TARGET
# tensor([[ -1.6000, -98.9600],
#         [  1.6000, -88.5300]])
#
#  PREDICTION
# tensor([[  4.8576,   4.2992],
#         [-25.4237, -24.9263]], grad_fn=<AddBackward0>)
# loss_value=50.086063385009766
# loss_value=50.086063385009766
